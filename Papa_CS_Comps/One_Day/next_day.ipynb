# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
import random
import time

stock_list = [
    'COST', 'UL', 'AMGN', 'UNH', 'WAT', 'UPS', 'LPX', 'WM', 'NVDA',
    'GOOGL', 'MSFT', 'AXP', 'BLK', 'BRK-B', 'NEE', 'XOM', 'CNI'
]

start_date = '2004-10-01'
end_date = '2024-10-01'
train_split = 0.8

# Hyperparameter search spaces
units_options = [16, 32, 64]
layers_options = [1, 2]
lr_options = [0.001, 0.0005]
batch_options = [4, 8]
epoch_options = [50, 100]
n_steps_options = [2, 5, 10]

def load_and_preprocess_data(ticker, n_steps):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)

    if stock_data.empty:
        return None, None, None, None

    target_y = stock_data['Close']
    X_feat = stock_data[['Open', 'High', 'Low']]

    sc_features = StandardScaler()
    sc_target = StandardScaler()

    X_ft_scaled = sc_features.fit_transform(X_feat.values)
    y_scaled = sc_target.fit_transform(target_y.values.reshape(-1, 1)).flatten()

    data = np.concatenate((X_ft_scaled, y_scaled.reshape(-1, 1)), axis=1)
    stock_data_ft = pd.DataFrame(
        data,
        columns=X_feat.columns.tolist() + ['Close_scaled'],
        index=stock_data['Date']
    )

    def lstm_split(data, n_steps):
        X, y = [], []
        for i in range(len(data) - n_steps + 1):
            X.append(data[i:i + n_steps, :-1])
            y.append(data[i + n_steps - 1, -1])
        return np.array(X), np.array(y)

    X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

    if len(X1) < 20:
        # Not enough data to split meaningfully
        return None, None, None, None

    split_idx = int(np.ceil(len(X1) * train_split))
    X_train, X_test = X1[:split_idx], X1[split_idx:]
    y_train, y_test = y1[:split_idx], y1[split_idx:]

    if len(X_test) < 1:
        return None, None, None, None

    return X_train, X_test, y_train, y_test

def build_lstm_model(n_layers, n_units, learning_rate, input_shape):
    model = Sequential()
    # First LSTM layer
    model.add(LSTM(n_units, input_shape=input_shape, activation='relu', return_sequences=(n_layers > 1)))
    # Additional LSTM layer if specified
    if n_layers > 1:
        model.add(LSTM(n_units, activation='relu'))

    model.add(Dense(1))
    opt = Adam(learning_rate=learning_rate)
    model.compile(loss='mean_squared_error', optimizer=opt)
    return model

def train_and_evaluate_stock(ticker, n_layers, n_units, n_steps, learning_rate, batch_size, epochs):
    X_train, X_test, y_train, y_test = load_and_preprocess_data(ticker, n_steps)
    if X_train is None or X_test is None:
        # Return None to indicate we couldn't train on this stock
        return None

    input_shape = (X_train.shape[1], X_train.shape[2])
    model = build_lstm_model(n_layers, n_units, learning_rate, input_shape=input_shape)
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0, shuffle=False)

    y_pred_scaled = model.predict(X_test, verbose=0)
    mape = mean_absolute_percentage_error(y_test, y_pred_scaled)
    return mape

def random_search(num_samples=40, print_interval=2):
    best_config = None
    best_score = float('inf')
    start_time = time.time()

    # Store results of all configurations
    all_results = []

    for i in range(num_samples):
        n_units = random.choice(units_options)
        n_layers = random.choice(layers_options)
        lr = random.choice(lr_options)
        batch_size = random.choice(batch_options)
        epochs = random.choice(epoch_options)
        n_steps = random.choice(n_steps_options)

        print(f"\n[INFO] Starting config {i+1}/{num_samples}: Layers={n_layers}, Units={n_units}, n_steps={n_steps}, LR={lr}, Batch={batch_size}, Epochs={epochs}")
        mape_scores = []
        stock_count = 0
        for ticker in stock_list:
            mape = train_and_evaluate_stock(ticker, n_layers, n_units, n_steps, lr, batch_size, epochs)
            stock_count += 1
            if mape is not None:
                mape_scores.append(mape)
            else:
                print(f"[WARN] Could not evaluate {ticker}, skipping.")

            # Print progress every few stocks
            if stock_count % (len(stock_list)//3) == 0:
                elapsed = time.time() - start_time
                print(f"[INFO] Processed {stock_count}/{len(stock_list)} stocks for this config. Time elapsed: {elapsed:.2f}s")

        if len(mape_scores) > 0:
            avg_mape = np.mean(mape_scores)
            print(f"[RESULT] Config {i+1}: Average MAPE={avg_mape:.4f}")
            # Record the results
            all_results.append({
                'Layers': n_layers,
                'Units': n_units,
                'n_steps': n_steps,
                'LR': lr,
                'Batch': batch_size,
                'Epochs': epochs,
                'Avg_MAPE': avg_mape
            })

            if avg_mape < best_score:
                best_score = avg_mape
                best_config = (n_layers, n_units, n_steps, lr, batch_size, epochs)
        else:
            print("[WARN] No valid results for this config.")
            # Still record with None if needed
            all_results.append({
                'Layers': n_layers,
                'Units': n_units,
                'n_steps': n_steps,
                'LR': lr,
                'Batch': batch_size,
                'Epochs': epochs,
                'Avg_MAPE': None
            })

        # Print intermediate best result every few configs
        if (i+1) % print_interval == 0:
            elapsed = time.time() - start_time
            print(f"[INFO] After {i+1} configs, best avg MAPE={best_score:.4f} with config={best_config}. Elapsed time={elapsed:.2f}s")

    # Save all results to CSV
    results_df = pd.DataFrame(all_results)
    results_df.to_csv('hyperparam_results.csv', index=False)
    print("[INFO] All results saved to hyperparam_results.csv")

    return best_config, best_score

if __name__ == "__main__":
    best_config, best_score = random_search(num_samples=10, print_interval=2)
    print("Best Config:", best_config, "with Avg MAPE:", best_score)

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
import os

# Configuration chosen from previous best results
n_layers = 1
n_units = 16
n_steps = 5
lr = 0.0005
batch_size = 4
epochs = 100

stock_list = [
    'COST', 'UL', 'AMGN', 'UNH', 'WAT', 'UPS', 'LPX', 'WM', 'NVDA',
    'GOOGL', 'MSFT', 'AXP', 'BLK', 'BRK-B', 'NEE', 'XOM', 'CNI'
]

start_date = '2004-10-01'
end_date = '2024-10-01'
train_split = 0.8

if not os.path.exists("error_analysis_results"):
    os.makedirs("error_analysis_results")

def load_and_preprocess_data(ticker, n_steps):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)

    if stock_data.empty:
        return None, None, None, None, None

    # One-day predictions: we want to predict next day's close
    # Features: Open, High, Low
    # Target: next day's Close
    # Shift Close by -1 day for target
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    # Drop last row due to shift
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    # Prepare features and target
    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day']

    # Scale features and target
    sc_features = StandardScaler()
    sc_target = StandardScaler()

    X_ft_scaled = sc_features.fit_transform(X_feat.values)
    y_scaled = sc_target.fit_transform(y_raw.values.reshape(-1, 1)).flatten()

    data = np.concatenate((X_ft_scaled, y_scaled.reshape(-1, 1)), axis=1)
    # Columns: [Open_scaled, High_scaled, Low_scaled, Close_next_day_scaled]

    def lstm_split(data, n_steps):
        X, y = [], []
        for i in range(len(data) - n_steps + 1):
            X.append(data[i:i + n_steps, :-1])  # all features except last column
            y.append(data[i + n_steps - 1, -1]) # target is at the end of the window
        return np.array(X), np.array(y)

    X1, y1 = lstm_split(data, n_steps=n_steps)

    if len(X1) < 20:
        return None, None, None, None, None

    split_idx = int(np.ceil(len(X1) * train_split))
    X_train, X_test = X1[:split_idx], X1[split_idx:]
    y_train, y_test = y1[:split_idx], y1[split_idx:]

    # Keep track of dates for error analysis
    # The dates correspond to the last day of each n-step window
    # For i-th sample: end date index = i+n_steps-1
    dates = stock_data['Date'].values
    # After LSTM split, the number of samples is len(dates)-n_steps+1
    # The test set dates:
    all_sample_dates = dates[n_steps-1:]
    test_dates = all_sample_dates[split_idx:]

    # We will need scaling inverses for error analysis
    return X_train, X_test, y_train, y_test, (sc_target, test_dates, sc_features)

def build_lstm_model(n_layers, n_units, learning_rate, input_shape):
    model = Sequential()
    model.add(LSTM(n_units, input_shape=input_shape, activation='relu', return_sequences=(n_layers > 1)))
    if n_layers > 1:
        model.add(LSTM(n_units, activation='relu'))
    model.add(Dense(1))
    opt = Adam(learning_rate=learning_rate)
    model.compile(loss='mean_squared_error', optimizer=opt)
    return model

def train_and_get_predictions(ticker):
    # Load data
    data = load_and_preprocess_data(ticker, n_steps)
    if data[0] is None:
        print(f"[WARN] {ticker}: Insufficient data.")
        return None
    X_train, X_test, y_train, y_test, (sc_target, test_dates, sc_features) = data

    input_shape = (X_train.shape[1], X_train.shape[2])
    model = build_lstm_model(n_layers, n_units, lr, input_shape=input_shape)
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0, shuffle=False)

    y_pred_scaled = model.predict(X_test, verbose=0)

    # Inverse scaling
    y_test_unscaled = sc_target.inverse_transform(y_test.reshape(-1,1)).flatten()
    y_pred_unscaled = sc_target.inverse_transform(y_pred_scaled).flatten()

    # Create a DataFrame for analysis
    df_errors = pd.DataFrame({
        'Date': test_dates,
        'Actual_Close_Next_Day': y_test_unscaled,
        'Predicted_Close_Next_Day': y_pred_unscaled
    })

    df_errors['Absolute_Error'] = np.abs(df_errors['Actual_Close_Next_Day'] - df_errors['Predicted_Close_Next_Day'])
    df_errors['APE'] = df_errors['Absolute_Error'] / np.abs(df_errors['Actual_Close_Next_Day'])  # Absolute Percentage Error
    df_errors['MAPE'] = df_errors['APE'] * 100.0  # percentage

    return df_errors

def analyze_errors_for_all_stocks():
    all_summary = []
    for ticker in stock_list:
        print(f"\n[INFO] Analyzing errors for {ticker}...")
        df_errors = train_and_get_predictions(ticker)
        if df_errors is None or len(df_errors)==0:
            continue

        # Compute overall MAPE
        overall_mape = df_errors['MAPE'].mean()
        print(f"[RESULT] {ticker} Overall MAPE: {overall_mape:.2f}%")

        # Sort by MAPE (highest errors first)
        df_sorted = df_errors.sort_values('MAPE', ascending=False)

        # Print top 10 worst predictions
        worst_10 = df_sorted.head(10)
        print(f"[INFO] Top 10 days with highest error for {ticker}:")
        print(worst_10[['Date', 'Actual_Close_Next_Day', 'Predicted_Close_Next_Day', 'MAPE']])

        # Save full error DataFrame to CSV
        df_errors.to_csv(f"error_analysis_results/{ticker}_error_analysis.csv", index=False)

        # Store summary
        all_summary.append({
            'Ticker': ticker,
            'Overall_MAPE': overall_mape
        })

    # Overall summary
    summary_df = pd.DataFrame(all_summary)
    summary_df.to_csv("error_analysis_results/summary.csv", index=False)
    print("\n[INFO] Error analysis completed. Summary saved to error_analysis_results/summary.csv")

if __name__ == "__main__":
    analyze_errors_for_all_stocks()

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
import os
import math
import time

# Configuration chosen from previous best results (example)
n_layers = 1
n_units = 16
n_steps = 5
lr = 0.0005
batch_size = 4
epochs = 50  # Consider fewer epochs for repeated training

# We will only test on Costco
ticker = 'COST'

# Reduced date range
start_date = '2020-01-01'
end_date = '2024-01-01'

if not os.path.exists("rolling_error_analysis_results"):
    os.makedirs("rolling_error_analysis_results")

def load_and_preprocess_data(ticker, n_steps=5):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None, None, None, None

    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day']

    sc_features = StandardScaler()
    sc_target = StandardScaler()

    X_ft_scaled = sc_features.fit_transform(X_feat.values)
    y_scaled = sc_target.fit_transform(y_raw.values.reshape(-1, 1)).flatten()

    data = np.concatenate((X_ft_scaled, y_scaled.reshape(-1,1)), axis=1)
    dates = stock_data['Date'].values

    def lstm_split(data, n_steps):
        X, y = [], []
        for i in range(len(data) - n_steps + 1):
            X.append(data[i:i+n_steps, :-1])
            y.append(data[i+n_steps-1, -1])
        return np.array(X), np.array(y)

    X_all, y_all = lstm_split(data, n_steps)

    if len(X_all) < 20:
        return None, None, None, None, None, None

    sample_end_dates = dates[n_steps-1:]
    return X_all, y_all, sample_end_dates, sc_target, sc_features, stock_data

def build_lstm_model(n_layers, n_units, learning_rate, input_shape):
    model = Sequential()
    model.add(LSTM(n_units, activation='relu', return_sequences=(n_layers > 1), input_shape=input_shape))
    if n_layers > 1:
        model.add(LSTM(n_units, activation='relu'))
    model.add(Dense(1))
    opt = Adam(learning_rate=learning_rate)
    model.compile(loss='mean_squared_error', optimizer=opt)
    return model

def walk_forward_evaluation(X_all, y_all, sample_end_dates, sc_target, window_size=200):
    total_samples = len(X_all)
    if total_samples <= window_size:
        return None

    predictions = []
    actuals = []
    prediction_dates = []

    start_time = time.time()
    progress_interval = 50

    for i in range(total_samples - window_size):
        X_train = X_all[i:i+window_size]
        y_train = y_all[i:i+window_size]
        X_test = X_all[i+window_size:i+window_size+1]
        y_test = y_all[i+window_size:i+window_size+1]

        model = build_lstm_model(n_layers, n_units, lr, input_shape=(X_train.shape[1], X_train.shape[2]))
        model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0, shuffle=False)

        y_pred_scaled = model.predict(X_test, verbose=0)
        y_test_unscaled = sc_target.inverse_transform(y_test.reshape(-1,1)).flatten()
        y_pred_unscaled = sc_target.inverse_transform(y_pred_scaled).flatten()

        predictions.append(y_pred_unscaled[0])
        actuals.append(y_test_unscaled[0])
        prediction_dates.append(sample_end_dates[i+window_size])

        if (i+1) % progress_interval == 0:
            elapsed = time.time() - start_time
            print(f"[INFO] Processed {i+1}/{total_samples - window_size} predictions for {ticker}. Elapsed: {elapsed:.2f}s")

    df_results = pd.DataFrame({
        'Date': prediction_dates,
        'Actual_Close_Next_Day': actuals,
        'Predicted_Close_Next_Day': predictions
    })

    df_results['Absolute_Error'] = np.abs(df_results['Actual_Close_Next_Day'] - df_results['Predicted_Close_Next_Day'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual_Close_Next_Day'])
    df_results['MAPE'] = df_results['APE'] * 100.0

    return df_results

def analyze_rolling_for_costco(window_size=200):
    print(f"[INFO] Rolling evaluation for {ticker} (2020-2024 data)...")
    data = load_and_preprocess_data(ticker, n_steps)
    if data is None or data[0] is None:
        print(f"[WARN] {ticker}: Not enough data.")
        return
    X_all, y_all, sample_end_dates, sc_target, sc_features, stock_data = data
    df_results = walk_forward_evaluation(X_all, y_all, sample_end_dates, sc_target, window_size=window_size)
    if df_results is None or len(df_results)==0:
        print(f"[WARN] {ticker}: Not enough samples for rolling evaluation.")
        return

    overall_mape = df_results['MAPE'].mean()
    print(f"[RESULT] {ticker} Overall MAPE (Rolling): {overall_mape:.2f}%")

    worst_10 = df_results.sort_values('MAPE', ascending=False).head(10)
    print("[INFO] Top 10 worst predictions for COST:")
    print(worst_10[['Date', 'Actual_Close_Next_Day', 'Predicted_Close_Next_Day', 'MAPE']])

    df_results.to_csv(f"rolling_error_analysis_results/{ticker}_rolling_results.csv", index=False)
    print("[INFO] Rolling error analysis completed for COST. Results saved.")

if __name__ == "__main__":
    analyze_rolling_for_costco(window_size=200)

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
import os
import math
import time

########################
# Configuration
########################
ticker = 'COST'
start_date = '2020-01-01'
end_date = '2024-01-01'

n_steps = 5
window_size = 200
step_size = 10
initial_epochs = 50
update_epochs = 20

initial_lr = 0.0005
update_lr = 0.0002

train_ratio = 0.9

if not os.path.exists("rolling_error_analysis_results"):
    os.makedirs("rolling_error_analysis_results")

########################
# Data Loading Functions
########################
def load_full_data_helper(ticker):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None

    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values

    if len(dates) < window_size:
        return None, None, None

    return X_feat.values, y_raw, dates

def load_full_data(ticker):
    X_feat, y_raw, dates = load_full_data_helper(ticker)
    if X_feat is None:
        return None, None, None
    return X_feat, y_raw, dates

########################
# Model Creation
########################
def create_lstm_model(n_layers, n_units, learning_rate, input_shape):
    model = Sequential()
    model.add(LSTM(n_units, activation='relu', return_sequences=(n_layers > 1), input_shape=input_shape))
    if n_layers > 1:
        model.add(LSTM(n_units, activation='relu'))
    model.add(Dense(1))
    opt = Adam(learning_rate=learning_rate)
    model.compile(loss='mean_squared_error', optimizer=opt)
    return model

########################
# Window Extraction
########################
def extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None, None, None, None

    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]

    def lstm_split(dataX, dataY, n_steps):
        X, y = [], []
        for i in range(len(dataX)-n_steps+1):
            X.append(dataX[i:i+n_steps])
            y.append(dataY[i+n_steps-1])
        return np.array(X), np.array(y)

    # Create samples before scaling to determine sample count
    X_samples, y_samples = lstm_split(X_window, y_window, n_steps)
    sample_dates = dates_window[n_steps-1:]

    # Scaling with RobustScaler
    feat_scaler = RobustScaler()
    target_scaler = RobustScaler()

    X_flat = X_window.reshape(len(X_window), -1)
    feat_scaler.fit(X_flat)
    y_window_reshaped = y_window.reshape(-1,1)
    target_scaler.fit(y_window_reshaped)

    X_scaled = feat_scaler.transform(X_flat).reshape(X_window.shape)
    y_scaled = target_scaler.transform(y_window_reshaped).flatten()

    X_samples_scaled, y_samples_scaled = lstm_split(X_scaled, y_scaled, n_steps)

    return X_samples_scaled, y_samples_scaled, sample_dates, feat_scaler, target_scaler, (X_window, y_window, dates_window)

########################
# Train on Window
########################
def train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=None):
    total_samples = len(X_samples)
    train_count = int(math.floor(total_samples * train_ratio))
    if train_count >= total_samples:
        train_count = total_samples - 1

    X_train, y_train = X_samples[:train_count], y_samples[:train_count]
    X_val, y_val = X_samples[train_count:], y_samples[train_count:]

    if initial_training:
        epochs = initial_epochs
        lr = initial_lr
    else:
        epochs = update_epochs
        lr = update_lr

    input_shape = (X_train.shape[1], X_train.shape[2])
    model = create_lstm_model(1, 16, lr, input_shape)

    if prev_weights is not None:
        model.load_weights(prev_weights)

    model.fit(X_train, y_train, epochs=epochs, batch_size=4, verbose=0, shuffle=False, validation_data=(X_val, y_val))

    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_unscaled = target_scaler.inverse_transform(y_val.reshape(-1,1)).flatten()
    y_val_pred_unscaled = target_scaler.inverse_transform(y_val_pred_scaled).flatten()
    val_mape = mean_absolute_percentage_error(y_val_unscaled, y_val_pred_unscaled) * 100

    return model, val_mape

########################
# Rolling Training
########################
def rolling_training(ticker, window_size=200, step_size=10, n_steps=5):
    data = load_full_data(ticker)
    if data[0] is None:
        print("[WARN] Not enough data.")
        return
    X_full, y_full, dates_full = data

    start_time = time.time()

    # Initial window
    start_idx = 0
    window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
    if window_data[0] is None:
        print("[WARN] Initial window not valid.")
        return
    X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

    print("[INFO] Training initial window...")
    model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=True, prev_weights=None)
    print(f"[RESULT] Initial window validation MAPE: {val_mape:.2f}%")

    weights_path = "rolling_error_analysis_results/cost_initial.weights.h5"
    model.save_weights(weights_path)

    predictions = []
    actuals = []
    pred_dates = []

    iteration = 1
    while True:
        start_idx += step_size
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
        if window_data[0] is None:
            print("[INFO] No more windows can be extracted.")
            break
        X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

        print(f"\n[INFO] Iteration {iteration}: training on new window starting at {start_idx}")
        model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=weights_path)
        print(f"[RESULT] Window validation MAPE: {val_mape:.2f}%")

        weights_path = f"rolling_error_analysis_results/cost_iteration_{iteration}.weights.h5"
        model.save_weights(weights_path)

        X_test_last = X_samples[-1:]
        y_test_last = y_samples[-1:]
        y_pred_scaled = model.predict(X_test_last, verbose=0)
        y_test_unscaled = target_scaler.inverse_transform(y_test_last.reshape(-1,1)).flatten()
        y_pred_unscaled = target_scaler.inverse_transform(y_pred_scaled).flatten()

        predictions.append(y_pred_unscaled[0])
        actuals.append(y_test_unscaled[0])
        pred_dates.append(sample_dates[-1])

        test_mape = mean_absolute_percentage_error(y_test_unscaled, y_pred_unscaled)*100
        print(f"[INFO] Predicted last sample of window: Actual={y_test_unscaled[0]:.2f}, Pred={y_pred_unscaled[0]:.2f}, MAPE={test_mape:.2f}%")

        iteration += 1

    df_results = pd.DataFrame({
        'Date': pred_dates,
        'Actual': actuals,
        'Predicted': predictions
    })
    df_results['Absolute_Error'] = np.abs(df_results['Actual'] - df_results['Predicted'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual'])
    df_results['MAPE'] = df_results['APE'] * 100.0

    df_results.to_csv("rolling_error_analysis_results/cost_rolling_results.csv", index=False)
    overall_mape = df_results['MAPE'].mean()
    print(f"\n[INFO] Rolling training completed for COST. Overall MAPE across predictions: {overall_mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] Total elapsed time: {elapsed:.2f}s")

    worst_10 = df_results.sort_values('MAPE', ascending=False).head(10)
    print("[INFO] Top 10 worst predictions in rolling scenario:")
    print(worst_10[['Date', 'Actual', 'Predicted', 'MAPE']])

if __name__ == "__main__":
    rolling_training(ticker, window_size=200, step_size=10, n_steps=5)

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
import os
import math
import time
import matplotlib.pyplot as plt

########################
# Configuration
########################
ticker = 'COST'
start_date = '2020-01-01'
end_date = '2024-01-01'

n_steps = 5
window_size = 200
step_size = 10
initial_epochs = 50
update_epochs = 20

initial_lr = 0.0005
update_lr = 0.0002

train_ratio = 0.9

if not os.path.exists("rolling_error_analysis_results"):
    os.makedirs("rolling_error_analysis_results")

def load_full_data_helper(ticker):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values

    if len(dates) < window_size:
        return None, None, None
    return X_feat.values, y_raw, dates

def load_full_data(ticker):
    X_feat, y_raw, dates = load_full_data_helper(ticker)
    if X_feat is None:
        return None, None, None
    return X_feat, y_raw, dates

def create_lstm_model(n_layers, n_units, learning_rate, input_shape):
    model = Sequential()
    model.add(LSTM(n_units, activation='relu', return_sequences=(n_layers > 1), input_shape=input_shape))
    if n_layers > 1:
        model.add(LSTM(n_units, activation='relu'))
    model.add(Dense(1))
    opt = Adam(learning_rate=learning_rate)
    model.compile(loss='mean_squared_error', optimizer=opt)
    return model

def extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None, None, None, None

    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]

    def lstm_split(dataX, dataY, n_steps):
        X, y = [], []
        for i in range(len(dataX)-n_steps+1):
            X.append(dataX[i:i+n_steps])
            y.append(dataY[i+n_steps-1])
        return np.array(X), np.array(y)

    X_samples, y_samples = lstm_split(X_window, y_window, n_steps)
    sample_dates = dates_window[n_steps-1:]

    feat_scaler = RobustScaler()
    target_scaler = RobustScaler()
    X_flat = X_window.reshape(len(X_window), -1)
    feat_scaler.fit(X_flat)
    y_window_reshaped = y_window.reshape(-1,1)
    target_scaler.fit(y_window_reshaped)
    X_scaled = feat_scaler.transform(X_flat).reshape(X_window.shape)
    y_scaled = target_scaler.transform(y_window_reshaped).flatten()
    X_samples_scaled, y_samples_scaled = lstm_split(X_scaled, y_scaled, n_steps)

    return X_samples_scaled, y_samples_scaled, sample_dates, feat_scaler, target_scaler, (X_window, y_window, dates_window)

def train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=None):
    total_samples = len(X_samples)
    train_count = int(math.floor(total_samples * train_ratio))
    if train_count >= total_samples:
        train_count = total_samples - 1

    X_train, y_train = X_samples[:train_count], y_samples[:train_count]
    X_val, y_val = X_samples[train_count:], y_samples[train_count:]

    if initial_training:
        epochs = initial_epochs
        lr = initial_lr
    else:
        epochs = update_epochs
        lr = update_lr

    input_shape = (X_train.shape[1], X_train.shape[2])
    model = create_lstm_model(1, 16, lr, input_shape)

    if prev_weights is not None:
        model.load_weights(prev_weights)

    # No early stopping here, run all epochs
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=4, verbose=0, shuffle=False,
                        validation_data=(X_val, y_val))

    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_unscaled = target_scaler.inverse_transform(y_val.reshape(-1,1)).flatten()
    y_val_pred_unscaled = target_scaler.inverse_transform(y_val_pred_scaled).flatten()
    val_mape = mean_absolute_percentage_error(y_val_unscaled, y_val_pred_unscaled) * 100

    return model, val_mape, history

def rolling_training_no_early_stopping_worst10(ticker, window_size=200, step_size=10, n_steps=5):
    X_full, y_full, dates_full = load_full_data(ticker)
    if X_full is None:
        print("[WARN] Not enough data.")
        return

    start_time = time.time()

    start_idx = 0
    window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
    if window_data[0] is None:
        print("[WARN] Initial window not valid.")
        return
    X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

    print("[INFO] Training initial window (no early stopping)...")
    model, val_mape, history_init = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=True, prev_weights=None)
    print(f"[RESULT] Initial window validation MAPE: {val_mape:.2f}%")

    weights_path = "rolling_error_analysis_results/cost_initial_noes.weights.h5"
    model.save_weights(weights_path)

    predictions = []
    actuals = []
    pred_dates = []
    histories = [(0, history_init)]  # 0 for initial

    iteration = 1
    while True:
        start_idx += step_size
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
        if window_data[0] is None:
            print("[INFO] No more windows can be extracted.")
            break
        X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

        print(f"\n[INFO] Iteration {iteration}: training on new window (no early stopping)...")
        model, val_mape, history_iter = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=weights_path)
        print(f"[RESULT] Window validation MAPE: {val_mape:.2f}%")
        histories.append((iteration, history_iter))

        weights_path = f"rolling_error_analysis_results/cost_iteration_{iteration}_noes.weights.h5"
        model.save_weights(weights_path)

        X_test_last = X_samples[-1:]
        y_test_last = y_samples[-1:]
        y_pred_scaled = model.predict(X_test_last, verbose=0)
        y_test_unscaled = target_scaler.inverse_transform(y_test_last.reshape(-1,1)).flatten()
        y_pred_unscaled = target_scaler.inverse_transform(y_pred_scaled).flatten()

        predictions.append(y_pred_unscaled[0])
        actuals.append(y_test_unscaled[0])
        pred_dates.append(sample_dates[-1])

        test_mape = mean_absolute_percentage_error(y_test_unscaled, y_pred_unscaled)*100
        print(f"[INFO] Predicted last sample of window: Actual={y_test_unscaled[0]:.2f}, Pred={y_pred_unscaled[0]:.2f}, MAPE={test_mape:.2f}%")

        iteration += 1

    df_results = pd.DataFrame({
        'Date': pred_dates,
        'Actual': actuals,
        'Predicted': predictions
    })
    df_results['Absolute_Error'] = np.abs(df_results['Actual'] - df_results['Predicted'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual'])
    df_results['MAPE'] = df_results['APE'] * 100.0

    df_results.to_csv("rolling_error_analysis_results/cost_rolling_results_noes.csv", index=False)
    overall_mape = df_results['MAPE'].mean()
    print(f"\n[INFO] Rolling training (no early stopping) completed for COST. Overall MAPE: {overall_mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] Total elapsed time: {elapsed:.2f}s")

    worst_10 = df_results.sort_values('MAPE', ascending=False).head(10)
    print("[INFO] Top 10 worst predictions in rolling scenario (No Early Stopping):")
    print(worst_10[['Date', 'Actual', 'Predicted', 'MAPE']])

    # Extract iterations from worst_10 predictions
    # iteration index starts at 1 for first update, df_results starts at 0
    worst_iterations = [i+1 for i in worst_10.index]

    # Filter histories to only include these worst iterations
    filtered_histories = [(it, hist) for (it, hist) in histories if it in worst_iterations]

    # Plot only these worst iterations
    plt.figure(figsize=(10,6))
    for (it, hist) in filtered_histories:
        train_loss = hist.history['loss']
        val_loss = hist.history['val_loss']
        epochs_range = range(1, len(train_loss)+1)
        plt.plot(epochs_range, train_loss, label=f'Iter_{it}_train_loss')
        plt.plot(epochs_range, val_loss, label=f'Iter_{it}_val_loss')

    plt.title("Training and Validation Loss for 10 Worst MAPE Iterations (No Early Stopping)")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.savefig("rolling_error_analysis_results/worst_10_training_curves_noes.png")
    print("[INFO] Training curves for 10 worst MAPE iterations (No Early Stopping) saved as worst_10_training_curves_noes.png")

if __name__ == "__main__":
    rolling_training_no_early_stopping_worst10(ticker, window_size=200, step_size=10, n_steps=5)

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os
import math
import time

########################
# Configuration
########################
ticker = 'COST'
start_date = '2020-01-01'
end_date = '2024-01-01'

n_steps = 5
window_size = 200
step_size = 10
initial_epochs = 100
update_epochs = 100

initial_lr = 0.0005
update_lr = 0.0002

train_ratio = 0.9

if not os.path.exists("rolling_error_analysis_results"):
    os.makedirs("rolling_error_analysis_results")

def load_full_data_helper(ticker):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values

    if len(dates) < window_size:
        return None, None, None
    return X_feat.values, y_raw, dates

def load_full_data(ticker):
    X_feat, y_raw, dates = load_full_data_helper(ticker)
    if X_feat is None:
        return None, None, None
    return X_feat, y_raw, dates

def create_lstm_model(n_layers, n_units, learning_rate, input_shape):
    model = Sequential()
    model.add(LSTM(n_units, activation='relu', return_sequences=(n_layers > 1), input_shape=input_shape))
    if n_layers > 1:
        model.add(LSTM(n_units, activation='relu'))
    model.add(Dense(1))
    opt = Adam(learning_rate=learning_rate)
    model.compile(loss='mean_squared_error', optimizer=opt)
    return model

def extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None, None, None, None

    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]

    def lstm_split(dataX, dataY, n_steps):
        X, y = [], []
        for i in range(len(dataX)-n_steps+1):
            X.append(dataX[i:i+n_steps])
            y.append(dataY[i+n_steps-1])
        return np.array(X), np.array(y)

    X_samples, y_samples = lstm_split(X_window, y_window, n_steps)
    sample_dates = dates_window[n_steps-1:]

    feat_scaler = RobustScaler()
    target_scaler = RobustScaler()
    X_flat = X_window.reshape(len(X_window), -1)
    feat_scaler.fit(X_flat)
    y_window_reshaped = y_window.reshape(-1,1)
    target_scaler.fit(y_window_reshaped)
    X_scaled = feat_scaler.transform(X_flat).reshape(X_window.shape)
    y_scaled = target_scaler.transform(y_window_reshaped).flatten()
    X_samples_scaled, y_samples_scaled = lstm_split(X_scaled, y_scaled, n_steps)

    return X_samples_scaled, y_samples_scaled, sample_dates, feat_scaler, target_scaler, (X_window, y_window, dates_window)

def train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=None):
    total_samples = len(X_samples)
    train_count = int(math.floor(total_samples * train_ratio))
    if train_count >= total_samples:
        train_count = total_samples - 1

    X_train, y_train = X_samples[:train_count], y_samples[:train_count]
    X_val, y_val = X_samples[train_count:], y_samples[train_count:]

    if initial_training:
        epochs = initial_epochs
        lr = initial_lr
    else:
        epochs = update_epochs
        lr = update_lr

    input_shape = (X_train.shape[1], X_train.shape[2])
    model = create_lstm_model(1, 16, lr, input_shape)

    if prev_weights is not None:
        model.load_weights(prev_weights)

    # EarlyStopping callback
    es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=epochs, batch_size=4, verbose=0, shuffle=False,
              validation_data=(X_val, y_val), callbacks=[es])

    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_unscaled = target_scaler.inverse_transform(y_val.reshape(-1,1)).flatten()
    y_val_pred_unscaled = target_scaler.inverse_transform(y_val_pred_scaled).flatten()
    val_mape = mean_absolute_percentage_error(y_val_unscaled, y_val_pred_unscaled) * 100

    return model, val_mape

def rolling_training_early_stopping(ticker, window_size=200, step_size=10, n_steps=5):
    X_full, y_full, dates_full = load_full_data(ticker)
    if X_full is None:
        print("[WARN] Not enough data.")
        return

    start_time = time.time()

    start_idx = 0
    window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
    if window_data[0] is None:
        print("[WARN] Initial window not valid.")
        return
    X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

    print("[INFO] Training initial window with Early Stopping...")
    model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=True, prev_weights=None)
    print(f"[RESULT] Initial window validation MAPE: {val_mape:.2f}%")

    weights_path = "rolling_error_analysis_results/cost_initial_es.weights.h5"
    model.save_weights(weights_path)

    predictions = []
    actuals = []
    pred_dates = []

    iteration = 1
    while True:
        start_idx += step_size
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
        if window_data[0] is None:
            print("[INFO] No more windows can be extracted.")
            break
        X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

        print(f"\n[INFO] Iteration {iteration}: training on new window with Early Stopping...")
        model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=weights_path)
        print(f"[RESULT] Window validation MAPE: {val_mape:.2f}%")

        weights_path = f"rolling_error_analysis_results/cost_iteration_{iteration}_es.weights.h5"
        model.save_weights(weights_path)

        X_test_last = X_samples[-1:]
        y_test_last = y_samples[-1:]
        y_pred_scaled = model.predict(X_test_last, verbose=0)
        y_test_unscaled = target_scaler.inverse_transform(y_test_last.reshape(-1,1)).flatten()
        y_pred_unscaled = target_scaler.inverse_transform(y_pred_scaled).flatten()

        predictions.append(y_pred_unscaled[0])
        actuals.append(y_test_unscaled[0])
        pred_dates.append(sample_dates[-1])

        test_mape = mean_absolute_percentage_error(y_test_unscaled, y_pred_unscaled)*100
        print(f"[INFO] Predicted last sample of window: Actual={y_test_unscaled[0]:.2f}, Pred={y_pred_unscaled[0]:.2f}, MAPE={test_mape:.2f}%")

        iteration += 1

    df_results = pd.DataFrame({
        'Date': pred_dates,
        'Actual': actuals,
        'Predicted': predictions
    })
    df_results['Absolute_Error'] = np.abs(df_results['Actual'] - df_results['Predicted'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual'])
    df_results['MAPE'] = df_results['APE'] * 100.0

    df_results.to_csv("rolling_error_analysis_results/cost_rolling_results_es.csv", index=False)
    overall_mape = df_results['MAPE'].mean()
    print(f"\n[INFO] Rolling training with Early Stopping completed for COST. Overall MAPE: {overall_mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] Total elapsed time: {elapsed:.2f}s")

    worst_10 = df_results.sort_values('MAPE', ascending=False).head(10)
    print("[INFO] Top 10 worst predictions in rolling scenario (Early Stopping):")
    print(worst_10[['Date', 'Actual', 'Predicted', 'MAPE']])

if __name__ == "__main__":
    rolling_training_early_stopping(ticker, window_size=200, step_size=10, n_steps=5)

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
import os
import math
import time

########################
# Configuration
########################
ticker = 'COST'
start_date = '2020-01-01'
end_date = '2024-01-01'

n_steps = 5
window_size = 200
step_size = 10
initial_epochs = 50
update_epochs = 20
initial_lr = 0.0005
update_lr = 0.0002
train_ratio = 0.9
dropout_rate = 0.01

if not os.path.exists("rolling_error_analysis_results"):
    os.makedirs("rolling_error_analysis_results")

def load_full_data_helper(ticker):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values

    if len(dates) < window_size:
        return None, None, None
    return X_feat.values, y_raw, dates

def load_full_data(ticker):
    X_feat, y_raw, dates = load_full_data_helper(ticker)
    if X_feat is None:
        return None, None, None
    return X_feat, y_raw, dates

from tensorflow.keras.layers import LSTM, Dense, Dropout

def create_lstm_model(n_layers, n_units, learning_rate, input_shape, dropout=0.2):
    model = Sequential()
    model.add(LSTM(n_units, activation='relu', return_sequences=(n_layers > 1),
                   input_shape=input_shape, dropout=dropout, recurrent_dropout=dropout))
    if n_layers > 1:
        model.add(LSTM(n_units, activation='relu', dropout=dropout, recurrent_dropout=dropout))
    model.add(Dense(1))
    opt = Adam(learning_rate=learning_rate)
    model.compile(loss='mean_squared_error', optimizer=opt)
    return model

def extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None, None, None, None
    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]

    def lstm_split(dataX, dataY, n_steps):
        X, y = [], []
        for i in range(len(dataX)-n_steps+1):
            X.append(dataX[i:i+n_steps])
            y.append(dataY[i+n_steps-1])
        return np.array(X), np.array(y)

    X_samples, y_samples = lstm_split(X_window, y_window, n_steps)
    sample_dates = dates_window[n_steps-1:]

    from sklearn.preprocessing import RobustScaler
    feat_scaler = RobustScaler()
    target_scaler = RobustScaler()
    X_flat = X_window.reshape(len(X_window), -1)
    feat_scaler.fit(X_flat)
    y_window_reshaped = y_window.reshape(-1,1)
    target_scaler.fit(y_window_reshaped)
    X_scaled = feat_scaler.transform(X_flat).reshape(X_window.shape)
    y_scaled = target_scaler.transform(y_window_reshaped).flatten()
    X_samples_scaled, y_samples_scaled = lstm_split(X_scaled, y_scaled, n_steps)

    return X_samples_scaled, y_samples_scaled, sample_dates, feat_scaler, target_scaler, (X_window, y_window, dates_window)

def train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=None, dropout=0.2):
    total_samples = len(X_samples)
    train_count = int(math.floor(total_samples * train_ratio))
    if train_count >= total_samples:
        train_count = total_samples - 1

    X_train, y_train = X_samples[:train_count], y_samples[:train_count]
    X_val, y_val = X_samples[train_count:], y_samples[train_count:]

    if initial_training:
        epochs = initial_epochs
        lr = initial_lr
    else:
        epochs = update_epochs
        lr = update_lr

    input_shape = (X_train.shape[1], X_train.shape[2])
    model = create_lstm_model(1, 16, lr, input_shape, dropout=dropout)

    if prev_weights is not None:
        model.load_weights(prev_weights)

    model.fit(X_train, y_train, epochs=epochs, batch_size=4, verbose=0, shuffle=False, validation_data=(X_val, y_val))

    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_unscaled = target_scaler.inverse_transform(y_val.reshape(-1,1)).flatten()
    y_val_pred_unscaled = target_scaler.inverse_transform(y_val_pred_scaled).flatten()
    val_mape = mean_absolute_percentage_error(y_val_unscaled, y_val_pred_unscaled) * 100

    return model, val_mape

def rolling_training_dropout(ticker, window_size=200, step_size=10, n_steps=5, dropout=0.2):
    X_full, y_full, dates_full = load_full_data(ticker)
    if X_full is None:
        print("[WARN] Not enough data.")
        return

    start_time = time.time()

    start_idx = 0
    window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
    if window_data[0] is None:
        print("[WARN] Initial window not valid.")
        return
    X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

    print("[INFO] Training initial window with Dropout...")
    model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=True, prev_weights=None, dropout=dropout)
    print(f"[RESULT] Initial window validation MAPE: {val_mape:.2f}%")

    weights_path = "rolling_error_analysis_results/cost_initial_dropout.weights.h5"
    model.save_weights(weights_path)

    predictions = []
    actuals = []
    pred_dates = []

    iteration = 1
    while True:
        start_idx += step_size
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
        if window_data[0] is None:
            print("[INFO] No more windows can be extracted.")
            break
        X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

        print(f"\n[INFO] Iteration {iteration}: training on new window with Dropout...")
        model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=weights_path, dropout=dropout)
        print(f"[RESULT] Window validation MAPE: {val_mape:.2f}%")

        weights_path = f"rolling_error_analysis_results/cost_iteration_{iteration}_dropout.weights.h5"
        model.save_weights(weights_path)

        X_test_last = X_samples[-1:]
        y_test_last = y_samples[-1:]
        y_pred_scaled = model.predict(X_test_last, verbose=0)
        y_test_unscaled = target_scaler.inverse_transform(y_test_last.reshape(-1,1)).flatten()
        y_pred_unscaled = target_scaler.inverse_transform(y_pred_scaled).flatten()

        predictions.append(y_pred_unscaled[0])
        actuals.append(y_test_unscaled[0])
        pred_dates.append(sample_dates[-1])

        test_mape = mean_absolute_percentage_error(y_test_unscaled, y_pred_unscaled)*100
        print(f"[INFO] Predicted last sample of window: Actual={y_test_unscaled[0]:.2f}, Pred={y_pred_unscaled[0]:.2f}, MAPE={test_mape:.2f}%")

        iteration += 1

    df_results = pd.DataFrame({
        'Date': pred_dates,
        'Actual': actuals,
        'Predicted': predictions
    })
    df_results['Absolute_Error'] = np.abs(df_results['Actual'] - df_results['Predicted'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual'])
    df_results['MAPE'] = df_results['APE'] * 100.0

    df_results.to_csv("rolling_error_analysis_results/cost_rolling_results_dropout.csv", index=False)
    overall_mape = df_results['MAPE'].mean()
    print(f"\n[INFO] Rolling training with Dropout completed for COST. Overall MAPE: {overall_mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] Total elapsed time: {elapsed:.2f}s")

    worst_10 = df_results.sort_values('MAPE', ascending=False).head(10)
    print("[INFO] Top 10 worst predictions in rolling scenario (Dropout):")
    print(worst_10[['Date', 'Actual', 'Predicted', 'MAPE']])

if __name__ == "__main__":
    rolling_training_dropout(ticker, window_size=200, step_size=10, n_steps=5, dropout=0.2)

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os
import math
import time

########################
# Configuration
########################
ticker = 'COST'
start_date = '2020-01-01'
end_date = '2024-01-01'

n_steps = 5
window_size = 200
step_size = 10
initial_epochs = 100
update_epochs = 100

initial_lr = 0.0005
update_lr = 0.0002

train_ratio = 0.9

if not os.path.exists("rolling_error_analysis_results"):
    os.makedirs("rolling_error_analysis_results")

def load_full_data_helper(ticker):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values

    if len(dates) < window_size:
        return None, None, None
    return X_feat.values, y_raw, dates

def load_full_data(ticker):
    X_feat, y_raw, dates = load_full_data_helper(ticker)
    if X_feat is None:
        return None, None, None
    return X_feat, y_raw, dates

def create_lstm_model(n_layers, n_units, learning_rate, input_shape):
    model = Sequential()
    model.add(LSTM(n_units, activation='relu', return_sequences=(n_layers > 1), input_shape=input_shape))
    if n_layers > 1:
        model.add(LSTM(n_units, activation='relu'))
    model.add(Dense(1))
    opt = Adam(learning_rate=learning_rate)
    model.compile(loss='mean_squared_error', optimizer=opt)
    return model

def apply_scaling(X_window, y_window, method):
    """
    Apply chosen scaling method to X_window and y_window.
    method can be 'robust', 'log', or 'rolling_stats'.
    Returns X_scaled, y_scaled, X_transform_info, y_transform_info
    where transform_info can be used for inverse transformation later.
    """
    if method == 'robust':
        # Use RobustScaler as originally
        feat_scaler = RobustScaler()
        target_scaler = RobustScaler()
        X_flat = X_window.reshape(len(X_window), -1)
        feat_scaler.fit(X_flat)
        y_window_reshaped = y_window.reshape(-1,1)
        target_scaler.fit(y_window_reshaped)
        X_scaled_flat = feat_scaler.transform(X_flat)
        y_scaled = target_scaler.transform(y_window_reshaped).flatten()
        X_scaled = X_scaled_flat.reshape(X_window.shape)
        # Store scalers for inverse
        return X_scaled, y_scaled, ('robust', feat_scaler), ('robust', target_scaler)

    elif method == 'log':
        # Log transform features and target, then standard scale
        # Add a small constant to avoid log(0) if necessary
        epsilon = 1e-3
        X_log = np.log(X_window + epsilon)
        y_log = np.log(y_window.reshape(-1,1) + epsilon)

        feat_scaler = StandardScaler()
        target_scaler = StandardScaler()
        X_flat = X_log.reshape(len(X_window), -1)
        feat_scaler.fit(X_flat)
        target_scaler.fit(y_log)
        X_scaled_flat = feat_scaler.transform(X_flat)
        y_scaled = target_scaler.transform(y_log).flatten()
        X_scaled = X_scaled_flat.reshape(X_window.shape)
        # Store info that we used log transform and epsilon
        return X_scaled, y_scaled, ('log', feat_scaler, epsilon), ('log', target_scaler, epsilon)

    elif method == 'rolling_stats':
        # Compute median and IQR for each feature in X_window and for target
        # We'll apply median/IQR scaling similar to a robust scaling but manually
        X_median = np.median(X_window, axis=0)
        X_q1 = np.percentile(X_window, 25, axis=0)
        X_q3 = np.percentile(X_window, 75, axis=0)
        X_iqr = X_q3 - X_q1
        # Avoid divide by zero
        X_iqr[X_iqr == 0] = 1e-3
        X_scaled = (X_window - X_median) / X_iqr

        y_median = np.median(y_window)
        y_q1 = np.percentile(y_window, 25)
        y_q3 = np.percentile(y_window, 75)
        y_iqr = y_q3 - y_q1
        if y_iqr == 0:
            y_iqr = 1e-3
        y_scaled = (y_window - y_median) / y_iqr
        return X_scaled, y_scaled, ('rolling_stats', X_median, X_iqr), ('rolling_stats', y_median, y_iqr)

def lstm_split(dataX, dataY, n_steps):
    X, y = [], []
    for i in range(len(dataX)-n_steps+1):
        X.append(dataX[i:i+n_steps])
        y.append(dataY[i+n_steps-1])
    return np.array(X), np.array(y)

def extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps, scaling_method='robust'):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None, None, None, None

    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]

    # We first scale X_window and y_window
    X_scaled, y_scaled, X_info, y_info = apply_scaling(X_window, y_window, scaling_method)

    X_samples, y_samples = lstm_split(X_scaled, y_scaled, n_steps)
    sample_dates = dates_window[n_steps-1:]

    return X_samples, y_samples, sample_dates, X_info, y_info, (X_window, y_window, dates_window)

def inverse_transform(y_pred_scaled, y_true_scaled, y_info):
    method = y_info[0]
    if method == 'robust':
        target_scaler = y_info[1]
        # inverse_transform expects a 2D array
        y_pred_unscaled = target_scaler.inverse_transform(y_pred_scaled.reshape(-1,1)).flatten()
        y_true_unscaled = target_scaler.inverse_transform(y_true_scaled.reshape(-1,1)).flatten()
        return y_pred_unscaled, y_true_unscaled

    elif method == 'log':
        target_scaler = y_info[1]
        epsilon = y_info[2]
        y_pred_log = target_scaler.inverse_transform(y_pred_scaled.reshape(-1,1))
        y_true_log = target_scaler.inverse_transform(y_true_scaled.reshape(-1,1))
        # Now exponentiate and subtract epsilon
        y_pred_unscaled = np.exp(y_pred_log) - epsilon
        y_true_unscaled = np.exp(y_true_log) - epsilon
        return y_pred_unscaled.flatten(), y_true_unscaled.flatten()

    elif method == 'rolling_stats':
        y_median = y_info[1]
        y_iqr = y_info[2]
        y_pred_unscaled = (y_pred_scaled * y_iqr) + y_median
        y_true_unscaled = (y_true_scaled * y_iqr) + y_median
        return y_pred_unscaled, y_true_unscaled

def train_on_window(X_samples, y_samples, X_info, y_info, initial_training=False, prev_weights=None):
    total_samples = len(X_samples)
    train_count = int(math.floor(total_samples * train_ratio))
    if train_count >= total_samples:
        train_count = total_samples - 1

    X_train, y_train = X_samples[:train_count], y_samples[:train_count]
    X_val, y_val = X_samples[train_count:], y_samples[train_count:]

    if initial_training:
        epochs = initial_epochs
        lr = initial_lr
    else:
        epochs = update_epochs
        lr = update_lr

    input_shape = (X_train.shape[1], X_train.shape[2])
    model = create_lstm_model(1, 16, lr, input_shape)

    if prev_weights is not None:
        model.load_weights(prev_weights)

    es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=epochs, batch_size=4, verbose=0, shuffle=False,
              validation_data=(X_val, y_val), callbacks=[es])

    # Compute validation MAPE
    y_val_pred_scaled = model.predict(X_val, verbose=0)
    # For MAPE, we need inverse transform
    y_val_pred_unscaled, y_val_unscaled = inverse_transform(y_val_pred_scaled.flatten(), y_val.flatten(), y_info)
    val_mape = mean_absolute_percentage_error(y_val_unscaled, y_val_pred_unscaled) * 100

    return model, val_mape

def rolling_training_early_stopping(ticker, window_size=200, step_size=10, n_steps=5, scaling_method='robust'):
    X_full, y_full, dates_full = load_full_data(ticker)
    if X_full is None:
        print("[WARN] Not enough data.")
        return

    start_time = time.time()

    start_idx = 0
    window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps, scaling_method)
    if window_data[0] is None:
        print("[WARN] Initial window not valid.")
        return
    X_samples, y_samples, sample_dates, X_info, y_info, (Xw, yw, dw) = window_data

    print(f"[INFO] Training initial window with Early Stopping using {scaling_method} scaling...")
    model, val_mape = train_on_window(X_samples, y_samples, X_info, y_info, initial_training=True, prev_weights=None)
    print(f"[RESULT] Initial window validation MAPE ({scaling_method}): {val_mape:.2f}%")

    weights_path = f"rolling_error_analysis_results/cost_initial_es_{scaling_method}.weights.h5"
    model.save_weights(weights_path)

    predictions = []
    actuals = []
    pred_dates = []
    iteration = 1
    while True:
        start_idx += step_size
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps, scaling_method)
        if window_data[0] is None:
            print("[INFO] No more windows can be extracted.")
            break
        X_samples, y_samples, sample_dates, X_info, y_info, (Xw, yw, dw) = window_data

        print(f"\n[INFO] Iteration {iteration}: training on new window with Early Stopping ({scaling_method})...")
        model, val_mape = train_on_window(X_samples, y_samples, X_info, y_info, initial_training=False, prev_weights=weights_path)
        print(f"[RESULT] Window validation MAPE ({scaling_method}): {val_mape:.2f}%")

        weights_path = f"rolling_error_analysis_results/cost_iteration_{iteration}_es_{scaling_method}.weights.h5"
        model.save_weights(weights_path)

        # Predict last sample
        X_test_last = X_samples[-1:]
        y_test_last = y_samples[-1:]
        y_pred_scaled = model.predict(X_test_last, verbose=0)
        y_pred_unscaled, y_test_unscaled = inverse_transform(y_pred_scaled.flatten(), y_test_last.flatten(), y_info)
        predictions.append(y_pred_unscaled[0])
        actuals.append(y_test_unscaled[0])
        pred_dates.append(sample_dates[-1])

        test_mape = mean_absolute_percentage_error(y_test_unscaled, y_pred_unscaled)*100
        print(f"[INFO] Predicted last sample of window ({scaling_method}): Actual={y_test_unscaled[0]:.2f}, Pred={y_pred_unscaled[0]:.2f}, MAPE={test_mape:.2f}%")

        iteration += 1

    df_results = pd.DataFrame({
        'Date': pred_dates,
        'Actual': actuals,
        'Predicted': predictions
    })
    df_results['Absolute_Error'] = np.abs(df_results['Actual'] - df_results['Predicted'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual'])
    df_results['MAPE'] = df_results['APE'] * 100.0

    df_results.to_csv(f"rolling_error_analysis_results/cost_rolling_results_es_{scaling_method}.csv", index=False)
    overall_mape = df_results['MAPE'].mean()
    print(f"\n[INFO] Rolling training with Early Stopping completed for COST using {scaling_method} scaling. Overall MAPE: {overall_mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] Total elapsed time: {elapsed:.2f}s")

    # Print worst 10 predictions
    worst_10 = df_results.sort_values('MAPE', ascending=False).head(10)
    print(f"[INFO] Top 10 worst predictions in rolling scenario (Early Stopping, {scaling_method}):")
    print(worst_10[['Date', 'Actual', 'Predicted', 'MAPE']])

if __name__ == "__main__":
    # Compare three scaling methods: 'robust', 'log', 'rolling_stats'
    for method in ['robust', 'log', 'rolling_stats']:
        rolling_training_early_stopping(ticker, window_size=200, step_size=10, n_steps=5, scaling_method=method)

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os
import math
import time

########################
# Configuration
########################
ticker = 'COST'
start_date = '2020-01-01'
end_date = '2024-01-01'

n_steps = 5
window_size = 200
step_size = 10
initial_epochs = 100
update_epochs = 100

initial_lr = 0.0005
update_lr = 0.0002

train_ratio = 0.9

if not os.path.exists("rolling_error_analysis_results"):
    os.makedirs("rolling_error_analysis_results")

def load_full_data_helper(ticker):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values

    if len(dates) < window_size:
        return None, None, None
    return X_feat.values, y_raw, dates

def load_full_data(ticker):
    X_feat, y_raw, dates = load_full_data_helper(ticker)
    if X_feat is None:
        return None, None, None
    return X_feat, y_raw, dates

def create_lstm_model(n_layers, n_units, learning_rate, input_shape):
    model = Sequential()
    model.add(LSTM(n_units, activation='relu', return_sequences=(n_layers > 1), input_shape=input_shape))
    if n_layers > 1:
        model.add(LSTM(n_units, activation='relu'))
    model.add(Dense(1))
    opt = Adam(learning_rate=learning_rate)
    model.compile(loss='mean_squared_error', optimizer=opt)
    return model

def extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None, None, None, None

    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]

    def lstm_split(dataX, dataY, n_steps):
        X, y = [], []
        for i in range(len(dataX)-n_steps+1):
            X.append(dataX[i:i+n_steps])
            y.append(dataY[i+n_steps-1])
        return np.array(X), np.array(y)

    X_samples, y_samples = lstm_split(X_window, y_window, n_steps)
    sample_dates = dates_window[n_steps-1:]

    feat_scaler = RobustScaler()
    target_scaler = RobustScaler()
    X_flat = X_window.reshape(len(X_window), -1)
    feat_scaler.fit(X_flat)
    y_window_reshaped = y_window.reshape(-1,1)
    target_scaler.fit(y_window_reshaped)
    X_scaled = feat_scaler.transform(X_flat).reshape(X_window.shape)
    y_scaled = target_scaler.transform(y_window_reshaped).flatten()
    X_samples_scaled, y_samples_scaled = lstm_split(X_scaled, y_scaled, n_steps)

    return X_samples_scaled, y_samples_scaled, sample_dates, feat_scaler, target_scaler, (X_window, y_window, dates_window)

def train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=None):
    total_samples = len(X_samples)
    train_count = int(math.floor(total_samples * train_ratio))
    if train_count >= total_samples:
        train_count = total_samples - 1

    X_train, y_train = X_samples[:train_count], y_samples[:train_count]
    X_val, y_val = X_samples[train_count:], y_samples[train_count:]

    if initial_training:
        epochs = initial_epochs
        lr = initial_lr
    else:
        epochs = update_epochs
        lr = update_lr

    input_shape = (X_train.shape[1], X_train.shape[2])
    model = create_lstm_model(1, 16, lr, input_shape)

    if prev_weights is not None:
        model.load_weights(prev_weights)

    # EarlyStopping callback
    es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=epochs, batch_size=4, verbose=0, shuffle=False,
              validation_data=(X_val, y_val), callbacks=[es])

    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_unscaled = target_scaler.inverse_transform(y_val.reshape(-1,1)).flatten()
    y_val_pred_unscaled = target_scaler.inverse_transform(y_val_pred_scaled).flatten()
    val_mape = mean_absolute_percentage_error(y_val_unscaled, y_val_pred_unscaled) * 100

    return model, val_mape

def rolling_training_early_stopping(ticker, window_size=200, step_size=10, n_steps=5):
    X_full, y_full, dates_full = load_full_data(ticker)
    if X_full is None:
        print("[WARN] Not enough data.")
        return

    start_time = time.time()

    start_idx = 0
    window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
    if window_data[0] is None:
        print("[WARN] Initial window not valid.")
        return
    X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

    print("[INFO] Training initial window with Early Stopping...")
    model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=True, prev_weights=None)
    print(f"[RESULT] Initial window validation MAPE: {val_mape:.2f}%")

    weights_path = "rolling_error_analysis_results/cost_initial_es.weights.h5"
    model.save_weights(weights_path)

    predictions = []
    actuals = []
    pred_dates = []

    iteration = 1
    while True:
        start_idx += step_size
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
        if window_data[0] is None:
            print("[INFO] No more windows can be extracted.")
            break
        X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

        print(f"\n[INFO] Iteration {iteration}: training on new window with Early Stopping...")
        model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=weights_path)
        print(f"[RESULT] Window validation MAPE: {val_mape:.2f}%")

        weights_path = f"rolling_error_analysis_results/cost_iteration_{iteration}_es.weights.h5"
        model.save_weights(weights_path)

        X_test_last = X_samples[-1:]
        y_test_last = y_samples[-1:]
        y_pred_scaled = model.predict(X_test_last, verbose=0)
        y_test_unscaled = target_scaler.inverse_transform(y_test_last.reshape(-1,1)).flatten()
        y_pred_unscaled = target_scaler.inverse_transform(y_pred_scaled).flatten()

        predictions.append(y_pred_unscaled[0])
        actuals.append(y_test_unscaled[0])
        pred_dates.append(sample_dates[-1])

        test_mape = mean_absolute_percentage_error(y_test_unscaled, y_pred_unscaled)*100
        print(f"[INFO] Predicted last sample of window: Actual={y_test_unscaled[0]:.2f}, Pred={y_pred_unscaled[0]:.2f}, MAPE={test_mape:.2f}%")

        iteration += 1

    df_results = pd.DataFrame({
        'Date': pred_dates,
        'Actual': actuals,
        'Predicted': predictions
    })
    df_results['Absolute_Error'] = np.abs(df_results['Actual'] - df_results['Predicted'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual'])
    df_results['MAPE'] = df_results['APE'] * 100.0

    df_results.to_csv("rolling_error_analysis_results/cost_rolling_results_es.csv", index=False)
    overall_mape = df_results['MAPE'].mean()
    print(f"\n[INFO] Rolling training with Early Stopping completed for COST. Overall MAPE: {overall_mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] Total elapsed time: {elapsed:.2f}s")

    worst_10 = df_results.sort_values('MAPE', ascending=False).head(10)
    print("[INFO] Top 10 worst predictions in rolling scenario (Early Stopping):")
    print(worst_10[['Date', 'Actual', 'Predicted', 'MAPE']])

if __name__ == "__main__":
    rolling_training_early_stopping(ticker, window_size=200, step_size=10, n_steps=5)

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os
import math
import time

########################
# Configuration
########################
ticker = 'COST'
start_date = '2020-01-01'
end_date = '2024-01-01'

n_steps = 10
window_size = 200
step_size = 10
initial_epochs = 100
update_epochs = 100

initial_lr = 0.0005
update_lr = 0.0002

train_ratio = 0.9

if not os.path.exists("rolling_error_analysis_results"):
    os.makedirs("rolling_error_analysis_results")

def load_full_data_helper(ticker):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values

    if len(dates) < window_size:
        return None, None, None
    return X_feat.values, y_raw, dates

def load_full_data(ticker):
    X_feat, y_raw, dates = load_full_data_helper(ticker)
    if X_feat is None:
        return None, None, None
    return X_feat, y_raw, dates

def create_lstm_model(n_layers, n_units, learning_rate, input_shape):
    model = Sequential()
    model.add(LSTM(n_units, activation='relu', return_sequences=(n_layers > 1), input_shape=input_shape))
    if n_layers > 1:
        model.add(LSTM(n_units, activation='relu'))
    model.add(Dense(1))
    opt = Adam(learning_rate=learning_rate)
    model.compile(loss='mean_squared_error', optimizer=opt)
    return model

def extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None, None, None, None

    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]

    def lstm_split(dataX, dataY, n_steps):
        X, y = [], []
        for i in range(len(dataX)-n_steps+1):
            X.append(dataX[i:i+n_steps])
            y.append(dataY[i+n_steps-1])
        return np.array(X), np.array(y)

    X_samples, y_samples = lstm_split(X_window, y_window, n_steps)
    sample_dates = dates_window[n_steps-1:]

    feat_scaler = RobustScaler()
    target_scaler = RobustScaler()
    X_flat = X_window.reshape(len(X_window), -1)
    feat_scaler.fit(X_flat)
    y_window_reshaped = y_window.reshape(-1,1)
    target_scaler.fit(y_window_reshaped)
    X_scaled = feat_scaler.transform(X_flat).reshape(X_window.shape)
    y_scaled = target_scaler.transform(y_window_reshaped).flatten()
    X_samples_scaled, y_samples_scaled = lstm_split(X_scaled, y_scaled, n_steps)

    return X_samples_scaled, y_samples_scaled, sample_dates, feat_scaler, target_scaler, (X_window, y_window, dates_window)

def train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=None):
    total_samples = len(X_samples)
    train_count = int(math.floor(total_samples * train_ratio))
    if train_count >= total_samples:
        train_count = total_samples - 1

    X_train, y_train = X_samples[:train_count], y_samples[:train_count]
    X_val, y_val = X_samples[train_count:], y_samples[train_count:]

    if initial_training:
        epochs = initial_epochs
        lr = initial_lr
    else:
        epochs = update_epochs
        lr = update_lr

    input_shape = (X_train.shape[1], X_train.shape[2])
    model = create_lstm_model(1, 16, lr, input_shape)

    if prev_weights is not None:
        model.load_weights(prev_weights)

    # EarlyStopping callback
    es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=epochs, batch_size=4, verbose=0, shuffle=False,
              validation_data=(X_val, y_val), callbacks=[es])

    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_unscaled = target_scaler.inverse_transform(y_val.reshape(-1,1)).flatten()
    y_val_pred_unscaled = target_scaler.inverse_transform(y_val_pred_scaled).flatten()
    val_mape = mean_absolute_percentage_error(y_val_unscaled, y_val_pred_unscaled) * 100

    return model, val_mape

def rolling_training_early_stopping(ticker, window_size=200, step_size=10, n_steps=10):
    X_full, y_full, dates_full = load_full_data(ticker)
    if X_full is None:
        print("[WARN] Not enough data.")
        return

    start_time = time.time()

    start_idx = 0
    window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
    if window_data[0] is None:
        print("[WARN] Initial window not valid.")
        return
    X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

    print("[INFO] Training initial window with Early Stopping...")
    model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=True, prev_weights=None)
    print(f"[RESULT] Initial window validation MAPE: {val_mape:.2f}%")

    weights_path = "rolling_error_analysis_results/cost_initial_es.weights.h5"
    model.save_weights(weights_path)

    predictions = []
    actuals = []
    pred_dates = []

    iteration = 1
    while True:
        start_idx += step_size
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
        if window_data[0] is None:
            print("[INFO] No more windows can be extracted.")
            break
        X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

        print(f"\n[INFO] Iteration {iteration}: training on new window with Early Stopping...")
        model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=weights_path)
        print(f"[RESULT] Window validation MAPE: {val_mape:.2f}%")

        weights_path = f"rolling_error_analysis_results/cost_iteration_{iteration}_es.weights.h5"
        model.save_weights(weights_path)

        X_test_last = X_samples[-1:]
        y_test_last = y_samples[-1:]
        y_pred_scaled = model.predict(X_test_last, verbose=0)
        y_test_unscaled = target_scaler.inverse_transform(y_test_last.reshape(-1,1)).flatten()
        y_pred_unscaled = target_scaler.inverse_transform(y_pred_scaled).flatten()

        predictions.append(y_pred_unscaled[0])
        actuals.append(y_test_unscaled[0])
        pred_dates.append(sample_dates[-1])

        test_mape = mean_absolute_percentage_error(y_test_unscaled, y_pred_unscaled)*100
        print(f"[INFO] Predicted last sample of window: Actual={y_test_unscaled[0]:.2f}, Pred={y_pred_unscaled[0]:.2f}, MAPE={test_mape:.2f}%")

        iteration += 1

    df_results = pd.DataFrame({
        'Date': pred_dates,
        'Actual': actuals,
        'Predicted': predictions
    })
    df_results['Absolute_Error'] = np.abs(df_results['Actual'] - df_results['Predicted'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual'])
    df_results['MAPE'] = df_results['APE'] * 100.0

    df_results.to_csv("rolling_error_analysis_results/cost_rolling_results_es.csv", index=False)
    overall_mape = df_results['MAPE'].mean()
    print(f"\n[INFO] Rolling training with Early Stopping completed for COST. Overall MAPE: {overall_mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] Total elapsed time: {elapsed:.2f}s")

    worst_10 = df_results.sort_values('MAPE', ascending=False).head(10)
    print("[INFO] Top 10 worst predictions in rolling scenario (Early Stopping):")
    print(worst_10[['Date', 'Actual', 'Predicted', 'MAPE']])

if __name__ == "__main__":
    rolling_training_early_stopping(ticker, window_size=200, step_size=10, n_steps=5)

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import talib
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os
import math
import time

########################
# Configuration
########################
ticker = 'COST'
start_date = '2020-01-01'
end_date = '2024-01-01'

# Hyperparameters
n_steps = 10
window_size = 200
step_size = 10
initial_epochs = 100
update_epochs = 100
initial_lr = 0.0002
update_lr = 0.0002
train_ratio = 0.9
n_units = 32
batch_size = 8

# If you change features or other logic, do so below
if not os.path.exists("rolling_error_analysis_results"):
    os.makedirs("rolling_error_analysis_results")


def load_full_data_helper(ticker, start_date, end_date, window_size):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None

    # Next day prediction setup
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    # Simple features
    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values

    if len(dates) < window_size:
        return None, None, None
    return X_feat.values, y_raw, dates


def load_full_data(ticker, start_date, end_date, window_size):
    X_feat, y_raw, dates = load_full_data_helper(ticker, start_date, end_date, window_size)
    if X_feat is None:
        return None, None, None
    return X_feat, y_raw, dates


def extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None, None, None, None

    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]

    def lstm_split(dataX, dataY, n_steps):
        X, y = [], []
        for i in range(len(dataX)-n_steps+1):
            X.append(dataX[i:i+n_steps])
            y.append(dataY[i+n_steps-1])
        return np.array(X), np.array(y)

    X_samples, y_samples = lstm_split(X_window, y_window, n_steps)
    sample_dates = dates_window[n_steps-1:]

    feat_scaler = RobustScaler()
    target_scaler = RobustScaler()
    X_flat = X_window.reshape(len(X_window), -1)
    feat_scaler.fit(X_flat)
    y_window_reshaped = y_window.reshape(-1,1)
    target_scaler.fit(y_window_reshaped)

    X_scaled = feat_scaler.transform(X_flat).reshape(X_window.shape)
    y_scaled = target_scaler.transform(y_window_reshaped).flatten()
    X_samples_scaled, y_samples_scaled = lstm_split(X_scaled, y_scaled, n_steps)

    return X_samples_scaled, y_samples_scaled, sample_dates, feat_scaler, target_scaler, (X_window, y_window, dates_window)


def create_lstm_model(n_units, learning_rate, n_steps, n_features, n_layers=1):
    inputs = Input(shape=(n_steps, n_features))
    x = LSTM(n_units, activation='relu', return_sequences=(n_layers > 1))(inputs)
    if n_layers > 1:
        x = LSTM(n_units, activation='relu')(x)
    outputs = Dense(1)(x)
    model = Model(inputs, outputs)
    # We'll compile after loading weights if needed
    return model


def train_on_window(X_samples, y_samples, feat_scaler, target_scaler,
                    initial_training=False, prev_weights=None):
    total_samples = len(X_samples)
    global train_ratio
    train_count = int(math.floor(total_samples * train_ratio))
    if train_count >= total_samples:
        train_count = total_samples - 1

    X_train, y_train = X_samples[:train_count], y_samples[:train_count]
    X_val, y_val = X_samples[train_count:], y_samples[train_count:]

    if X_train.size == 0 or X_val.size == 0:
        return None, np.nan

    n_steps_local = X_train.shape[1]
    n_features = X_train.shape[2]

    if initial_training:
        epochs = initial_epochs
        lr = initial_lr
    else:
        epochs = update_epochs
        lr = update_lr

    model = create_lstm_model(n_units, lr, n_steps_local, n_features, n_layers=1)

    if prev_weights is not None:
        model.load_weights(prev_weights)

    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=lr))

    es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0, shuffle=False,
              validation_data=(X_val, y_val), callbacks=[es])

    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_unscaled = target_scaler.inverse_transform(y_val.reshape(-1,1)).flatten()
    y_val_pred_unscaled = target_scaler.inverse_transform(y_val_pred_scaled).flatten()
    val_mape = mean_absolute_percentage_error(y_val_unscaled, y_val_pred_unscaled) * 100

    return model, val_mape


def rolling_training_early_stopping(ticker, window_size, step_size, n_steps):
    X_full, y_full, dates_full = load_full_data(ticker, start_date, end_date, window_size)
    if X_full is None:
        print("[WARN] Not enough data.")
        return

    start_time = time.time()

    start_idx = 0
    window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
    if window_data[0] is None:
        print("[WARN] Initial window not valid.")
        return
    X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

    print("[INFO] Training initial window with Early Stopping...")
    model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=True, prev_weights=None)
    print(f"[RESULT] Initial window validation MAPE: {val_mape:.2f}%")

    weights_path = "rolling_error_analysis_results/cost_initial_es.weights.h5"
    model.save_weights(weights_path)

    predictions = []
    actuals = []
    pred_dates = []

    iteration = 1
    while True:
        start_idx += step_size
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
        if window_data[0] is None:
            print("[INFO] No more windows can be extracted.")
            break
        X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

        print(f"\n[INFO] Iteration {iteration}: training on new window with Early Stopping...")
        model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=weights_path)
        print(f"[RESULT] Window validation MAPE: {val_mape:.2f}%")

        weights_path = f"rolling_error_analysis_results/cost_iteration_{iteration}_es.weights.h5"
        model.save_weights(weights_path)

        X_test_last = X_samples[-1:]
        y_test_last = y_samples[-1:]
        y_pred_scaled = model.predict(X_test_last, verbose=0)
        y_test_unscaled = target_scaler.inverse_transform(y_test_last.reshape(-1,1)).flatten()
        y_pred_unscaled = target_scaler.inverse_transform(y_pred_scaled).flatten()

        predictions.append(y_pred_unscaled[0])
        actuals.append(y_test_unscaled[0])
        pred_dates.append(sample_dates[-1])

        test_mape = mean_absolute_percentage_error(y_test_unscaled, y_pred_unscaled)*100
        print(f"[INFO] Predicted last sample of window: Actual={y_test_unscaled[0]:.2f}, Pred={y_pred_unscaled[0]:.2f}, MAPE={test_mape:.2f}%")

        iteration += 1

    df_results = pd.DataFrame({
        'Date': pred_dates,
        'Actual': actuals,
        'Predicted': predictions
    })
    df_results['Absolute_Error'] = np.abs(df_results['Actual'] - df_results['Predicted'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual'])
    df_results['MAPE'] = df_results['APE'] * 100.0

    df_results.to_csv("rolling_error_analysis_results/cost_rolling_results_es.csv", index=False)
    overall_mape = df_results['MAPE'].mean()
    print(f"\n[INFO] Rolling training with Early Stopping completed for {ticker}. Overall MAPE: {overall_mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] Total elapsed time: {elapsed:.2f}s")

    worst_10 = df_results.sort_values('MAPE', ascending=False).head(10)
    print("[INFO] Top 10 worst predictions in rolling scenario (Early Stopping):")
    print(worst_10[['Date', 'Actual', 'Predicted', 'MAPE']])

if __name__ == "__main__":
    # Just run with the current top-level defined parameters:
    rolling_training_early_stopping(ticker, window_size, step_size, n_steps)

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import talib
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os
import math
import time

########################
# Configuration
########################
ticker = 'COST'
start_date = '2020-01-01'
end_date = '2024-01-01'

# Hyperparameters
n_steps = 5
window_size = 200
step_size = 10
initial_epochs = 100
update_epochs = 100
initial_lr = 0.0005
update_lr = 0.0002
train_ratio = 0.9
n_units = 16
batch_size = 4

# If you change features or other logic, do so below
if not os.path.exists("rolling_error_analysis_results"):
    os.makedirs("rolling_error_analysis_results")


def load_full_data_helper(ticker, start_date, end_date, window_size):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None

    # Next day prediction setup
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    # Simple features
    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values

    if len(dates) < window_size:
        return None, None, None
    return X_feat.values, y_raw, dates


def load_full_data(ticker, start_date, end_date, window_size):
    X_feat, y_raw, dates = load_full_data_helper(ticker, start_date, end_date, window_size)
    if X_feat is None:
        return None, None, None
    return X_feat, y_raw, dates


def extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None, None, None, None

    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]

    def lstm_split(dataX, dataY, n_steps):
        X, y = [], []
        for i in range(len(dataX)-n_steps+1):
            X.append(dataX[i:i+n_steps])
            y.append(dataY[i+n_steps-1])
        return np.array(X), np.array(y)

    X_samples, y_samples = lstm_split(X_window, y_window, n_steps)
    sample_dates = dates_window[n_steps-1:]

    feat_scaler = RobustScaler()
    target_scaler = RobustScaler()
    X_flat = X_window.reshape(len(X_window), -1)
    feat_scaler.fit(X_flat)
    y_window_reshaped = y_window.reshape(-1,1)
    target_scaler.fit(y_window_reshaped)

    X_scaled = feat_scaler.transform(X_flat).reshape(X_window.shape)
    y_scaled = target_scaler.transform(y_window_reshaped).flatten()
    X_samples_scaled, y_samples_scaled = lstm_split(X_scaled, y_scaled, n_steps)

    return X_samples_scaled, y_samples_scaled, sample_dates, feat_scaler, target_scaler, (X_window, y_window, dates_window)


def create_lstm_model(n_units, learning_rate, n_steps, n_features, n_layers=1):
    inputs = Input(shape=(n_steps, n_features))
    x = LSTM(n_units, activation='relu', return_sequences=(n_layers > 1))(inputs)
    if n_layers > 1:
        x = LSTM(n_units, activation='relu')(x)
    outputs = Dense(1)(x)
    model = Model(inputs, outputs)
    # We'll compile after loading weights if needed
    return model


def train_on_window(X_samples, y_samples, feat_scaler, target_scaler,
                    initial_training=False, prev_weights=None):
    total_samples = len(X_samples)
    global train_ratio
    train_count = int(math.floor(total_samples * train_ratio))
    if train_count >= total_samples:
        train_count = total_samples - 1

    X_train, y_train = X_samples[:train_count], y_samples[:train_count]
    X_val, y_val = X_samples[train_count:], y_samples[train_count:]

    if X_train.size == 0 or X_val.size == 0:
        return None, np.nan

    n_steps_local = X_train.shape[1]
    n_features = X_train.shape[2]

    if initial_training:
        epochs = initial_epochs
        lr = initial_lr
    else:
        epochs = update_epochs
        lr = update_lr

    model = create_lstm_model(n_units, lr, n_steps_local, n_features, n_layers=1)

    if prev_weights is not None:
        model.load_weights(prev_weights)

    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=lr))

    es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0, shuffle=False,
              validation_data=(X_val, y_val), callbacks=[es])

    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_unscaled = target_scaler.inverse_transform(y_val.reshape(-1,1)).flatten()
    y_val_pred_unscaled = target_scaler.inverse_transform(y_val_pred_scaled).flatten()
    val_mape = mean_absolute_percentage_error(y_val_unscaled, y_val_pred_unscaled) * 100

    return model, val_mape


def rolling_training_early_stopping(ticker, window_size, step_size, n_steps):
    X_full, y_full, dates_full = load_full_data(ticker, start_date, end_date, window_size)
    if X_full is None:
        print("[WARN] Not enough data.")
        return

    start_time = time.time()

    start_idx = 0
    window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
    if window_data[0] is None:
        print("[WARN] Initial window not valid.")
        return
    X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

    print("[INFO] Training initial window with Early Stopping...")
    model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=True, prev_weights=None)
    print(f"[RESULT] Initial window validation MAPE: {val_mape:.2f}%")

    weights_path = "rolling_error_analysis_results/cost_initial_es.weights.h5"
    model.save_weights(weights_path)

    predictions = []
    actuals = []
    pred_dates = []

    iteration = 1
    while True:
        start_idx += step_size
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
        if window_data[0] is None:
            print("[INFO] No more windows can be extracted.")
            break
        X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

        print(f"\n[INFO] Iteration {iteration}: training on new window with Early Stopping...")
        model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=weights_path)
        print(f"[RESULT] Window validation MAPE: {val_mape:.2f}%")

        weights_path = f"rolling_error_analysis_results/cost_iteration_{iteration}_es.weights.h5"
        model.save_weights(weights_path)

        X_test_last = X_samples[-1:]
        y_test_last = y_samples[-1:]
        y_pred_scaled = model.predict(X_test_last, verbose=0)
        y_test_unscaled = target_scaler.inverse_transform(y_test_last.reshape(-1,1)).flatten()
        y_pred_unscaled = target_scaler.inverse_transform(y_pred_scaled).flatten()

        predictions.append(y_pred_unscaled[0])
        actuals.append(y_test_unscaled[0])
        pred_dates.append(sample_dates[-1])

        test_mape = mean_absolute_percentage_error(y_test_unscaled, y_pred_unscaled)*100
        print(f"[INFO] Predicted last sample of window: Actual={y_test_unscaled[0]:.2f}, Pred={y_pred_unscaled[0]:.2f}, MAPE={test_mape:.2f}%")

        iteration += 1

    df_results = pd.DataFrame({
        'Date': pred_dates,
        'Actual': actuals,
        'Predicted': predictions
    })
    df_results['Absolute_Error'] = np.abs(df_results['Actual'] - df_results['Predicted'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual'])
    df_results['MAPE'] = df_results['APE'] * 100.0

    df_results.to_csv("rolling_error_analysis_results/cost_rolling_results_es.csv", index=False)
    overall_mape = df_results['MAPE'].mean()
    print(f"\n[INFO] Rolling training with Early Stopping completed for {ticker}. Overall MAPE: {overall_mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] Total elapsed time: {elapsed:.2f}s")

    worst_10 = df_results.sort_values('MAPE', ascending=False).head(10)
    print("[INFO] Top 10 worst predictions in rolling scenario (Early Stopping):")
    print(worst_10[['Date', 'Actual', 'Predicted', 'MAPE']])

if __name__ == "__main__":
    # Just run with the current top-level defined parameters:
    rolling_training_early_stopping(ticker, window_size, step_size, n_steps)

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import talib
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os
import math
import time

########################
# Configuration
########################

stocks = [
    'COST', 'UL', 'AMGN', 'UNH', 'WAT', 'UPS', 'LPX', 'WM', 'NVDA',
    'GOOGL', 'MSFT', 'AXP', 'BLK', 'BRK-B', 'NEE', 'XOM', 'CNI'
]

start_date = '2020-01-01'
end_date = '2024-01-01'

# Hyperparameters
n_steps = 5
window_size = 200
step_size = 10
initial_epochs = 100
update_epochs = 100
initial_lr = 0.0005
update_lr = 0.0002
train_ratio = 0.9
n_units = 16
batch_size = 4

if not os.path.exists("rolling_error_analysis_results"):
    os.makedirs("rolling_error_analysis_results")

def load_full_data_helper(ticker, start_date, end_date, window_size):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None

    # Next day prediction setup
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values

    if len(dates) < window_size:
        return None, None, None
    return X_feat.values, y_raw, dates

def load_full_data(ticker, start_date, end_date, window_size):
    X_feat, y_raw, dates = load_full_data_helper(ticker, start_date, end_date, window_size)
    if X_feat is None:
        return None, None, None
    return X_feat, y_raw, dates

def extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None, None, None, None

    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]

    def lstm_split(dataX, dataY, n_steps):
        X, y = [], []
        for i in range(len(dataX)-n_steps+1):
            X.append(dataX[i:i+n_steps])
            y.append(dataY[i+n_steps-1])
        return np.array(X), np.array(y)

    X_samples, y_samples = lstm_split(X_window, y_window, n_steps)
    sample_dates = dates_window[n_steps-1:]

    feat_scaler = RobustScaler()
    target_scaler = RobustScaler()
    X_flat = X_window.reshape(len(X_window), -1)
    feat_scaler.fit(X_flat)
    y_window_reshaped = y_window.reshape(-1,1)
    target_scaler.fit(y_window_reshaped)

    X_scaled = feat_scaler.transform(X_flat).reshape(X_window.shape)
    y_scaled = target_scaler.transform(y_window_reshaped).flatten()
    X_samples_scaled, y_samples_scaled = lstm_split(X_scaled, y_scaled, n_steps)

    return X_samples_scaled, y_samples_scaled, sample_dates, feat_scaler, target_scaler, (X_window, y_window, dates_window)

def create_lstm_model(n_units, learning_rate, n_steps, n_features, n_layers=1):
    inputs = Input(shape=(n_steps, n_features))
    x = LSTM(n_units, activation='relu', return_sequences=(n_layers > 1))(inputs)
    if n_layers > 1:
        x = LSTM(n_units, activation='relu')(x)
    outputs = Dense(1)(x)
    model = Model(inputs, outputs)
    return model

def train_on_window(X_samples, y_samples, feat_scaler, target_scaler,
                    initial_training=False, prev_weights=None):
    total_samples = len(X_samples)
    global train_ratio
    train_count = int(math.floor(total_samples * train_ratio))
    if train_count >= total_samples:
        train_count = total_samples - 1

    X_train, y_train = X_samples[:train_count], y_samples[:train_count]
    X_val, y_val = X_samples[train_count:], y_samples[train_count:]

    if X_train.size == 0 or X_val.size == 0:
        return None, np.nan

    n_steps_local = X_train.shape[1]
    n_features = X_train.shape[2]

    if initial_training:
        epochs = initial_epochs
        lr = initial_lr
    else:
        epochs = update_epochs
        lr = update_lr

    model = create_lstm_model(n_units, lr, n_steps_local, n_features, n_layers=1)

    if prev_weights is not None:
        model.load_weights(prev_weights)

    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=lr))

    es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0, shuffle=False,
              validation_data=(X_val, y_val), callbacks=[es])

    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_unscaled = target_scaler.inverse_transform(y_val.reshape(-1,1)).flatten()
    y_val_pred_unscaled = target_scaler.inverse_transform(y_val_pred_scaled).flatten()
    val_mape = mean_absolute_percentage_error(y_val_unscaled, y_val_pred_unscaled) * 100

    return model, val_mape

def rolling_training_early_stopping(ticker, window_size, step_size, n_steps):
    X_full, y_full, dates_full = load_full_data(ticker, start_date, end_date, window_size)
    if X_full is None:
        print(f"[WARN] Not enough data for {ticker}.")
        return None

    start_time = time.time()

    start_idx = 0
    window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
    if window_data[0] is None:
        print(f"[WARN] Initial window not valid for {ticker}.")
        return None
    X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

    print(f"[INFO] Training initial window with Early Stopping for {ticker}...")
    model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=True, prev_weights=None)
    print(f"[RESULT] {ticker}: Initial window validation MAPE: {val_mape:.2f}%")

    weights_path = f"rolling_error_analysis_results/{ticker}_initial_es.weights.h5"
    model.save_weights(weights_path)

    predictions = []
    actuals = []
    pred_dates = []

    iteration = 1
    while True:
        start_idx += step_size
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
        if window_data[0] is None:
            print(f"[INFO] No more windows can be extracted for {ticker}.")
            break
        X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

        print(f"\n[INFO] Iteration {iteration}: {ticker}, training on new window with Early Stopping...")
        model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=weights_path)
        print(f"[RESULT] {ticker}: Window validation MAPE: {val_mape:.2f}%")

        weights_path = f"rolling_error_analysis_results/{ticker}_iteration_{iteration}_es.weights.h5"
        model.save_weights(weights_path)

        X_test_last = X_samples[-1:]
        y_test_last = y_samples[-1:]
        y_pred_scaled = model.predict(X_test_last, verbose=0)
        y_test_unscaled = target_scaler.inverse_transform(y_test_last.reshape(-1,1)).flatten()
        y_pred_unscaled = target_scaler.inverse_transform(y_pred_scaled).flatten()

        predictions.append(y_pred_unscaled[0])
        actuals.append(y_test_unscaled[0])
        pred_dates.append(sample_dates[-1])

        test_mape = mean_absolute_percentage_error(y_test_unscaled, y_pred_unscaled)*100
        print(f"[INFO] {ticker}: Predicted last sample of window: Actual={y_test_unscaled[0]:.2f}, Pred={y_pred_unscaled[0]:.2f}, MAPE={test_mape:.2f}%")

        iteration += 1

    df_results = pd.DataFrame({
        'Date': pred_dates,
        'Actual': actuals,
        'Predicted': predictions
    })
    df_results['Absolute_Error'] = np.abs(df_results['Actual'] - df_results['Predicted'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual'])
    df_results['MAPE'] = df_results['APE'] * 100.0

    df_results.to_csv(f"rolling_error_analysis_results/{ticker}_rolling_results_es.csv", index=False)
    overall_mape = df_results['MAPE'].mean()
    print(f"\n[INFO] Rolling training with Early Stopping completed for {ticker}. Overall MAPE: {overall_mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] {ticker}: Total elapsed time: {elapsed:.2f}s")

    # Return the overall MAPE so we can store it in a CSV by stock
    return overall_mape

if __name__ == "__main__":
    # Run the code for each stock and save their MAPEs to a CSV
    stock_list = [
        'COST', 'UL', 'AMGN', 'UNH', 'WAT', 'UPS', 'LPX', 'WM', 'NVDA',
        'GOOGL', 'MSFT', 'AXP', 'BLK', 'BRK-B', 'NEE', 'XOM', 'CNI'
    ]

    results = []
    for s in stock_list:
        mape = rolling_training_early_stopping(s, window_size, step_size, n_steps)
        if mape is not None:
            results.append({'Stock': s, 'Overall_MAPE': mape})
        else:
            results.append({'Stock': s, 'Overall_MAPE': np.nan})

    results_df = pd.DataFrame(results)
    results_df.to_csv('stock_mapes.csv', index=False)
    print("[INFO] All stock MAPEs saved to stock_mapes.csv")

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.metrics import mean_absolute_percentage_error
import os
import math
import time

stocks = [
    'COST', 'UL', 'AMGN', 'UNH', 'WAT', 'UPS', 'LPX', 'WM', 'NVDA',
    'GOOGL', 'MSFT', 'AXP', 'BLK', 'BRK-B', 'NEE', 'XOM', 'CNI'
]

start_date = '2020-01-01'
end_date = '2024-01-01'

n_steps = 5
window_size = 200
step_size = 10

if not os.path.exists("baseline_sma_results"):
    os.makedirs("baseline_sma_results")

def load_data(ticker, start_date, end_date):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)
    X = stock_data['Close'].values
    y = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values
    return X, y, dates

def extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None, None
    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]

    def lstm_split(dataX, dataY, n_steps):
        X, y = [], []
        for i in range(len(dataX)-n_steps+1):
            X.append(dataX[i:i+n_steps])
            y.append(dataY[i+n_steps-1])
        return np.array(X), np.array(y)

    X_samples, y_samples = lstm_split(X_window, y_window, n_steps)
    sample_dates = dates_window[n_steps-1:]
    if X_samples.size == 0:
        return None, None, None, None
    return X_samples, y_samples, sample_dates, (X_window, y_window, dates_window)

def baseline_sma_prediction(X_samples, n_steps):
    predictions = []
    for i in range(len(X_samples)):
        pred = np.mean(X_samples[i])
        predictions.append(pred)
    return np.array(predictions)

def rolling_baseline_sma(ticker, window_size, step_size, n_steps):
    X_full, y_full, dates_full = load_data(ticker, start_date, end_date)
    if X_full is None:
        print(f"[WARN] Not enough data for {ticker}.")
        return None

    start_time = time.time()

    start_idx = 0
    window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
    if window_data[0] is None:
        print(f"[WARN] Initial window not valid for {ticker}.")
        return None
    X_samples, y_samples, sample_dates, _ = window_data
    predictions = baseline_sma_prediction(X_samples, n_steps)

    all_predictions = list(predictions)
    all_actuals = list(y_samples)
    all_dates = list(sample_dates)

    iteration = 1
    while True:
        start_idx += step_size
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
        if window_data[0] is None:
            print(f"[INFO] No more windows for {ticker}.")
            break
        X_samples, y_samples, sample_dates, _ = window_data
        predictions = baseline_sma_prediction(X_samples, n_steps)
        all_predictions.extend(predictions)
        all_actuals.extend(y_samples)
        all_dates.extend(sample_dates)
        iteration += 1

    all_predictions = np.array(all_predictions)
    all_actuals = np.array(all_actuals)
    mape = mean_absolute_percentage_error(all_actuals, all_predictions)*100.0

    df_results = pd.DataFrame({
        'Date': all_dates,
        'Actual': all_actuals,
        'Predicted': all_predictions
    })
    df_results['Absolute_Error'] = np.abs(df_results['Actual'] - df_results['Predicted'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual'])
    df_results['MAPE'] = df_results['APE'] * 100.0
    df_results.to_csv(f"baseline_sma_results/{ticker}_rolling_baseline_sma_results.csv", index=False)

    print(f"[INFO] Baseline SMA {ticker}: Overall MAPE: {mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] {ticker}: Elapsed time: {elapsed:.2f}s")
    return mape

if __name__ == "__main__":
    results = []
    for s in stocks:
        mape = rolling_baseline_sma(s, window_size, step_size, n_steps)
        if mape is not None:
            results.append({'Stock': s, 'Overall_MAPE': mape})
        else:
            results.append({'Stock': s, 'Overall_MAPE': np.nan})

    results_df = pd.DataFrame(results)
    results_df.to_csv('stock_mapes_sma_baseline.csv', index=False)
    print("[INFO] All SMA baseline MAPEs saved to stock_mapes_sma_baseline.csv")

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import talib
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os
import math
import time

########################
# Configuration
########################
ticker = 'NVDA'
start_date = '2020-01-01'
end_date = '2024-01-01'
1
# Hyperparameters
n_steps = 5
window_size = 200
step_size = 10
initial_epochs = 100
update_epochs = 100
initial_lr = 0.0005
update_lr = 0.0002
train_ratio = 0.9
n_units = 16
batch_size = 4

# If you change features or other logic, do so below
if not os.path.exists("rolling_error_analysis_results"):
    os.makedirs("rolling_error_analysis_results")


def load_full_data_helper(ticker, start_date, end_date, window_size):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None

    # Next day prediction setup
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    # Simple features
    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values

    if len(dates) < window_size:
        return None, None, None
    return X_feat.values, y_raw, dates


def load_full_data(ticker, start_date, end_date, window_size):
    X_feat, y_raw, dates = load_full_data_helper(ticker, start_date, end_date, window_size)
    if X_feat is None:
        return None, None, None
    return X_feat, y_raw, dates


def extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None, None, None, None

    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]

    def lstm_split(dataX, dataY, n_steps):
        X, y = [], []
        for i in range(len(dataX)-n_steps+1):
            X.append(dataX[i:i+n_steps])
            y.append(dataY[i+n_steps-1])
        return np.array(X), np.array(y)

    X_samples, y_samples = lstm_split(X_window, y_window, n_steps)
    sample_dates = dates_window[n_steps-1:]

    feat_scaler = RobustScaler()
    target_scaler = RobustScaler()
    X_flat = X_window.reshape(len(X_window), -1)
    feat_scaler.fit(X_flat)
    y_window_reshaped = y_window.reshape(-1,1)
    target_scaler.fit(y_window_reshaped)

    X_scaled = feat_scaler.transform(X_flat).reshape(X_window.shape)
    y_scaled = target_scaler.transform(y_window_reshaped).flatten()
    X_samples_scaled, y_samples_scaled = lstm_split(X_scaled, y_scaled, n_steps)

    return X_samples_scaled, y_samples_scaled, sample_dates, feat_scaler, target_scaler, (X_window, y_window, dates_window)


def create_lstm_model(n_units, learning_rate, n_steps, n_features, n_layers=1):
    inputs = Input(shape=(n_steps, n_features))
    x = LSTM(n_units, activation='relu', return_sequences=(n_layers > 1))(inputs)
    if n_layers > 1:
        x = LSTM(n_units, activation='relu')(x)
    outputs = Dense(1)(x)
    model = Model(inputs, outputs)
    # We'll compile after loading weights if needed
    return model


def train_on_window(X_samples, y_samples, feat_scaler, target_scaler,
                    initial_training=False, prev_weights=None):
    total_samples = len(X_samples)
    global train_ratio
    train_count = int(math.floor(total_samples * train_ratio))
    if train_count >= total_samples:
        train_count = total_samples - 1

    X_train, y_train = X_samples[:train_count], y_samples[:train_count]
    X_val, y_val = X_samples[train_count:], y_samples[train_count:]

    if X_train.size == 0 or X_val.size == 0:
        return None, np.nan

    n_steps_local = X_train.shape[1]
    n_features = X_train.shape[2]

    if initial_training:
        epochs = initial_epochs
        lr = initial_lr
    else:
        epochs = update_epochs
        lr = update_lr

    model = create_lstm_model(n_units, lr, n_steps_local, n_features, n_layers=1)

    if prev_weights is not None:
        model.load_weights(prev_weights)

    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=lr))

    es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0, shuffle=False,
              validation_data=(X_val, y_val), callbacks=[es])

    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_unscaled = target_scaler.inverse_transform(y_val.reshape(-1,1)).flatten()
    y_val_pred_unscaled = target_scaler.inverse_transform(y_val_pred_scaled).flatten()
    val_mape = mean_absolute_percentage_error(y_val_unscaled, y_val_pred_unscaled) * 100

    return model, val_mape


def rolling_training_early_stopping(ticker, window_size, step_size, n_steps):
    X_full, y_full, dates_full = load_full_data(ticker, start_date, end_date, window_size)
    if X_full is None:
        print("[WARN] Not enough data.")
        return

    start_time = time.time()

    start_idx = 0
    window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
    if window_data[0] is None:
        print("[WARN] Initial window not valid.")
        return
    X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

    print("[INFO] Training initial window with Early Stopping...")
    model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=True, prev_weights=None)
    print(f"[RESULT] Initial window validation MAPE: {val_mape:.2f}%")

    weights_path = "rolling_error_analysis_results/cost_initial_es.weights.h5"
    model.save_weights(weights_path)

    predictions = []
    actuals = []
    pred_dates = []

    iteration = 1
    while True:
        start_idx += step_size
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
        if window_data[0] is None:
            print("[INFO] No more windows can be extracted.")
            break
        X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

        print(f"\n[INFO] Iteration {iteration}: training on new window with Early Stopping...")
        model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=weights_path)
        print(f"[RESULT] Window validation MAPE: {val_mape:.2f}%")

        weights_path = f"rolling_error_analysis_results/cost_iteration_{iteration}_es.weights.h5"
        model.save_weights(weights_path)

        X_test_last = X_samples[-1:]
        y_test_last = y_samples[-1:]
        y_pred_scaled = model.predict(X_test_last, verbose=0)
        y_test_unscaled = target_scaler.inverse_transform(y_test_last.reshape(-1,1)).flatten()
        y_pred_unscaled = target_scaler.inverse_transform(y_pred_scaled).flatten()

        predictions.append(y_pred_unscaled[0])
        actuals.append(y_test_unscaled[0])
        pred_dates.append(sample_dates[-1])

        test_mape = mean_absolute_percentage_error(y_test_unscaled, y_pred_unscaled)*100
        print(f"[INFO] Predicted last sample of window: Actual={y_test_unscaled[0]:.2f}, Pred={y_pred_unscaled[0]:.2f}, MAPE={test_mape:.2f}%")

        iteration += 1

    df_results = pd.DataFrame({
        'Date': pred_dates,
        'Actual': actuals,
        'Predicted': predictions
    })
    df_results['Absolute_Error'] = np.abs(df_results['Actual'] - df_results['Predicted'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual'])
    df_results['MAPE'] = df_results['APE'] * 100.0

    df_results.to_csv("rolling_error_analysis_results/cost_rolling_results_es.csv", index=False)
    overall_mape = df_results['MAPE'].mean()
    print(f"\n[INFO] Rolling training with Early Stopping completed for {ticker}. Overall MAPE: {overall_mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] Total elapsed time: {elapsed:.2f}s")

    worst_10 = df_results.sort_values('MAPE', ascending=False).head(10)
    print("[INFO] Top 10 worst predictions in rolling scenario (Early Stopping):")
    print(worst_10[['Date', 'Actual', 'Predicted', 'MAPE']])

if __name__ == "__main__":
    # Just run with the current top-level defined parameters:
    rolling_training_early_stopping(ticker, window_size, step_size, n_steps)

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import talib
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os
import math
import time

########################
# Configuration
########################
ticker = 'NVDA'
start_date = '2020-01-01'
end_date = '2024-01-01'
1
# Hyperparameters
n_steps = 2
window_size = 5
step_size = 2
initial_epochs = 100
update_epochs = 100
initial_lr = 0.0005
update_lr = 0.00005
train_ratio = 0.9
n_units = 16
batch_size = 4

# If you change features or other logic, do so below
if not os.path.exists("rolling_error_analysis_results"):
    os.makedirs("rolling_error_analysis_results")


def load_full_data_helper(ticker, start_date, end_date, window_size):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None

    # Next day prediction setup
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    # Simple features
    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values

    if len(dates) < window_size:
        return None, None, None
    return X_feat.values, y_raw, dates


def load_full_data(ticker, start_date, end_date, window_size):
    X_feat, y_raw, dates = load_full_data_helper(ticker, start_date, end_date, window_size)
    if X_feat is None:
        return None, None, None
    return X_feat, y_raw, dates


def extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None, None, None, None

    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]

    def lstm_split(dataX, dataY, n_steps):
        X, y = [], []
        for i in range(len(dataX)-n_steps+1):
            X.append(dataX[i:i+n_steps])
            y.append(dataY[i+n_steps-1])
        return np.array(X), np.array(y)

    X_samples, y_samples = lstm_split(X_window, y_window, n_steps)
    sample_dates = dates_window[n_steps-1:]

    feat_scaler = RobustScaler()
    target_scaler = RobustScaler()
    X_flat = X_window.reshape(len(X_window), -1)
    feat_scaler.fit(X_flat)
    y_window_reshaped = y_window.reshape(-1,1)
    target_scaler.fit(y_window_reshaped)

    X_scaled = feat_scaler.transform(X_flat).reshape(X_window.shape)
    y_scaled = target_scaler.transform(y_window_reshaped).flatten()
    X_samples_scaled, y_samples_scaled = lstm_split(X_scaled, y_scaled, n_steps)

    return X_samples_scaled, y_samples_scaled, sample_dates, feat_scaler, target_scaler, (X_window, y_window, dates_window)


def create_lstm_model(n_units, learning_rate, n_steps, n_features, n_layers=1):
    inputs = Input(shape=(n_steps, n_features))
    x = LSTM(n_units, activation='relu', return_sequences=(n_layers > 1))(inputs)
    if n_layers > 1:
        x = LSTM(n_units, activation='relu')(x)
    outputs = Dense(1)(x)
    model = Model(inputs, outputs)
    # We'll compile after loading weights if needed
    return model


def train_on_window(X_samples, y_samples, feat_scaler, target_scaler,
                    initial_training=False, prev_weights=None):
    total_samples = len(X_samples)
    global train_ratio
    train_count = int(math.floor(total_samples * train_ratio))
    if train_count >= total_samples:
        train_count = total_samples - 1

    X_train, y_train = X_samples[:train_count], y_samples[:train_count]
    X_val, y_val = X_samples[train_count:], y_samples[train_count:]

    if X_train.size == 0 or X_val.size == 0:
        return None, np.nan

    n_steps_local = X_train.shape[1]
    n_features = X_train.shape[2]

    if initial_training:
        epochs = initial_epochs
        lr = initial_lr
    else:
        epochs = update_epochs
        lr = update_lr

    model = create_lstm_model(n_units, lr, n_steps_local, n_features, n_layers=1)

    if prev_weights is not None:
        model.load_weights(prev_weights)

    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=lr))

    es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0, shuffle=False,
              validation_data=(X_val, y_val), callbacks=[es])

    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_unscaled = target_scaler.inverse_transform(y_val.reshape(-1,1)).flatten()
    y_val_pred_unscaled = target_scaler.inverse_transform(y_val_pred_scaled).flatten()
    val_mape = mean_absolute_percentage_error(y_val_unscaled, y_val_pred_unscaled) * 100

    return model, val_mape


def rolling_training_early_stopping(ticker, window_size, step_size, n_steps):
    X_full, y_full, dates_full = load_full_data(ticker, start_date, end_date, window_size)
    if X_full is None:
        print("[WARN] Not enough data.")
        return

    start_time = time.time()

    start_idx = 0
    window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
    if window_data[0] is None:
        print("[WARN] Initial window not valid.")
        return
    X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

    print("[INFO] Training initial window with Early Stopping...")
    model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=True, prev_weights=None)
    print(f"[RESULT] Initial window validation MAPE: {val_mape:.2f}%")

    weights_path = "rolling_error_analysis_results/cost_initial_es.weights.h5"
    model.save_weights(weights_path)

    predictions = []
    actuals = []
    pred_dates = []

    iteration = 1
    while True:
        start_idx += step_size
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
        if window_data[0] is None:
            print("[INFO] No more windows can be extracted.")
            break
        X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

        print(f"\n[INFO] Iteration {iteration}: training on new window with Early Stopping...")
        model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=weights_path)
        print(f"[RESULT] Window validation MAPE: {val_mape:.2f}%")

        weights_path = f"rolling_error_analysis_results/cost_iteration_{iteration}_es.weights.h5"
        model.save_weights(weights_path)

        X_test_last = X_samples[-1:]
        y_test_last = y_samples[-1:]
        y_pred_scaled = model.predict(X_test_last, verbose=0)
        y_test_unscaled = target_scaler.inverse_transform(y_test_last.reshape(-1,1)).flatten()
        y_pred_unscaled = target_scaler.inverse_transform(y_pred_scaled).flatten()

        predictions.append(y_pred_unscaled[0])
        actuals.append(y_test_unscaled[0])
        pred_dates.append(sample_dates[-1])

        test_mape = mean_absolute_percentage_error(y_test_unscaled, y_pred_unscaled)*100
        print(f"[INFO] Predicted last sample of window: Actual={y_test_unscaled[0]:.2f}, Pred={y_pred_unscaled[0]:.2f}, MAPE={test_mape:.2f}%")

        iteration += 1

    df_results = pd.DataFrame({
        'Date': pred_dates,
        'Actual': actuals,
        'Predicted': predictions
    })
    df_results['Absolute_Error'] = np.abs(df_results['Actual'] - df_results['Predicted'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual'])
    df_results['MAPE'] = df_results['APE'] * 100.0

    df_results.to_csv("rolling_error_analysis_results/cost_rolling_results_es.csv", index=False)
    overall_mape = df_results['MAPE'].mean()
    print(f"\n[INFO] Rolling training with Early Stopping completed for {ticker}. Overall MAPE: {overall_mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] Total elapsed time: {elapsed:.2f}s")

    worst_10 = df_results.sort_values('MAPE', ascending=False).head(10)
    print("[INFO] Top 10 worst predictions in rolling scenario (Early Stopping):")
    print(worst_10[['Date', 'Actual', 'Predicted', 'MAPE']])

if __name__ == "__main__":
    # Just run with the current top-level defined parameters:
    rolling_training_early_stopping(ticker, window_size, step_size, n_steps)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [INFO] Training initial window with Early Stopping...
# [RESULT] Initial window validation MAPE: 1.28%
#
# [INFO] Iteration 1: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.60%
# [INFO] Predicted last sample of window: Actual=6.30, Pred=6.07, MAPE=3.60%
#
# [INFO] Iteration 2: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.01%
# [INFO] Predicted last sample of window: Actual=6.14, Pred=6.14, MAPE=0.01%
#
# [INFO] Iteration 3: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.16%
# [INFO] Predicted last sample of window: Actual=6.23, Pred=6.22, MAPE=0.16%
#
# [INFO] Iteration 4: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.44%
# [INFO] Predicted last sample of window: Actual=6.25, Pred=6.23, MAPE=0.44%
#
# [INFO] Iteration 5: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.14%
# [INFO] Predicted last sample of window: Actual=6.26, Pred=6.25, MAPE=0.14%
#
# [INFO] Iteration 6: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.50%
# [INFO] Predicted last sample of window: Actual=6.20, Pred=6.23, MAPE=0.50%
#
# [INFO] Iteration 7: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.04%
# [INFO] Predicted last sample of window: Actual=6.15, Pred=6.15, MAPE=0.04%
#
# [INFO] Iteration 8: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.15%
# [INFO] Predicted last sample of window: Actual=6.01, Pred=6.14, MAPE=2.15%
#
# [INFO] Iteration 9: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.42%
# [INFO] Predicted last sample of window: Actual=6.27, Pred=6.18, MAPE=1.42%
#
# [INFO] Iteration 10: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.36%
# [INFO] Predicted last sample of window: Actual=6.29, Pred=6.27, MAPE=0.36%
#
# [INFO] Iteration 11: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.13%
# [INFO] Predicted last sample of window: Actual=6.70, Pred=6.35, MAPE=5.13%
#
# [INFO] Iteration 12: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.92%
# [INFO] Predicted last sample of window: Actual=6.77, Pred=6.71, MAPE=0.92%
#
# [INFO] Iteration 13: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 8.10%
# [INFO] Predicted last sample of window: Actual=7.41, Pred=6.81, MAPE=8.10%
#
# [INFO] Iteration 14: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.74%
# [INFO] Predicted last sample of window: Actual=7.72, Pred=7.43, MAPE=3.74%
#
# [INFO] Iteration 15: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 8.59%
# [INFO] Predicted last sample of window: Actual=6.83, Pred=7.42, MAPE=8.59%
#
# [INFO] Iteration 16: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.50%
# [INFO] Predicted last sample of window: Actual=6.69, Pred=6.79, MAPE=1.50%
#
# [INFO] Iteration 17: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.95%
# [INFO] Predicted last sample of window: Actual=6.75, Pred=6.69, MAPE=0.95%
#
# [INFO] Iteration 18: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.59%
# [INFO] Predicted last sample of window: Actual=6.65, Pred=6.69, MAPE=0.59%
#
# [INFO] Iteration 19: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.04%
# [INFO] Predicted last sample of window: Actual=6.83, Pred=6.84, MAPE=0.04%
#
# [INFO] Iteration 20: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 8.71%
# [INFO] Predicted last sample of window: Actual=6.14, Pred=6.67, MAPE=8.71%
#
# [INFO] Iteration 21: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.76%
# [INFO] Predicted last sample of window: Actual=6.16, Pred=6.52, MAPE=5.76%
#
# [INFO] Iteration 22: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.82%
# [INFO] Predicted last sample of window: Actual=6.02, Pred=6.07, MAPE=0.82%
#
# [INFO] Iteration 23: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.55%
# [INFO] Predicted last sample of window: Actual=5.43, Pred=5.40, MAPE=0.55%
#
# [INFO] Iteration 24: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=5.32, Pred=5.32, MAPE=0.00%
#
# [INFO] Iteration 25: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.37%
# [INFO] Predicted last sample of window: Actual=5.32, Pred=5.39, MAPE=1.37%
#
# [INFO] Iteration 26: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 11.48%
# [INFO] Predicted last sample of window: Actual=6.14, Pred=5.44, MAPE=11.48%
#
# [INFO] Iteration 27: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.22%
# [INFO] Predicted last sample of window: Actual=6.32, Pred=6.24, MAPE=1.22%
#
# [INFO] Iteration 28: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.29%
# [INFO] Predicted last sample of window: Actual=6.59, Pred=6.44, MAPE=2.29%
#
# [INFO] Iteration 29: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.19%
# [INFO] Predicted last sample of window: Actual=6.39, Pred=6.40, MAPE=0.19%
#
# [INFO] Iteration 30: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.60%
# [INFO] Predicted last sample of window: Actual=6.71, Pred=6.47, MAPE=3.60%
#
# [INFO] Iteration 31: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.25%
# [INFO] Predicted last sample of window: Actual=6.67, Pred=6.82, MAPE=2.25%
#
# [INFO] Iteration 32: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.94%
# [INFO] Predicted last sample of window: Actual=6.75, Pred=6.68, MAPE=0.94%
#
# [INFO] Iteration 33: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.89%
# [INFO] Predicted last sample of window: Actual=7.02, Pred=6.89, MAPE=1.89%
#
# [INFO] Iteration 34: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.60%
# [INFO] Predicted last sample of window: Actual=7.31, Pred=7.12, MAPE=2.60%
#
# [INFO] Iteration 35: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 6.59%
# [INFO] Predicted last sample of window: Actual=6.74, Pred=7.18, MAPE=6.59%
#
# [INFO] Iteration 36: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.68%
# [INFO] Predicted last sample of window: Actual=7.10, Pred=7.15, MAPE=0.68%
#
# [INFO] Iteration 37: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.61%
# [INFO] Predicted last sample of window: Actual=7.43, Pred=7.16, MAPE=3.61%
#
# [INFO] Iteration 38: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.11%
# [INFO] Predicted last sample of window: Actual=7.46, Pred=7.30, MAPE=2.11%
#
# [INFO] Iteration 39: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.55%
# [INFO] Predicted last sample of window: Actual=7.07, Pred=7.32, MAPE=3.55%
#
# [INFO] Iteration 40: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.51%
# [INFO] Predicted last sample of window: Actual=7.34, Pred=7.31, MAPE=0.51%
#
# [INFO] Iteration 41: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.53%
# [INFO] Predicted last sample of window: Actual=7.62, Pred=7.35, MAPE=3.53%
#
# [INFO] Iteration 42: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.04%
# [INFO] Predicted last sample of window: Actual=8.07, Pred=7.66, MAPE=5.04%
#
# [INFO] Iteration 43: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.33%
# [INFO] Predicted last sample of window: Actual=7.78, Pred=7.81, MAPE=0.33%
#
# [INFO] Iteration 44: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.44%
# [INFO] Predicted last sample of window: Actual=8.49, Pred=8.03, MAPE=5.44%
#
# [INFO] Iteration 45: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.38%
# [INFO] Predicted last sample of window: Actual=8.81, Pred=9.02, MAPE=2.38%
#
# [INFO] Iteration 46: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.04%
# [INFO] Predicted last sample of window: Actual=8.78, Pred=8.78, MAPE=0.04%
#
# [INFO] Iteration 47: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.03%
# [INFO] Predicted last sample of window: Actual=8.72, Pred=8.81, MAPE=1.03%
#
# [INFO] Iteration 48: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.79%
# [INFO] Predicted last sample of window: Actual=8.49, Pred=8.25, MAPE=2.79%
#
# [INFO] Iteration 49: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.76%
# [INFO] Predicted last sample of window: Actual=8.81, Pred=8.74, MAPE=0.76%
#
# [INFO] Iteration 50: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.50%
# [INFO] Predicted last sample of window: Actual=8.77, Pred=8.81, MAPE=0.50%
#
# [INFO] Iteration 51: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.22%
# [INFO] Predicted last sample of window: Actual=8.92, Pred=8.81, MAPE=1.22%
#
# [INFO] Iteration 52: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.52%
# [INFO] Predicted last sample of window: Actual=9.05, Pred=8.82, MAPE=2.52%
#
# [INFO] Iteration 53: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.20%
# [INFO] Predicted last sample of window: Actual=8.80, Pred=9.17, MAPE=4.20%
#
# [INFO] Iteration 54: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.39%
# [INFO] Predicted last sample of window: Actual=9.17, Pred=9.05, MAPE=1.39%
#
# [INFO] Iteration 55: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.05%
# [INFO] Predicted last sample of window: Actual=9.24, Pred=9.24, MAPE=0.05%
#
# [INFO] Iteration 56: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.37%
# [INFO] Predicted last sample of window: Actual=9.26, Pred=9.23, MAPE=0.37%
#
# [INFO] Iteration 57: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.48%
# [INFO] Predicted last sample of window: Actual=9.45, Pred=9.31, MAPE=1.48%
#
# [INFO] Iteration 58: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.32%
# [INFO] Predicted last sample of window: Actual=9.49, Pred=9.46, MAPE=0.32%
#
# [INFO] Iteration 59: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.51%
# [INFO] Predicted last sample of window: Actual=9.20, Pred=9.25, MAPE=0.51%
#
# [INFO] Iteration 60: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.06%
# [INFO] Predicted last sample of window: Actual=9.53, Pred=9.54, MAPE=0.06%
#
# [INFO] Iteration 61: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.00%
# [INFO] Predicted last sample of window: Actual=9.84, Pred=9.54, MAPE=3.00%
#
# [INFO] Iteration 62: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.34%
# [INFO] Predicted last sample of window: Actual=10.22, Pred=9.87, MAPE=3.34%
#
# [INFO] Iteration 63: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.29%
# [INFO] Predicted last sample of window: Actual=10.48, Pred=10.34, MAPE=1.29%
#
# [INFO] Iteration 64: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.36%
# [INFO] Predicted last sample of window: Actual=10.38, Pred=10.41, MAPE=0.36%
#
# [INFO] Iteration 65: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.90%
# [INFO] Predicted last sample of window: Actual=10.13, Pred=10.23, MAPE=0.90%
#
# [INFO] Iteration 66: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.61%
# [INFO] Predicted last sample of window: Actual=10.51, Pred=10.24, MAPE=2.61%
#
# [INFO] Iteration 67: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.32%
# [INFO] Predicted last sample of window: Actual=10.44, Pred=10.41, MAPE=0.32%
#
# [INFO] Iteration 68: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.25%
# [INFO] Predicted last sample of window: Actual=10.19, Pred=10.32, MAPE=1.25%
#
# [INFO] Iteration 69: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.09%
# [INFO] Predicted last sample of window: Actual=10.22, Pred=10.22, MAPE=0.09%
#
# [INFO] Iteration 70: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.57%
# [INFO] Predicted last sample of window: Actual=10.61, Pred=10.45, MAPE=1.57%
#
# [INFO] Iteration 71: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.89%
# [INFO] Predicted last sample of window: Actual=11.01, Pred=10.80, MAPE=1.89%
#
# [INFO] Iteration 72: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.48%
# [INFO] Predicted last sample of window: Actual=11.29, Pred=11.12, MAPE=1.48%
#
# [INFO] Iteration 73: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.33%
# [INFO] Predicted last sample of window: Actual=11.20, Pred=11.24, MAPE=0.33%
#
# [INFO] Iteration 74: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.18%
# [INFO] Predicted last sample of window: Actual=10.85, Pred=11.20, MAPE=3.18%
#
# [INFO] Iteration 75: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.99%
# [INFO] Predicted last sample of window: Actual=11.44, Pred=11.22, MAPE=1.99%
#
# [INFO] Iteration 76: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 7.12%
# [INFO] Predicted last sample of window: Actual=12.34, Pred=11.46, MAPE=7.12%
#
# [INFO] Iteration 77: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.23%
# [INFO] Predicted last sample of window: Actual=12.14, Pred=12.29, MAPE=1.23%
#
# [INFO] Iteration 78: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.15%
# [INFO] Predicted last sample of window: Actual=12.68, Pred=12.28, MAPE=3.15%
#
# [INFO] Iteration 79: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.40%
# [INFO] Predicted last sample of window: Actual=12.75, Pred=13.06, MAPE=2.40%
#
# [INFO] Iteration 80: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.77%
# [INFO] Predicted last sample of window: Actual=12.63, Pred=12.73, MAPE=0.77%
#
# [INFO] Iteration 81: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.19%
# [INFO] Predicted last sample of window: Actual=13.37, Pred=12.81, MAPE=4.19%
#
# [INFO] Iteration 82: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.22%
# [INFO] Predicted last sample of window: Actual=14.35, Pred=13.60, MAPE=5.22%
#
# [INFO] Iteration 83: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 6.40%
# [INFO] Predicted last sample of window: Actual=12.62, Pred=13.43, MAPE=6.40%
#
# [INFO] Iteration 84: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=12.72, Pred=12.71, MAPE=0.00%
#
# [INFO] Iteration 85: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.55%
# [INFO] Predicted last sample of window: Actual=12.16, Pred=12.35, MAPE=1.55%
#
# [INFO] Iteration 86: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.69%
# [INFO] Predicted last sample of window: Actual=12.99, Pred=12.77, MAPE=1.69%
#
# [INFO] Iteration 87: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.72%
# [INFO] Predicted last sample of window: Actual=12.46, Pred=12.55, MAPE=0.72%
#
# [INFO] Iteration 88: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.03%
# [INFO] Predicted last sample of window: Actual=12.52, Pred=12.51, MAPE=0.03%
#
# [INFO] Iteration 89: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.22%
# [INFO] Predicted last sample of window: Actual=12.12, Pred=12.51, MAPE=3.22%
#
# [INFO] Iteration 90: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.48%
# [INFO] Predicted last sample of window: Actual=12.87, Pred=12.55, MAPE=2.48%
#
# [INFO] Iteration 91: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.12%
# [INFO] Predicted last sample of window: Actual=13.23, Pred=13.37, MAPE=1.12%
#
# [INFO] Iteration 92: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.51%
# [INFO] Predicted last sample of window: Actual=13.61, Pred=13.27, MAPE=2.51%
#
# [INFO] Iteration 93: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.18%
# [INFO] Predicted last sample of window: Actual=13.64, Pred=13.62, MAPE=0.18%
#
# [INFO] Iteration 94: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.17%
# [INFO] Predicted last sample of window: Actual=13.96, Pred=13.66, MAPE=2.17%
#
# [INFO] Iteration 95: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.07%
# [INFO] Predicted last sample of window: Actual=13.76, Pred=13.77, MAPE=0.07%
#
# [INFO] Iteration 96: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.14%
# [INFO] Predicted last sample of window: Actual=14.25, Pred=14.09, MAPE=1.14%
#
# [INFO] Iteration 97: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.06%
# [INFO] Predicted last sample of window: Actual=13.97, Pred=14.12, MAPE=1.06%
#
# [INFO] Iteration 98: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.09%
# [INFO] Predicted last sample of window: Actual=13.50, Pred=13.91, MAPE=3.09%
#
# [INFO] Iteration 99: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.53%
# [INFO] Predicted last sample of window: Actual=13.52, Pred=13.60, MAPE=0.53%
#
# [INFO] Iteration 100: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.69%
# [INFO] Predicted last sample of window: Actual=13.59, Pred=13.50, MAPE=0.69%
#
# [INFO] Iteration 101: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.03%
# [INFO] Predicted last sample of window: Actual=13.40, Pred=13.39, MAPE=0.03%
#
# [INFO] Iteration 102: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.19%
# [INFO] Predicted last sample of window: Actual=13.02, Pred=13.00, MAPE=0.19%
#
# [INFO] Iteration 103: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.08%
# [INFO] Predicted last sample of window: Actual=12.58, Pred=12.59, MAPE=0.08%
#
# [INFO] Iteration 104: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.52%
# [INFO] Predicted last sample of window: Actual=13.79, Pred=13.03, MAPE=5.52%
#
# [INFO] Iteration 105: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.11%
# [INFO] Predicted last sample of window: Actual=14.56, Pred=14.11, MAPE=3.11%
#
# [INFO] Iteration 106: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 8.27%
# [INFO] Predicted last sample of window: Actual=12.77, Pred=13.83, MAPE=8.27%
#
# [INFO] Iteration 107: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.16%
# [INFO] Predicted last sample of window: Actual=13.46, Pred=13.43, MAPE=0.16%
#
# [INFO] Iteration 108: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.63%
# [INFO] Predicted last sample of window: Actual=13.52, Pred=13.43, MAPE=0.63%
#
# [INFO] Iteration 109: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.03%
# [INFO] Predicted last sample of window: Actual=13.43, Pred=13.43, MAPE=0.03%
#
# [INFO] Iteration 110: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.59%
# [INFO] Predicted last sample of window: Actual=13.09, Pred=13.43, MAPE=2.59%
#
# [INFO] Iteration 111: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.09%
# [INFO] Predicted last sample of window: Actual=12.96, Pred=13.10, MAPE=1.09%
#
# [INFO] Iteration 112: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.21%
# [INFO] Predicted last sample of window: Actual=13.26, Pred=13.10, MAPE=1.21%
#
# [INFO] Iteration 113: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.58%
# [INFO] Predicted last sample of window: Actual=13.39, Pred=13.31, MAPE=0.58%
#
# [INFO] Iteration 114: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=13.40, Pred=13.40, MAPE=0.00%
#
# [INFO] Iteration 115: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.13%
# [INFO] Predicted last sample of window: Actual=13.61, Pred=13.59, MAPE=0.13%
#
# [INFO] Iteration 116: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.66%
# [INFO] Predicted last sample of window: Actual=12.93, Pred=13.40, MAPE=3.66%
#
# [INFO] Iteration 117: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.49%
# [INFO] Predicted last sample of window: Actual=13.01, Pred=12.95, MAPE=0.49%
#
# [INFO] Iteration 118: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.25%
# [INFO] Predicted last sample of window: Actual=13.36, Pred=13.06, MAPE=2.25%
#
# [INFO] Iteration 119: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.19%
# [INFO] Predicted last sample of window: Actual=13.34, Pred=13.32, MAPE=0.19%
#
# [INFO] Iteration 120: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.04%
# [INFO] Predicted last sample of window: Actual=13.33, Pred=13.33, MAPE=0.04%
#
# [INFO] Iteration 121: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.10%
# [INFO] Predicted last sample of window: Actual=13.01, Pred=13.28, MAPE=2.10%
#
# [INFO] Iteration 122: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.64%
# [INFO] Predicted last sample of window: Actual=12.90, Pred=12.98, MAPE=0.64%
#
# [INFO] Iteration 123: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.22%
# [INFO] Predicted last sample of window: Actual=13.15, Pred=12.99, MAPE=1.22%
#
# [INFO] Iteration 124: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.38%
# [INFO] Predicted last sample of window: Actual=13.11, Pred=13.06, MAPE=0.38%
#
# [INFO] Iteration 125: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.25%
# [INFO] Predicted last sample of window: Actual=12.61, Pred=13.15, MAPE=4.25%
#
# [INFO] Iteration 126: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.57%
# [INFO] Predicted last sample of window: Actual=13.28, Pred=13.20, MAPE=0.57%
#
# [INFO] Iteration 127: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.74%
# [INFO] Predicted last sample of window: Actual=13.48, Pred=13.38, MAPE=0.74%
#
# [INFO] Iteration 128: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.32%
# [INFO] Predicted last sample of window: Actual=13.20, Pred=13.51, MAPE=2.32%
#
# [INFO] Iteration 129: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.12%
# [INFO] Predicted last sample of window: Actual=13.03, Pred=13.04, MAPE=0.12%
#
# [INFO] Iteration 130: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.70%
# [INFO] Predicted last sample of window: Actual=13.87, Pred=13.22, MAPE=4.70%
#
# [INFO] Iteration 131: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.54%
# [INFO] Predicted last sample of window: Actual=13.65, Pred=13.73, MAPE=0.54%
#
# [INFO] Iteration 132: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 6.02%
# [INFO] Predicted last sample of window: Actual=12.92, Pred=13.70, MAPE=6.02%
#
# [INFO] Iteration 133: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.48%
# [INFO] Predicted last sample of window: Actual=12.99, Pred=13.05, MAPE=0.48%
#
# [INFO] Iteration 134: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.66%
# [INFO] Predicted last sample of window: Actual=13.56, Pred=13.06, MAPE=3.66%
#
# [INFO] Iteration 135: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.73%
# [INFO] Predicted last sample of window: Actual=13.66, Pred=13.56, MAPE=0.73%
#
# [INFO] Iteration 136: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.79%
# [INFO] Predicted last sample of window: Actual=14.44, Pred=13.60, MAPE=5.79%
#
# [INFO] Iteration 137: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.55%
# [INFO] Predicted last sample of window: Actual=14.76, Pred=14.99, MAPE=1.55%
#
# [INFO] Iteration 138: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.97%
# [INFO] Predicted last sample of window: Actual=14.96, Pred=14.82, MAPE=0.97%
#
# [INFO] Iteration 139: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.50%
# [INFO] Predicted last sample of window: Actual=14.91, Pred=14.98, MAPE=0.50%
#
# [INFO] Iteration 140: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.13%
# [INFO] Predicted last sample of window: Actual=14.93, Pred=14.91, MAPE=0.13%
#
# [INFO] Iteration 141: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.40%
# [INFO] Predicted last sample of window: Actual=14.14, Pred=14.76, MAPE=4.40%
#
# [INFO] Iteration 142: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 7.54%
# [INFO] Predicted last sample of window: Actual=13.31, Pred=14.31, MAPE=7.54%
#
# [INFO] Iteration 143: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.21%
# [INFO] Predicted last sample of window: Actual=13.84, Pred=13.87, MAPE=0.21%
#
# [INFO] Iteration 144: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.94%
# [INFO] Predicted last sample of window: Actual=12.80, Pred=13.44, MAPE=4.94%
#
# [INFO] Iteration 145: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=12.46, Pred=12.46, MAPE=0.00%
#
# [INFO] Iteration 146: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.59%
# [INFO] Predicted last sample of window: Actual=12.52, Pred=12.45, MAPE=0.59%
#
# [INFO] Iteration 147: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.97%
# [INFO] Predicted last sample of window: Actual=12.99, Pred=12.48, MAPE=3.97%
#
# [INFO] Iteration 148: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.23%
# [INFO] Predicted last sample of window: Actual=13.19, Pred=12.90, MAPE=2.23%
#
# [INFO] Iteration 149: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.08%
# [INFO] Predicted last sample of window: Actual=13.34, Pred=13.33, MAPE=0.08%
#
# [INFO] Iteration 150: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.74%
# [INFO] Predicted last sample of window: Actual=12.85, Pred=13.20, MAPE=2.74%
#
# [INFO] Iteration 151: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=13.07, Pred=13.07, MAPE=0.00%
#
# [INFO] Iteration 152: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.51%
# [INFO] Predicted last sample of window: Actual=12.54, Pred=12.85, MAPE=2.51%
#
# [INFO] Iteration 153: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.98%
# [INFO] Predicted last sample of window: Actual=12.95, Pred=12.82, MAPE=0.98%
#
# [INFO] Iteration 154: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.55%
# [INFO] Predicted last sample of window: Actual=13.35, Pred=12.87, MAPE=3.55%
#
# [INFO] Iteration 155: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.86%
# [INFO] Predicted last sample of window: Actual=13.99, Pred=13.73, MAPE=1.86%
#
# [INFO] Iteration 156: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.96%
# [INFO] Predicted last sample of window: Actual=14.14, Pred=13.87, MAPE=1.96%
#
# [INFO] Iteration 157: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.13%
# [INFO] Predicted last sample of window: Actual=14.40, Pred=14.56, MAPE=1.13%
#
# [INFO] Iteration 158: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 8.05%
# [INFO] Predicted last sample of window: Actual=15.68, Pred=14.42, MAPE=8.05%
#
# [INFO] Iteration 159: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.75%
# [INFO] Predicted last sample of window: Actual=16.14, Pred=15.37, MAPE=4.75%
#
# [INFO] Iteration 160: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.55%
# [INFO] Predicted last sample of window: Actual=15.36, Pred=15.75, MAPE=2.55%
#
# [INFO] Iteration 161: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.35%
# [INFO] Predicted last sample of window: Actual=15.36, Pred=15.41, MAPE=0.35%
#
# [INFO] Iteration 162: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.06%
# [INFO] Predicted last sample of window: Actual=15.27, Pred=15.26, MAPE=0.06%
#
# [INFO] Iteration 163: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.01%
# [INFO] Predicted last sample of window: Actual=15.38, Pred=15.38, MAPE=0.01%
#
# [INFO] Iteration 164: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.02%
# [INFO] Predicted last sample of window: Actual=15.32, Pred=15.33, MAPE=0.02%
#
# [INFO] Iteration 165: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.82%
# [INFO] Predicted last sample of window: Actual=14.84, Pred=15.26, MAPE=2.82%
#
# [INFO] Iteration 166: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.33%
# [INFO] Predicted last sample of window: Actual=14.46, Pred=14.51, MAPE=0.33%
#
# [INFO] Iteration 167: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.94%
# [INFO] Predicted last sample of window: Actual=14.81, Pred=14.53, MAPE=1.94%
#
# [INFO] Iteration 168: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.25%
# [INFO] Predicted last sample of window: Actual=14.31, Pred=14.48, MAPE=1.25%
#
# [INFO] Iteration 169: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.88%
# [INFO] Predicted last sample of window: Actual=13.67, Pred=14.20, MAPE=3.88%
#
# [INFO] Iteration 170: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.71%
# [INFO] Predicted last sample of window: Actual=14.17, Pred=13.78, MAPE=2.71%
#
# [INFO] Iteration 171: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.18%
# [INFO] Predicted last sample of window: Actual=14.07, Pred=14.09, MAPE=0.18%
#
# [INFO] Iteration 172: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.03%
# [INFO] Predicted last sample of window: Actual=14.99, Pred=14.24, MAPE=5.03%
#
# [INFO] Iteration 173: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.86%
# [INFO] Predicted last sample of window: Actual=15.65, Pred=15.04, MAPE=3.86%
#
# [INFO] Iteration 174: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.86%
# [INFO] Predicted last sample of window: Actual=15.49, Pred=15.62, MAPE=0.86%
#
# [INFO] Iteration 175: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.35%
# [INFO] Predicted last sample of window: Actual=16.26, Pred=15.72, MAPE=3.35%
#
# [INFO] Iteration 176: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.66%
# [INFO] Predicted last sample of window: Actual=16.97, Pred=16.35, MAPE=3.66%
#
# [INFO] Iteration 177: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.90%
# [INFO] Predicted last sample of window: Actual=17.62, Pred=17.11, MAPE=2.90%
#
# [INFO] Iteration 178: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.65%
# [INFO] Predicted last sample of window: Actual=17.36, Pred=17.47, MAPE=0.65%
#
# [INFO] Iteration 179: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.90%
# [INFO] Predicted last sample of window: Actual=17.83, Pred=17.49, MAPE=1.90%
#
# [INFO] Iteration 180: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.20%
# [INFO] Predicted last sample of window: Actual=17.79, Pred=18.18, MAPE=2.20%
#
# [INFO] Iteration 181: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.39%
# [INFO] Predicted last sample of window: Actual=18.66, Pred=17.84, MAPE=4.39%
#
# [INFO] Iteration 182: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 8.25%
# [INFO] Predicted last sample of window: Actual=18.43, Pred=19.95, MAPE=8.25%
#
# [INFO] Iteration 183: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.94%
# [INFO] Predicted last sample of window: Actual=19.06, Pred=18.69, MAPE=1.94%
#
# [INFO] Iteration 184: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.12%
# [INFO] Predicted last sample of window: Actual=19.03, Pred=19.05, MAPE=0.12%
#
# [INFO] Iteration 185: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.40%
# [INFO] Predicted last sample of window: Actual=20.03, Pred=19.35, MAPE=3.40%
#
# [INFO] Iteration 186: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.00%
# [INFO] Predicted last sample of window: Actual=20.21, Pred=20.01, MAPE=1.00%
#
# [INFO] Iteration 187: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.98%
# [INFO] Predicted last sample of window: Actual=20.70, Pred=20.29, MAPE=1.98%
#
# [INFO] Iteration 188: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.44%
# [INFO] Predicted last sample of window: Actual=19.90, Pred=20.39, MAPE=2.44%
#
# [INFO] Iteration 189: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.86%
# [INFO] Predicted last sample of window: Actual=20.51, Pred=20.34, MAPE=0.86%
#
# [INFO] Iteration 190: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.15%
# [INFO] Predicted last sample of window: Actual=19.84, Pred=20.07, MAPE=1.15%
#
# [INFO] Iteration 191: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 7.61%
# [INFO] Predicted last sample of window: Actual=18.16, Pred=19.54, MAPE=7.61%
#
# [INFO] Iteration 192: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.00%
# [INFO] Predicted last sample of window: Actual=18.61, Pred=18.80, MAPE=1.00%
#
# [INFO] Iteration 193: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.55%
# [INFO] Predicted last sample of window: Actual=19.59, Pred=18.90, MAPE=3.55%
#
# [INFO] Iteration 194: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.69%
# [INFO] Predicted last sample of window: Actual=19.29, Pred=19.43, MAPE=0.69%
#
# [INFO] Iteration 195: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=19.50, Pred=19.50, MAPE=0.00%
#
# [INFO] Iteration 196: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.05%
# [INFO] Predicted last sample of window: Actual=19.50, Pred=19.51, MAPE=0.05%
#
# [INFO] Iteration 197: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.73%
# [INFO] Predicted last sample of window: Actual=19.82, Pred=19.67, MAPE=0.73%
#
# [INFO] Iteration 198: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.26%
# [INFO] Predicted last sample of window: Actual=20.64, Pred=20.17, MAPE=2.26%
#
# [INFO] Iteration 199: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.03%
# [INFO] Predicted last sample of window: Actual=20.30, Pred=20.30, MAPE=0.03%
#
# [INFO] Iteration 200: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.00%
# [INFO] Predicted last sample of window: Actual=19.70, Pred=20.29, MAPE=3.00%
#
# [INFO] Iteration 201: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.21%
# [INFO] Predicted last sample of window: Actual=20.19, Pred=19.94, MAPE=1.21%
#
# [INFO] Iteration 202: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.36%
# [INFO] Predicted last sample of window: Actual=19.46, Pred=19.92, MAPE=2.36%
#
# [INFO] Iteration 203: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=19.80, Pred=19.80, MAPE=0.00%
#
# [INFO] Iteration 204: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 9.32%
# [INFO] Predicted last sample of window: Actual=21.96, Pred=19.91, MAPE=9.32%
#
# [INFO] Iteration 205: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.70%
# [INFO] Predicted last sample of window: Actual=22.21, Pred=21.84, MAPE=1.70%
#
# [INFO] Iteration 206: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.49%
# [INFO] Predicted last sample of window: Actual=22.64, Pred=22.07, MAPE=2.49%
#
# [INFO] Iteration 207: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.20%
# [INFO] Predicted last sample of window: Actual=22.39, Pred=22.43, MAPE=0.20%
#
# [INFO] Iteration 208: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.26%
# [INFO] Predicted last sample of window: Actual=22.40, Pred=22.46, MAPE=0.26%
#
# [INFO] Iteration 209: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.92%
# [INFO] Predicted last sample of window: Actual=22.66, Pred=22.45, MAPE=0.92%
#
# [INFO] Iteration 210: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.35%
# [INFO] Predicted last sample of window: Actual=22.18, Pred=22.26, MAPE=0.35%
#
# [INFO] Iteration 211: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.93%
# [INFO] Predicted last sample of window: Actual=22.15, Pred=22.36, MAPE=0.93%
#
# [INFO] Iteration 212: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.45%
# [INFO] Predicted last sample of window: Actual=22.34, Pred=22.24, MAPE=0.45%
#
# [INFO] Iteration 213: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.62%
# [INFO] Predicted last sample of window: Actual=21.90, Pred=22.25, MAPE=1.62%
#
# [INFO] Iteration 214: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=21.25, Pred=21.25, MAPE=0.00%
#
# [INFO] Iteration 215: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.49%
# [INFO] Predicted last sample of window: Actual=22.48, Pred=21.92, MAPE=2.49%
#
# [INFO] Iteration 216: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.40%
# [INFO] Predicted last sample of window: Actual=21.66, Pred=21.96, MAPE=1.40%
#
# [INFO] Iteration 217: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.24%
# [INFO] Predicted last sample of window: Actual=20.52, Pred=21.59, MAPE=5.24%
#
# [INFO] Iteration 218: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.11%
# [INFO] Predicted last sample of window: Actual=20.74, Pred=20.72, MAPE=0.11%
#
# [INFO] Iteration 219: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=20.45, Pred=20.45, MAPE=0.00%
#
# [INFO] Iteration 220: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.65%
# [INFO] Predicted last sample of window: Actual=21.08, Pred=20.73, MAPE=1.65%
#
# [INFO] Iteration 221: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.05%
# [INFO] Predicted last sample of window: Actual=20.69, Pred=20.70, MAPE=0.05%
#
# [INFO] Iteration 222: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.45%
# [INFO] Predicted last sample of window: Actual=20.94, Pred=20.84, MAPE=0.45%
#
# [INFO] Iteration 223: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.85%
# [INFO] Predicted last sample of window: Actual=21.86, Pred=21.02, MAPE=3.85%
#
# [INFO] Iteration 224: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.78%
# [INFO] Predicted last sample of window: Actual=22.29, Pred=21.89, MAPE=1.78%
#
# [INFO] Iteration 225: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.95%
# [INFO] Predicted last sample of window: Actual=22.69, Pred=22.25, MAPE=1.95%
#
# [INFO] Iteration 226: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.89%
# [INFO] Predicted last sample of window: Actual=23.17, Pred=22.96, MAPE=0.89%
#
# [INFO] Iteration 227: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.53%
# [INFO] Predicted last sample of window: Actual=24.45, Pred=23.34, MAPE=4.53%
#
# [INFO] Iteration 228: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.18%
# [INFO] Predicted last sample of window: Actual=25.57, Pred=24.75, MAPE=3.18%
#
# [INFO] Iteration 229: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.80%
# [INFO] Predicted last sample of window: Actual=26.40, Pred=25.66, MAPE=2.80%
#
# [INFO] Iteration 230: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 11.00%
# [INFO] Predicted last sample of window: Actual=29.80, Pred=26.52, MAPE=11.00%
#
# [INFO] Iteration 231: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.07%
# [INFO] Predicted last sample of window: Actual=30.80, Pred=30.82, MAPE=0.07%
#
# [INFO] Iteration 232: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.39%
# [INFO] Predicted last sample of window: Actual=29.46, Pred=29.87, MAPE=1.39%
#
# [INFO] Iteration 233: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.17%
# [INFO] Predicted last sample of window: Actual=30.39, Pred=30.34, MAPE=0.17%
#
# [INFO] Iteration 234: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.08%
# [INFO] Predicted last sample of window: Actual=30.20, Pred=30.18, MAPE=0.08%
#
# [INFO] Iteration 235: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.90%
# [INFO] Predicted last sample of window: Actual=31.67, Pred=30.12, MAPE=4.90%
#
# [INFO] Iteration 236: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.38%
# [INFO] Predicted last sample of window: Actual=31.96, Pred=31.84, MAPE=0.38%
#
# [INFO] Iteration 237: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.25%
# [INFO] Predicted last sample of window: Actual=32.67, Pred=31.94, MAPE=2.25%
#
# [INFO] Iteration 238: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.27%
# [INFO] Predicted last sample of window: Actual=33.38, Pred=31.95, MAPE=4.27%
#
# [INFO] Iteration 239: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.19%
# [INFO] Predicted last sample of window: Actual=31.43, Pred=32.75, MAPE=4.19%
#
# [INFO] Iteration 240: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.35%
# [INFO] Predicted last sample of window: Actual=30.69, Pred=32.03, MAPE=4.35%
#
# [INFO] Iteration 241: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.42%
# [INFO] Predicted last sample of window: Actual=32.43, Pred=30.67, MAPE=5.42%
#
# [INFO] Iteration 242: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.14%
# [INFO] Predicted last sample of window: Actual=30.49, Pred=30.84, MAPE=1.14%
#
# [INFO] Iteration 243: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 7.40%
# [INFO] Predicted last sample of window: Actual=28.16, Pred=30.25, MAPE=7.40%
#
# [INFO] Iteration 244: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.92%
# [INFO] Predicted last sample of window: Actual=30.46, Pred=29.87, MAPE=1.92%
#
# [INFO] Iteration 245: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.92%
# [INFO] Predicted last sample of window: Actual=27.80, Pred=28.33, MAPE=1.92%
#
# [INFO] Iteration 246: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.65%
# [INFO] Predicted last sample of window: Actual=29.08, Pred=28.31, MAPE=2.65%
#
# [INFO] Iteration 247: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.70%
# [INFO] Predicted last sample of window: Actual=29.64, Pred=29.13, MAPE=1.70%
#
# [INFO] Iteration 248: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.03%
# [INFO] Predicted last sample of window: Actual=30.32, Pred=29.71, MAPE=2.03%
#
# [INFO] Iteration 249: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.73%
# [INFO] Predicted last sample of window: Actual=29.59, Pred=30.10, MAPE=1.73%
#
# [INFO] Iteration 250: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.54%
# [INFO] Predicted last sample of window: Actual=30.12, Pred=29.96, MAPE=0.54%
#
# [INFO] Iteration 251: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.79%
# [INFO] Predicted last sample of window: Actual=27.60, Pred=29.20, MAPE=5.79%
#
# [INFO] Iteration 252: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.08%
# [INFO] Predicted last sample of window: Actual=27.25, Pred=28.08, MAPE=3.08%
#
# [INFO] Iteration 253: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.30%
# [INFO] Predicted last sample of window: Actual=27.82, Pred=27.45, MAPE=1.30%
#
# [INFO] Iteration 254: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.59%
# [INFO] Predicted last sample of window: Actual=26.58, Pred=27.53, MAPE=3.59%
#
# [INFO] Iteration 255: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.84%
# [INFO] Predicted last sample of window: Actual=25.90, Pred=26.90, MAPE=3.84%
#
# [INFO] Iteration 256: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.48%
# [INFO] Predicted last sample of window: Actual=24.15, Pred=25.47, MAPE=5.48%
#
# [INFO] Iteration 257: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.65%
# [INFO] Predicted last sample of window: Actual=23.37, Pred=23.76, MAPE=1.65%
#
# [INFO] Iteration 258: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.77%
# [INFO] Predicted last sample of window: Actual=22.77, Pred=23.18, MAPE=1.77%
#
# [INFO] Iteration 259: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.34%
# [INFO] Predicted last sample of window: Actual=22.84, Pred=22.76, MAPE=0.34%
#
# [INFO] Iteration 260: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 6.31%
# ...
#
# [INFO] Iteration 419: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.02%
# [INFO] Predicted last sample of window: Actual=28.57, Pred=28.58, MAPE=0.02%
#
# [INFO] Iteration 420: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.31%
# [INFO] Predicted last sample of window: Actual=28.58, Pred=28.67, MAPE=0.31%
#
# [INFO] Iteration 421: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.37%
# [INFO] Predicted last sample of window: Actual=28.95, Pred=28.56, MAPE=1.37%
#
# [INFO] Iteration 422: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.54%
# [INFO] Predicted last sample of window: Actual=30.18, Pred=29.11, MAPE=3.54%
#
# [INFO] Iteration 423: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.30%
# [INFO] Predicted last sample of window: Actual=31.26, Pred=30.23, MAPE=3.30%
#
# [INFO] Iteration 424: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.56%
# [INFO] Predicted last sample of window: Actual=30.69, Pred=31.17, MAPE=1.56%
#
# [INFO] Iteration 425: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 18.27%
# [INFO] Predicted last sample of window: Actual=37.98, Pred=31.04, MAPE=18.27%
#
# [INFO] Iteration 426: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.11%
# [INFO] Predicted last sample of window: Actual=40.11, Pred=38.46, MAPE=4.11%
#
# [INFO] Iteration 427: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.96%
# [INFO] Predicted last sample of window: Actual=39.77, Pred=38.99, MAPE=1.96%
#
# [INFO] Iteration 428: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.50%
# [INFO] Predicted last sample of window: Actual=39.17, Pred=39.37, MAPE=0.50%
#
# [INFO] Iteration 429: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.47%
# [INFO] Predicted last sample of window: Actual=37.47, Pred=39.15, MAPE=4.47%
#
# [INFO] Iteration 430: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.36%
# [INFO] Predicted last sample of window: Actual=38.77, Pred=38.91, MAPE=0.36%
#
# [INFO] Iteration 431: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.62%
# [INFO] Predicted last sample of window: Actual=41.02, Pred=38.72, MAPE=5.62%
#
# [INFO] Iteration 432: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.13%
# [INFO] Predicted last sample of window: Actual=42.65, Pred=41.32, MAPE=3.13%
#
# [INFO] Iteration 433: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.52%
# [INFO] Predicted last sample of window: Actual=43.81, Pred=42.70, MAPE=2.52%
#
# [INFO] Iteration 434: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.01%
# [INFO] Predicted last sample of window: Actual=43.03, Pred=43.02, MAPE=0.01%
#
# [INFO] Iteration 435: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.54%
# [INFO] Predicted last sample of window: Actual=40.63, Pred=42.88, MAPE=5.54%
#
# [INFO] Iteration 436: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.00%
# [INFO] Predicted last sample of window: Actual=41.12, Pred=41.94, MAPE=2.00%
#
# [INFO] Iteration 437: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.67%
# [INFO] Predicted last sample of window: Actual=42.30, Pred=41.17, MAPE=2.67%
#
# [INFO] Iteration 438: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.37%
# [INFO] Predicted last sample of window: Actual=42.32, Pred=42.47, MAPE=0.37%
#
# [INFO] Iteration 439: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.45%
# [INFO] Predicted last sample of window: Actual=42.50, Pred=42.31, MAPE=0.45%
#
# [INFO] Iteration 440: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.29%
# [INFO] Predicted last sample of window: Actual=42.40, Pred=42.28, MAPE=0.29%
#
# [INFO] Iteration 441: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 7.32%
# [INFO] Predicted last sample of window: Actual=45.98, Pred=42.61, MAPE=7.32%
#
# [INFO] Iteration 442: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.58%
# [INFO] Predicted last sample of window: Actual=46.46, Pred=45.73, MAPE=1.58%
#
# [INFO] Iteration 443: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.12%
# [INFO] Predicted last sample of window: Actual=47.08, Pred=46.55, MAPE=1.12%
#
# [INFO] Iteration 444: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.47%
# [INFO] Predicted last sample of window: Actual=44.31, Pred=46.29, MAPE=4.47%
#
# [INFO] Iteration 445: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.48%
# [INFO] Predicted last sample of window: Actual=45.68, Pred=45.46, MAPE=0.48%
#
# [INFO] Iteration 446: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.99%
# [INFO] Predicted last sample of window: Actual=45.90, Pred=45.45, MAPE=0.99%
#
# [INFO] Iteration 447: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.48%
# [INFO] Predicted last sample of window: Actual=46.73, Pred=46.04, MAPE=1.48%
#
# [INFO] Iteration 448: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.02%
# [INFO] Predicted last sample of window: Actual=44.27, Pred=46.49, MAPE=5.02%
#
# [INFO] Iteration 449: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.66%
# [INFO] Predicted last sample of window: Actual=44.68, Pred=44.39, MAPE=0.66%
#
# [INFO] Iteration 450: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=44.66, Pred=44.67, MAPE=0.00%
#
# [INFO] Iteration 451: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.05%
# [INFO] Predicted last sample of window: Actual=42.39, Pred=43.26, MAPE=2.05%
#
# [INFO] Iteration 452: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.11%
# [INFO] Predicted last sample of window: Actual=43.75, Pred=42.39, MAPE=3.11%
#
# [INFO] Iteration 453: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.25%
# [INFO] Predicted last sample of window: Actual=43.49, Pred=43.59, MAPE=0.25%
#
# [INFO] Iteration 454: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.42%
# [INFO] Predicted last sample of window: Actual=43.30, Pred=43.48, MAPE=0.42%
#
# [INFO] Iteration 455: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.30%
# [INFO] Predicted last sample of window: Actual=45.67, Pred=44.16, MAPE=3.30%
#
# [INFO] Iteration 456: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.40%
# [INFO] Predicted last sample of window: Actual=47.16, Pred=46.97, MAPE=0.40%
#
# [INFO] Iteration 457: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.46%
# [INFO] Predicted last sample of window: Actual=46.83, Pred=47.05, MAPE=0.46%
#
# [INFO] Iteration 458: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.17%
# [INFO] Predicted last sample of window: Actual=49.26, Pred=47.21, MAPE=4.17%
#
# [INFO] Iteration 459: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.64%
# [INFO] Predicted last sample of window: Actual=48.51, Pred=48.82, MAPE=0.64%
#
# [INFO] Iteration 460: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.96%
# [INFO] Predicted last sample of window: Actual=47.06, Pred=48.46, MAPE=2.96%
#
# [INFO] Iteration 461: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.96%
# [INFO] Predicted last sample of window: Actual=45.57, Pred=46.46, MAPE=1.96%
#
# [INFO] Iteration 462: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.31%
# [INFO] Predicted last sample of window: Actual=44.87, Pred=45.46, MAPE=1.31%
#
# [INFO] Iteration 463: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.21%
# [INFO] Predicted last sample of window: Actual=45.58, Pred=45.48, MAPE=0.21%
#
# [INFO] Iteration 464: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.55%
# [INFO] Predicted last sample of window: Actual=43.97, Pred=44.21, MAPE=0.55%
#
# [INFO] Iteration 465: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.64%
# [INFO] Predicted last sample of window: Actual=42.24, Pred=43.78, MAPE=3.64%
#
# [INFO] Iteration 466: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.10%
# [INFO] Predicted last sample of window: Actual=41.61, Pred=40.74, MAPE=2.10%
#
# [INFO] Iteration 467: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.11%
# [INFO] Predicted last sample of window: Actual=41.91, Pred=41.87, MAPE=0.11%
#
# [INFO] Iteration 468: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.83%
# [INFO] Predicted last sample of window: Actual=43.09, Pred=42.30, MAPE=1.83%
#
# [INFO] Iteration 469: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.64%
# [INFO] Predicted last sample of window: Actual=44.78, Pred=43.60, MAPE=2.64%
#
# [INFO] Iteration 470: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.20%
# [INFO] Predicted last sample of window: Actual=44.04, Pred=43.51, MAPE=1.20%
#
# [INFO] Iteration 471: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.14%
# [INFO] Predicted last sample of window: Actual=45.76, Pred=44.78, MAPE=2.14%
#
# [INFO] Iteration 472: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.02%
# [INFO] Predicted last sample of window: Actual=45.80, Pred=45.33, MAPE=1.02%
#
# [INFO] Iteration 473: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.17%
# [INFO] Predicted last sample of window: Actual=46.94, Pred=45.92, MAPE=2.17%
#
# [INFO] Iteration 474: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.04%
# [INFO] Predicted last sample of window: Actual=46.10, Pred=46.11, MAPE=0.04%
#
# [INFO] Iteration 475: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.51%
# [INFO] Predicted last sample of window: Actual=42.20, Pred=44.10, MAPE=4.51%
#
# [INFO] Iteration 476: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.65%
# [INFO] Predicted last sample of window: Actual=41.39, Pred=42.07, MAPE=1.65%
#
# [INFO] Iteration 477: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.04%
# [INFO] Predicted last sample of window: Actual=43.66, Pred=41.46, MAPE=5.04%
#
# [INFO] Iteration 478: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.88%
# [INFO] Predicted last sample of window: Actual=40.33, Pred=41.89, MAPE=3.88%
#
# [INFO] Iteration 479: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.69%
# [INFO] Predicted last sample of window: Actual=41.16, Pred=40.88, MAPE=0.69%
#
# [INFO] Iteration 480: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.77%
# [INFO] Predicted last sample of window: Actual=42.33, Pred=40.73, MAPE=3.77%
#
# [INFO] Iteration 481: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.33%
# [INFO] Predicted last sample of window: Actual=45.01, Pred=44.86, MAPE=0.33%
#
# [INFO] Iteration 482: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.78%
# [INFO] Predicted last sample of window: Actual=45.96, Pred=45.14, MAPE=1.78%
#
# [INFO] Iteration 483: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.01%
# [INFO] Predicted last sample of window: Actual=46.95, Pred=46.01, MAPE=2.01%
#
# [INFO] Iteration 484: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.99%
# [INFO] Predicted last sample of window: Actual=48.62, Pred=47.17, MAPE=2.99%
#
# [INFO] Iteration 485: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.15%
# [INFO] Predicted last sample of window: Actual=48.89, Pred=48.82, MAPE=0.15%
#
# [INFO] Iteration 486: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.09%
# [INFO] Predicted last sample of window: Actual=49.30, Pred=49.34, MAPE=0.09%
#
# [INFO] Iteration 487: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.77%
# [INFO] Predicted last sample of window: Actual=49.94, Pred=49.56, MAPE=0.77%
#
# [INFO] Iteration 488: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.79%
# [INFO] Predicted last sample of window: Actual=47.78, Pred=49.11, MAPE=2.79%
#
# [INFO] Iteration 489: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.99%
# [INFO] Predicted last sample of window: Actual=47.82, Pred=48.29, MAPE=0.99%
#
# [INFO] Iteration 490: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.34%
# [INFO] Predicted last sample of window: Actual=46.77, Pred=47.86, MAPE=2.34%
#
# [INFO] Iteration 491: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.47%
# [INFO] Predicted last sample of window: Actual=45.51, Pred=46.63, MAPE=2.47%
#
# [INFO] Iteration 492: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.82%
# [INFO] Predicted last sample of window: Actual=45.50, Pred=46.33, MAPE=1.82%
#
# [INFO] Iteration 493: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.77%
# [INFO] Predicted last sample of window: Actual=47.51, Pred=46.66, MAPE=1.77%
#
# [INFO] Iteration 494: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.77%
# [INFO] Predicted last sample of window: Actual=47.66, Pred=46.81, MAPE=1.77%
#
# [INFO] Iteration 495: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.11%
# [INFO] Predicted last sample of window: Actual=48.35, Pred=47.81, MAPE=1.11%
#
# [INFO] Iteration 496: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.27%
# [INFO] Predicted last sample of window: Actual=50.08, Pred=48.44, MAPE=3.27%
#
# [INFO] Iteration 497: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.02%
# [INFO] Predicted last sample of window: Actual=48.11, Pred=49.08, MAPE=2.02%
#
# [INFO] Iteration 498: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.36%
# [INFO] Predicted last sample of window: Actual=48.83, Pred=49.01, MAPE=0.36%
#
# [INFO] Iteration 499: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.74%
# [INFO] Predicted last sample of window: Actual=49.42, Pred=49.05, MAPE=0.74%
#
# [INFO] Iteration 500: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.14%
# [INFO] Predicted last sample of window: Actual=49.52, Pred=49.45, MAPE=0.14%
# [INFO] No more windows can be extracted.
#
# [INFO] Rolling training with Early Stopping completed for NVDA. Overall MAPE: 2.37%
# [INFO] Total elapsed time: 1222.09s
# [INFO] Top 10 worst predictions in rolling scenario (Early Stopping):
#           Date     Actual  Predicted       MAPE
# 424 2023-05-24  37.980000  31.039837  18.273204
# 25  2020-03-24   6.140500   5.435560  11.480178
# 229 2021-11-03  29.801001  26.522100  11.002651
# 392 2023-02-22  23.664000  21.348066   9.786736
# 283 2022-04-08  21.917000  24.054884   9.754456
# 317 2022-07-19  17.806999  16.108162   9.540278
# 300 2022-05-27  18.672001  20.418451   9.353312
# 203 2021-08-20  21.958000  19.911388   9.320575
# 357 2022-11-09  15.750000  14.325315   9.045622
# 304 2022-06-09  16.974001  18.494543   8.958066

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import talib
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os
import math
import time

########################
# Configuration
########################

stocks = [
    'COST', 'UL', 'AMGN', 'UNH', 'WAT', 'UPS', 'LPX', 'WM', 'NVDA',
    'GOOGL', 'MSFT', 'AXP', 'BLK', 'BRK-B', 'NEE', 'XOM', 'CNI'
]

start_date = '2020-01-01'
end_date = '2024-01-01'

# Hyperparameters
n_steps = 2
window_size = 5
step_size = 2
initial_epochs = 100
update_epochs = 100
initial_lr = 0.0005
update_lr = 0.00005
train_ratio = 0.9
n_units = 16
batch_size = 4

if not os.path.exists("rolling_error_analysis_results"):
    os.makedirs("rolling_error_analysis_results")

def load_full_data_helper(ticker, start_date, end_date, window_size):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None

    # Next day prediction setup
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values

    if len(dates) < window_size:
        return None, None, None
    return X_feat.values, y_raw, dates

def load_full_data(ticker, start_date, end_date, window_size):
    X_feat, y_raw, dates = load_full_data_helper(ticker, start_date, end_date, window_size)
    if X_feat is None:
        return None, None, None
    return X_feat, y_raw, dates

def extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None, None, None, None

    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]

    def lstm_split(dataX, dataY, n_steps):
        X, y = [], []
        for i in range(len(dataX)-n_steps+1):
            X.append(dataX[i:i+n_steps])
            y.append(dataY[i+n_steps-1])
        return np.array(X), np.array(y)

    X_samples, y_samples = lstm_split(X_window, y_window, n_steps)
    sample_dates = dates_window[n_steps-1:]

    feat_scaler = RobustScaler()
    target_scaler = RobustScaler()
    X_flat = X_window.reshape(len(X_window), -1)
    feat_scaler.fit(X_flat)
    y_window_reshaped = y_window.reshape(-1,1)
    target_scaler.fit(y_window_reshaped)

    X_scaled = feat_scaler.transform(X_flat).reshape(X_window.shape)
    y_scaled = target_scaler.transform(y_window_reshaped).flatten()
    X_samples_scaled, y_samples_scaled = lstm_split(X_scaled, y_scaled, n_steps)

    return X_samples_scaled, y_samples_scaled, sample_dates, feat_scaler, target_scaler, (X_window, y_window, dates_window)

def create_lstm_model(n_units, learning_rate, n_steps, n_features, n_layers=1):
    inputs = Input(shape=(n_steps, n_features))
    x = LSTM(n_units, activation='relu', return_sequences=(n_layers > 1))(inputs)
    if n_layers > 1:
        x = LSTM(n_units, activation='relu')(x)
    outputs = Dense(1)(x)
    model = Model(inputs, outputs)
    return model

def train_on_window(X_samples, y_samples, feat_scaler, target_scaler,
                    initial_training=False, prev_weights=None):
    total_samples = len(X_samples)
    global train_ratio
    train_count = int(math.floor(total_samples * train_ratio))
    if train_count >= total_samples:
        train_count = total_samples - 1

    X_train, y_train = X_samples[:train_count], y_samples[:train_count]
    X_val, y_val = X_samples[train_count:], y_samples[train_count:]

    if X_train.size == 0 or X_val.size == 0:
        return None, np.nan

    n_steps_local = X_train.shape[1]
    n_features = X_train.shape[2]

    if initial_training:
        epochs = initial_epochs
        lr = initial_lr
    else:
        epochs = update_epochs
        lr = update_lr

    model = create_lstm_model(n_units, lr, n_steps_local, n_features, n_layers=1)

    if prev_weights is not None:
        model.load_weights(prev_weights)

    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=lr))

    es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0, shuffle=False,
              validation_data=(X_val, y_val), callbacks=[es])

    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_unscaled = target_scaler.inverse_transform(y_val.reshape(-1,1)).flatten()
    y_val_pred_unscaled = target_scaler.inverse_transform(y_val_pred_scaled).flatten()
    val_mape = mean_absolute_percentage_error(y_val_unscaled, y_val_pred_unscaled) * 100

    return model, val_mape

def rolling_training_early_stopping(ticker, window_size, step_size, n_steps):
    X_full, y_full, dates_full = load_full_data(ticker, start_date, end_date, window_size)
    if X_full is None:
        print(f"[WARN] Not enough data for {ticker}.")
        return None

    start_time = time.time()

    start_idx = 0
    window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
    if window_data[0] is None:
        print(f"[WARN] Initial window not valid for {ticker}.")
        return None
    X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

    print(f"[INFO] Training initial window with Early Stopping for {ticker}...")
    model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=True, prev_weights=None)
    print(f"[RESULT] {ticker}: Initial window validation MAPE: {val_mape:.2f}%")

    weights_path = f"rolling_error_analysis_results/{ticker}_initial_es.weights.h5"
    model.save_weights(weights_path)

    predictions = []
    actuals = []
    pred_dates = []

    iteration = 1
    while True:
        start_idx += step_size
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
        if window_data[0] is None:
            print(f"[INFO] No more windows can be extracted for {ticker}.")
            break
        X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

        print(f"\n[INFO] Iteration {iteration}: {ticker}, training on new window with Early Stopping...")
        model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=weights_path)
        print(f"[RESULT] {ticker}: Window validation MAPE: {val_mape:.2f}%")

        weights_path = f"rolling_error_analysis_results/{ticker}_iteration_{iteration}_es.weights.h5"
        model.save_weights(weights_path)

        X_test_last = X_samples[-1:]
        y_test_last = y_samples[-1:]
        y_pred_scaled = model.predict(X_test_last, verbose=0)
        y_test_unscaled = target_scaler.inverse_transform(y_test_last.reshape(-1,1)).flatten()
        y_pred_unscaled = target_scaler.inverse_transform(y_pred_scaled).flatten()

        predictions.append(y_pred_unscaled[0])
        actuals.append(y_test_unscaled[0])
        pred_dates.append(sample_dates[-1])

        test_mape = mean_absolute_percentage_error(y_test_unscaled, y_pred_unscaled)*100
        print(f"[INFO] {ticker}: Predicted last sample of window: Actual={y_test_unscaled[0]:.2f}, Pred={y_pred_unscaled[0]:.2f}, MAPE={test_mape:.2f}%")

        iteration += 1

    df_results = pd.DataFrame({
        'Date': pred_dates,
        'Actual': actuals,
        'Predicted': predictions
    })
    df_results['Absolute_Error'] = np.abs(df_results['Actual'] - df_results['Predicted'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual'])
    df_results['MAPE'] = df_results['APE'] * 100.0

    df_results.to_csv(f"rolling_error_analysis_results/{ticker}_rolling_results_es.csv", index=False)
    overall_mape = df_results['MAPE'].mean()
    print(f"\n[INFO] Rolling training with Early Stopping completed for {ticker}. Overall MAPE: {overall_mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] {ticker}: Total elapsed time: {elapsed:.2f}s")

    # Return the overall MAPE so we can store it in a CSV by stock
    return overall_mape

if __name__ == "__main__":
    # Run the code for each stock and save their MAPEs to a CSV
    stock_list = [
        'COST', 'UL', 'AMGN', 'UNH', 'WAT', 'UPS', 'LPX', 'WM', 'NVDA',
        'GOOGL', 'MSFT', 'AXP', 'BLK', 'BRK-B', 'NEE', 'XOM', 'CNI'
    ]

    results = []
    for s in stock_list:
        mape = rolling_training_early_stopping(s, window_size, step_size, n_steps)
        if mape is not None:
            results.append({'Stock': s, 'Overall_MAPE': mape})
        else:
            results.append({'Stock': s, 'Overall_MAPE': np.nan})

    results_df = pd.DataFrame(results)
    results_df.to_csv('stock_mapes.csv', index=False)
    print("[INFO] All stock MAPEs saved to stock_mapes.csv")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [INFO] Training initial window with Early Stopping for COST...
# [RESULT] COST: Initial window validation MAPE: 2.51%
#
# [INFO] Iteration 1: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.98%
# [INFO] COST: Predicted last sample of window: Actual=299.87, Pred=296.94, MAPE=0.98%
#
# [INFO] Iteration 2: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.36%
# [INFO] COST: Predicted last sample of window: Actual=300.82, Pred=299.75, MAPE=0.36%
#
# [INFO] Iteration 3: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.66%
# [INFO] COST: Predicted last sample of window: Actual=304.68, Pred=299.63, MAPE=1.66%
#
# [INFO] Iteration 4: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.50%
# [INFO] COST: Predicted last sample of window: Actual=311.89, Pred=304.08, MAPE=2.50%
#
# [INFO] Iteration 5: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.50%
# [INFO] COST: Predicted last sample of window: Actual=310.51, Pred=312.06, MAPE=0.50%
#
# [INFO] Iteration 6: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.26%
# [INFO] COST: Predicted last sample of window: Actual=310.85, Pred=311.67, MAPE=0.26%
#
# [INFO] Iteration 7: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.05%
# [INFO] COST: Predicted last sample of window: Actual=309.47, Pred=309.64, MAPE=0.05%
#
# [INFO] Iteration 8: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.80%
# [INFO] COST: Predicted last sample of window: Actual=302.00, Pred=310.45, MAPE=2.80%
#
# [INFO] Iteration 9: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.82%
# [INFO] COST: Predicted last sample of window: Actual=308.95, Pred=306.42, MAPE=0.82%
#
# [INFO] Iteration 10: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.74%
# [INFO] COST: Predicted last sample of window: Actual=313.63, Pred=308.18, MAPE=1.74%
#
# [INFO] Iteration 11: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.04%
# [INFO] COST: Predicted last sample of window: Actual=310.68, Pred=310.55, MAPE=0.04%
#
# [INFO] Iteration 12: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.37%
# [INFO] COST: Predicted last sample of window: Actual=318.20, Pred=313.86, MAPE=1.37%
#
# [INFO] Iteration 13: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.18%
# [INFO] COST: Predicted last sample of window: Actual=322.05, Pred=318.25, MAPE=1.18%
#
# [INFO] Iteration 14: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.67%
# [INFO] COST: Predicted last sample of window: Actual=324.08, Pred=321.92, MAPE=0.67%
#
# [INFO] Iteration 15: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.70%
# [INFO] COST: Predicted last sample of window: Actual=313.62, Pred=322.07, MAPE=2.70%
#
# [INFO] Iteration 16: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 3.53%
# [INFO] COST: Predicted last sample of window: Actual=305.69, Pred=316.48, MAPE=3.53%
#
# [INFO] Iteration 17: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 8.48%
# [INFO] COST: Predicted last sample of window: Actual=281.14, Pred=304.99, MAPE=8.48%
#
# [INFO] Iteration 18: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.55%
# [INFO] COST: Predicted last sample of window: Actual=302.73, Pred=304.38, MAPE=0.55%
#
# [INFO] Iteration 19: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.11%
# [INFO] COST: Predicted last sample of window: Actual=315.76, Pred=309.09, MAPE=2.11%
#
# [INFO] Iteration 20: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 3.30%
# [INFO] COST: Predicted last sample of window: Actual=301.98, Pred=311.95, MAPE=3.30%
#
# [INFO] Iteration 21: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 4.09%
# [INFO] COST: Predicted last sample of window: Actual=297.43, Pred=309.60, MAPE=4.09%
#
# [INFO] Iteration 22: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.70%
# [INFO] COST: Predicted last sample of window: Actual=302.27, Pred=304.40, MAPE=0.70%
#
# [INFO] Iteration 23: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.88%
# [INFO] COST: Predicted last sample of window: Actual=306.99, Pred=298.16, MAPE=2.88%
#
# [INFO] Iteration 24: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.02%
# [INFO] COST: Predicted last sample of window: Actual=305.22, Pred=305.15, MAPE=0.02%
#
# [INFO] Iteration 25: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 6.88%
# [INFO] COST: Predicted last sample of window: Actual=285.53, Pred=305.18, MAPE=6.88%
#
# [INFO] Iteration 26: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.79%
# [INFO] COST: Predicted last sample of window: Actual=280.86, Pred=285.89, MAPE=1.79%
#
# [INFO] Iteration 27: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.22%
# [INFO] COST: Predicted last sample of window: Actual=284.33, Pred=284.95, MAPE=0.22%
#
# [INFO] Iteration 28: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.17%
# [INFO] COST: Predicted last sample of window: Actual=285.13, Pred=285.62, MAPE=0.17%
#
# [INFO] Iteration 29: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.50%
# [INFO] COST: Predicted last sample of window: Actual=291.48, Pred=287.10, MAPE=1.50%
#
# [INFO] Iteration 30: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 5.42%
# [INFO] COST: Predicted last sample of window: Actual=305.12, Pred=288.59, MAPE=5.42%
#
# [INFO] Iteration 31: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.79%
# [INFO] COST: Predicted last sample of window: Actual=305.97, Pred=303.57, MAPE=0.79%
#
# [INFO] Iteration 32: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.37%
# [INFO] COST: Predicted last sample of window: Actual=299.62, Pred=303.71, MAPE=1.37%
#
# [INFO] Iteration 33: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.28%
# [INFO] COST: Predicted last sample of window: Actual=310.27, Pred=306.30, MAPE=1.28%
#
# [INFO] Iteration 34: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.20%
# [INFO] COST: Predicted last sample of window: Actual=317.92, Pred=314.12, MAPE=1.20%
#
# [INFO] Iteration 35: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 3.67%
# [INFO] COST: Predicted last sample of window: Actual=301.33, Pred=312.38, MAPE=3.67%
#
# [INFO] Iteration 36: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.38%
# [INFO] COST: Predicted last sample of window: Actual=305.40, Pred=309.61, MAPE=1.38%
#
# [INFO] Iteration 37: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.07%
# [INFO] COST: Predicted last sample of window: Actual=308.78, Pred=308.98, MAPE=0.07%
#
# [INFO] Iteration 38: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.10%
# [INFO] COST: Predicted last sample of window: Actual=307.09, Pred=306.77, MAPE=0.10%
#
# [INFO] Iteration 39: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.11%
# [INFO] COST: Predicted last sample of window: Actual=301.92, Pred=305.27, MAPE=1.11%
#
# [INFO] Iteration 40: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.13%
# [INFO] COST: Predicted last sample of window: Actual=307.92, Pred=304.46, MAPE=1.13%
#
# [INFO] Iteration 41: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.00%
# [INFO] COST: Predicted last sample of window: Actual=305.00, Pred=304.99, MAPE=0.00%
#
# [INFO] Iteration 42: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.73%
# [INFO] COST: Predicted last sample of window: Actual=310.33, Pred=308.08, MAPE=0.73%
#
# [INFO] Iteration 43: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.95%
# [INFO] COST: Predicted last sample of window: Actual=302.14, Pred=305.02, MAPE=0.95%
#
# [INFO] Iteration 44: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.67%
# [INFO] COST: Predicted last sample of window: Actual=299.21, Pred=301.22, MAPE=0.67%
#
# [INFO] Iteration 45: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.75%
# [INFO] COST: Predicted last sample of window: Actual=304.63, Pred=302.35, MAPE=0.75%
#
# [INFO] Iteration 46: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.25%
# [INFO] COST: Predicted last sample of window: Actual=301.97, Pred=302.73, MAPE=0.25%
#
# [INFO] Iteration 47: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.04%
# [INFO] COST: Predicted last sample of window: Actual=304.80, Pred=304.67, MAPE=0.04%
#
# [INFO] Iteration 48: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.48%
# [INFO] COST: Predicted last sample of window: Actual=309.56, Pred=304.98, MAPE=1.48%
#
# [INFO] Iteration 49: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.03%
# [INFO] COST: Predicted last sample of window: Actual=308.29, Pred=308.21, MAPE=0.03%
#
# [INFO] Iteration 50: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.55%
# [INFO] COST: Predicted last sample of window: Actual=306.64, Pred=308.32, MAPE=0.55%
#
# [INFO] Iteration 51: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.68%
# [INFO] COST: Predicted last sample of window: Actual=312.04, Pred=306.81, MAPE=1.68%
#
# [INFO] Iteration 52: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.54%
# [INFO] COST: Predicted last sample of window: Actual=305.55, Pred=307.19, MAPE=0.54%
#
# [INFO] Iteration 53: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.09%
# [INFO] COST: Predicted last sample of window: Actual=300.83, Pred=307.13, MAPE=2.09%
#
# [INFO] Iteration 54: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.64%
# [INFO] COST: Predicted last sample of window: Actual=297.18, Pred=299.09, MAPE=0.64%
#
# [INFO] Iteration 55: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.02%
# [INFO] COST: Predicted last sample of window: Actual=299.61, Pred=299.68, MAPE=0.02%
#
# [INFO] Iteration 56: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.09%
# [INFO] COST: Predicted last sample of window: Actual=299.90, Pred=299.62, MAPE=0.09%
#
# [INFO] Iteration 57: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.44%
# [INFO] COST: Predicted last sample of window: Actual=301.29, Pred=299.96, MAPE=0.44%
#
# [INFO] Iteration 58: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.04%
# [INFO] COST: Predicted last sample of window: Actual=300.53, Pred=300.42, MAPE=0.04%
#
# [INFO] Iteration 59: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.37%
# [INFO] COST: Predicted last sample of window: Actual=301.59, Pred=300.49, MAPE=0.37%
#
# [INFO] Iteration 60: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.08%
# [INFO] COST: Predicted last sample of window: Actual=304.75, Pred=301.45, MAPE=1.08%
#
# [INFO] Iteration 61: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.18%
# [INFO] COST: Predicted last sample of window: Actual=311.49, Pred=304.69, MAPE=2.18%
#
# [INFO] Iteration 62: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.58%
# [INFO] COST: Predicted last sample of window: Actual=316.32, Pred=311.33, MAPE=1.58%
#
# [INFO] Iteration 63: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.96%
# [INFO] COST: Predicted last sample of window: Actual=326.23, Pred=316.58, MAPE=2.96%
#
# [INFO] Iteration 64: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.69%
# [INFO] COST: Predicted last sample of window: Actual=328.00, Pred=325.74, MAPE=0.69%
#
# [INFO] Iteration 65: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.00%
# [INFO] COST: Predicted last sample of window: Actual=326.27, Pred=326.29, MAPE=0.00%
#
# [INFO] Iteration 66: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.01%
# [INFO] COST: Predicted last sample of window: Actual=326.51, Pred=326.54, MAPE=0.01%
#
# [INFO] Iteration 67: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.56%
# [INFO] COST: Predicted last sample of window: Actual=328.30, Pred=326.46, MAPE=0.56%
#
# [INFO] Iteration 68: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.26%
# [INFO] COST: Predicted last sample of window: Actual=325.78, Pred=326.63, MAPE=0.26%
#
# [INFO] Iteration 69: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.00%
# [INFO] COST: Predicted last sample of window: Actual=327.57, Pred=327.57, MAPE=0.00%
#
# [INFO] Iteration 70: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.37%
# [INFO] COST: Predicted last sample of window: Actual=324.82, Pred=326.03, MAPE=0.37%
#
# [INFO] Iteration 71: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.99%
# [INFO] COST: Predicted last sample of window: Actual=329.32, Pred=326.06, MAPE=0.99%
#
# [INFO] Iteration 72: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 3.39%
# [INFO] COST: Predicted last sample of window: Actual=339.97, Pred=328.43, MAPE=3.39%
#
# [INFO] Iteration 73: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.26%
# [INFO] COST: Predicted last sample of window: Actual=340.91, Pred=340.01, MAPE=0.26%
#
# [INFO] Iteration 74: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.27%
# [INFO] COST: Predicted last sample of window: Actual=332.43, Pred=339.99, MAPE=2.27%
#
# [INFO] Iteration 75: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.04%
# [INFO] COST: Predicted last sample of window: Actual=335.70, Pred=335.85, MAPE=0.04%
#
# [INFO] Iteration 76: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.08%
# [INFO] COST: Predicted last sample of window: Actual=339.96, Pred=336.30, MAPE=1.08%
#
# [INFO] Iteration 77: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.17%
# [INFO] COST: Predicted last sample of window: Actual=340.90, Pred=340.32, MAPE=0.17%
#
# [INFO] Iteration 78: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.08%
# [INFO] COST: Predicted last sample of window: Actual=344.61, Pred=340.87, MAPE=1.08%
#
# [INFO] Iteration 79: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.00%
# [INFO] COST: Predicted last sample of window: Actual=344.71, Pred=344.71, MAPE=0.00%
#
# [INFO] Iteration 80: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.50%
# [INFO] COST: Predicted last sample of window: Actual=346.36, Pred=344.62, MAPE=0.50%
#
# [INFO] Iteration 81: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.15%
# [INFO] COST: Predicted last sample of window: Actual=347.66, Pred=347.15, MAPE=0.15%
#
# [INFO] Iteration 82: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.84%
# [INFO] COST: Predicted last sample of window: Actual=358.86, Pred=348.67, MAPE=2.84%
#
# [INFO] Iteration 83: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 5.33%
# [INFO] COST: Predicted last sample of window: Actual=346.57, Pred=328.10, MAPE=5.33%
#
# [INFO] Iteration 84: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.00%
# [INFO] COST: Predicted last sample of window: Actual=346.43, Pred=346.44, MAPE=0.00%
#
# [INFO] Iteration 85: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.14%
# [INFO] COST: Predicted last sample of window: Actual=339.13, Pred=339.61, MAPE=0.14%
#
# [INFO] Iteration 86: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.19%
# [INFO] COST: Predicted last sample of window: Actual=343.91, Pred=343.25, MAPE=0.19%
#
# [INFO] Iteration 87: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.29%
# [INFO] COST: Predicted last sample of window: Actual=338.88, Pred=343.26, MAPE=1.29%
#
# [INFO] Iteration 88: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.00%
# [INFO] COST: Predicted last sample of window: Actual=339.57, Pred=339.57, MAPE=0.00%
#
# [INFO] Iteration 89: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.67%
# [INFO] COST: Predicted last sample of window: Actual=344.63, Pred=338.87, MAPE=1.67%
#
# [INFO] Iteration 90: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.59%
# [INFO] COST: Predicted last sample of window: Actual=342.58, Pred=344.60, MAPE=0.59%
#
# [INFO] Iteration 91: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.39%
# [INFO] COST: Predicted last sample of window: Actual=352.14, Pred=347.24, MAPE=1.39%
#
# [INFO] Iteration 92: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.61%
# [INFO] COST: Predicted last sample of window: Actual=358.46, Pred=352.69, MAPE=1.61%
#
# [INFO] Iteration 93: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.93%
# [INFO] COST: Predicted last sample of window: Actual=358.58, Pred=355.25, MAPE=0.93%
#
# [INFO] Iteration 94: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.25%
# [INFO] COST: Predicted last sample of window: Actual=363.02, Pred=358.49, MAPE=1.25%
#
# [INFO] Iteration 95: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.54%
# [INFO] COST: Predicted last sample of window: Actual=369.46, Pred=363.76, MAPE=1.54%
#
# [INFO] Iteration 96: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.39%
# [INFO] COST: Predicted last sample of window: Actual=380.68, Pred=371.58, MAPE=2.39%
#
# [INFO] Iteration 97: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.07%
# [INFO] COST: Predicted last sample of window: Actual=376.58, Pred=376.85, MAPE=0.07%
#
# [INFO] Iteration 98: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.84%
# [INFO] COST: Predicted last sample of window: Actual=375.56, Pred=378.71, MAPE=0.84%
#
# [INFO] Iteration 99: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.01%
# [INFO] COST: Predicted last sample of window: Actual=377.82, Pred=377.84, MAPE=0.01%
#
# [INFO] Iteration 100: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.27%
# [INFO] COST: Predicted last sample of window: Actual=374.60, Pred=375.60, MAPE=0.27%
#
# [INFO] Iteration 101: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.01%
# [INFO] COST: Predicted last sample of window: Actual=372.72, Pred=372.75, MAPE=0.01%
#
# [INFO] Iteration 102: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.55%
# [INFO] COST: Predicted last sample of window: Actual=364.86, Pred=370.51, MAPE=1.55%
#
# [INFO] Iteration 103: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.05%
# [INFO] COST: Predicted last sample of window: Actual=364.39, Pred=364.59, MAPE=0.05%
#
# [INFO] Iteration 104: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.75%
# [INFO] COST: Predicted last sample of window: Actual=376.17, Pred=365.84, MAPE=2.75%
#
# [INFO] Iteration 105: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.84%
# [INFO] COST: Predicted last sample of window: Actual=385.66, Pred=378.58, MAPE=1.84%
#
# [INFO] Iteration 106: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 3.13%
# [INFO] COST: Predicted last sample of window: Actual=366.62, Pred=378.08, MAPE=3.13%
#
# [INFO] Iteration 107: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.34%
# [INFO] COST: Predicted last sample of window: Actual=375.71, Pred=370.66, MAPE=1.34%
#
# [INFO] Iteration 108: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.91%
# [INFO] COST: Predicted last sample of window: Actual=379.79, Pred=376.33, MAPE=0.91%
#
# [INFO] Iteration 109: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.03%
# [INFO] COST: Predicted last sample of window: Actual=382.23, Pred=382.34, MAPE=0.03%
#
# [INFO] Iteration 110: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.22%
# [INFO] COST: Predicted last sample of window: Actual=381.12, Pred=381.96, MAPE=0.22%
#
# [INFO] Iteration 111: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.54%
# [INFO] COST: Predicted last sample of window: Actual=384.22, Pred=382.14, MAPE=0.54%
#
# [INFO] Iteration 112: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.22%
# [INFO] COST: Predicted last sample of window: Actual=388.39, Pred=393.11, MAPE=1.22%
#
# [INFO] Iteration 113: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.07%
# [INFO] COST: Predicted last sample of window: Actual=387.56, Pred=387.83, MAPE=0.07%
#
# [INFO] Iteration 114: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 3.54%
# [INFO] COST: Predicted last sample of window: Actual=374.05, Pred=387.28, MAPE=3.54%
#
# [INFO] Iteration 115: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.55%
# [INFO] COST: Predicted last sample of window: Actual=373.33, Pred=371.27, MAPE=0.55%
#
# [INFO] Iteration 116: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.07%
# [INFO] COST: Predicted last sample of window: Actual=374.29, Pred=374.02, MAPE=0.07%
#
# [INFO] Iteration 117: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.16%
# [INFO] COST: Predicted last sample of window: Actual=375.10, Pred=374.49, MAPE=0.16%
#
# [INFO] Iteration 118: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.69%
# [INFO] COST: Predicted last sample of window: Actual=371.88, Pred=374.45, MAPE=0.69%
#
# [INFO] Iteration 119: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.29%
# [INFO] COST: Predicted last sample of window: Actual=370.29, Pred=371.36, MAPE=0.29%
#
# [INFO] Iteration 120: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.16%
# [INFO] COST: Predicted last sample of window: Actual=364.97, Pred=369.19, MAPE=1.16%
#
# [INFO] Iteration 121: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.49%
# [INFO] COST: Predicted last sample of window: Actual=361.89, Pred=363.67, MAPE=0.49%
#
# [INFO] Iteration 122: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.88%
# [INFO] COST: Predicted last sample of window: Actual=371.06, Pred=364.10, MAPE=1.88%
#
# [INFO] Iteration 123: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.15%
# [INFO] COST: Predicted last sample of window: Actual=374.45, Pred=373.89, MAPE=0.15%
#
# [INFO] Iteration 124: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.41%
# [INFO] COST: Predicted last sample of window: Actual=380.15, Pred=374.77, MAPE=1.41%
#
# [INFO] Iteration 125: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.65%
# [INFO] COST: Predicted last sample of window: Actual=370.02, Pred=376.13, MAPE=1.65%
#
# [INFO] Iteration 126: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.33%
# [INFO] COST: Predicted last sample of window: Actual=369.94, Pred=368.74, MAPE=0.33%
#
# [INFO] Iteration 127: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.81%
# [INFO] COST: Predicted last sample of window: Actual=364.20, Pred=367.16, MAPE=0.81%
#
# [INFO] Iteration 128: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.18%
# [INFO] COST: Predicted last sample of window: Actual=362.35, Pred=363.01, MAPE=0.18%
#
# [INFO] Iteration 129: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.15%
# [INFO] COST: Predicted last sample of window: Actual=354.47, Pred=362.10, MAPE=2.15%
#
# [INFO] Iteration 130: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.27%
# [INFO] COST: Predicted last sample of window: Actual=362.80, Pred=361.82, MAPE=0.27%
#
# [INFO] Iteration 131: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.02%
# [INFO] COST: Predicted last sample of window: Actual=361.88, Pred=361.95, MAPE=0.02%
#
# [INFO] Iteration 132: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.65%
# [INFO] COST: Predicted last sample of window: Actual=356.39, Pred=362.26, MAPE=1.65%
#
# [INFO] Iteration 133: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.17%
# [INFO] COST: Predicted last sample of window: Actual=352.43, Pred=356.55, MAPE=1.17%
#
# [INFO] Iteration 134: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.29%
# [INFO] COST: Predicted last sample of window: Actual=355.58, Pred=354.53, MAPE=0.29%
#
# [INFO] Iteration 135: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.16%
# [INFO] COST: Predicted last sample of window: Actual=355.85, Pred=355.29, MAPE=0.16%
#
# [INFO] Iteration 136: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.17%
# [INFO] COST: Predicted last sample of window: Actual=359.83, Pred=355.60, MAPE=1.17%
#
# [INFO] Iteration 137: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.67%
# [INFO] COST: Predicted last sample of window: Actual=356.12, Pred=358.51, MAPE=0.67%
#
# [INFO] Iteration 138: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.79%
# [INFO] COST: Predicted last sample of window: Actual=352.75, Pred=355.54, MAPE=0.79%
#
# [INFO] Iteration 139: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.20%
# [INFO] COST: Predicted last sample of window: Actual=358.04, Pred=353.74, MAPE=1.20%
#
# [INFO] Iteration 140: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.02%
# [INFO] COST: Predicted last sample of window: Actual=354.77, Pred=354.84, MAPE=0.02%
#
# [INFO] Iteration 141: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.04%
# [INFO] COST: Predicted last sample of window: Actual=342.15, Pred=349.12, MAPE=2.04%
#
# [INFO] Iteration 142: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.76%
# [INFO] COST: Predicted last sample of window: Actual=333.90, Pred=336.43, MAPE=0.76%
#
# [INFO] Iteration 143: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.22%
# [INFO] COST: Predicted last sample of window: Actual=331.77, Pred=332.51, MAPE=0.22%
#
# [INFO] Iteration 144: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.09%
# [INFO] COST: Predicted last sample of window: Actual=323.92, Pred=330.69, MAPE=2.09%
#
# [INFO] Iteration 145: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.43%
# [INFO] COST: Predicted last sample of window: Actual=317.32, Pred=318.69, MAPE=0.43%
#
# [INFO] Iteration 146: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.13%
# [INFO] COST: Predicted last sample of window: Actual=318.78, Pred=318.38, MAPE=0.13%
#
# [INFO] Iteration 147: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.77%
# [INFO] COST: Predicted last sample of window: Actual=328.65, Pred=319.55, MAPE=2.77%
#
# [INFO] Iteration 148: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.13%
# [INFO] COST: Predicted last sample of window: Actual=330.51, Pred=330.07, MAPE=0.13%
#
# [INFO] Iteration 149: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.03%
# [INFO] COST: Predicted last sample of window: Actual=329.19, Pred=329.30, MAPE=0.03%
#
# [INFO] Iteration 150: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.19%
# [INFO] COST: Predicted last sample of window: Actual=328.91, Pred=328.27, MAPE=0.19%
#
# [INFO] Iteration 151: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.93%
# [INFO] COST: Predicted last sample of window: Actual=340.34, Pred=330.36, MAPE=2.93%
#
# [INFO] Iteration 152: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.97%
# [INFO] COST: Predicted last sample of window: Actual=346.34, Pred=339.52, MAPE=1.97%
#
# [INFO] Iteration 153: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.53%
# [INFO] COST: Predicted last sample of window: Actual=356.15, Pred=350.70, MAPE=1.53%
#
# [INFO] Iteration 154: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.01%
# [INFO] COST: Predicted last sample of window: Actual=352.48, Pred=352.50, MAPE=0.01%
#
# [INFO] Iteration 155: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.46%
# [INFO] COST: Predicted last sample of window: Actual=360.82, Pred=355.57, MAPE=1.46%
#
# [INFO] Iteration 156: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.37%
# [INFO] COST: Predicted last sample of window: Actual=358.81, Pred=360.13, MAPE=0.37%
#
# [INFO] Iteration 157: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.59%
# [INFO] COST: Predicted last sample of window: Actual=363.21, Pred=361.08, MAPE=0.59%
#
# [INFO] Iteration 158: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.03%
# [INFO] COST: Predicted last sample of window: Actual=365.21, Pred=365.12, MAPE=0.03%
#
# [INFO] Iteration 159: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.95%
# [INFO] COST: Predicted last sample of window: Actual=368.80, Pred=365.28, MAPE=0.95%
#
# [INFO] Iteration 160: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.76%
# [INFO] COST: Predicted last sample of window: Actual=369.55, Pred=372.37, MAPE=0.76%
#
# [INFO] Iteration 161: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.84%
# [INFO] COST: Predicted last sample of window: Actual=374.09, Pred=370.96, MAPE=0.84%
#
# [INFO] Iteration 162: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.18%
# [INFO] COST: Predicted last sample of window: Actual=373.28, Pred=372.61, MAPE=0.18%
#
# [INFO] Iteration 163: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.33%
# [INFO] COST: Predicted last sample of window: Actual=370.21, Pred=371.42, MAPE=0.33%
#
# [INFO] Iteration 164: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.12%
# [INFO] COST: Predicted last sample of window: Actual=373.54, Pred=369.34, MAPE=1.12%
#
# [INFO] Iteration 165: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.37%
# [INFO] COST: Predicted last sample of window: Actual=379.32, Pred=377.93, MAPE=0.37%
#
# [INFO] Iteration 166: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.40%
# [INFO] COST: Predicted last sample of window: Actual=372.50, Pred=373.98, MAPE=0.40%
#
# [INFO] Iteration 167: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.10%
# [INFO] COST: Predicted last sample of window: Actual=384.32, Pred=380.08, MAPE=1.10%
#
# [INFO] Iteration 168: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.15%
# [INFO] COST: Predicted last sample of window: Actual=378.18, Pred=382.54, MAPE=1.15%
#
# [INFO] Iteration 169: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.09%
# [INFO] COST: Predicted last sample of window: Actual=379.53, Pred=379.20, MAPE=0.09%
#
# [INFO] Iteration 170: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.13%
# [INFO] COST: Predicted last sample of window: Actual=383.96, Pred=379.64, MAPE=1.13%
#
# [INFO] Iteration 171: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.97%
# [INFO] COST: Predicted last sample of window: Actual=379.66, Pred=383.34, MAPE=0.97%
#
# [INFO] Iteration 172: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.35%
# [INFO] COST: Predicted last sample of window: Actual=380.72, Pred=382.05, MAPE=0.35%
#
# [INFO] Iteration 173: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.43%
# [INFO] COST: Predicted last sample of window: Actual=385.38, Pred=383.73, MAPE=0.43%
#
# [INFO] Iteration 174: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.34%
# [INFO] COST: Predicted last sample of window: Actual=387.50, Pred=386.18, MAPE=0.34%
#
# [INFO] Iteration 175: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.69%
# [INFO] COST: Predicted last sample of window: Actual=378.23, Pred=384.64, MAPE=1.69%
#
# [INFO] Iteration 176: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.14%
# [INFO] COST: Predicted last sample of window: Actual=383.87, Pred=379.50, MAPE=1.14%
#
# [INFO] Iteration 177: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.59%
# [INFO] COST: Predicted last sample of window: Actual=380.40, Pred=382.64, MAPE=0.59%
#
# [INFO] Iteration 178: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.14%
# [INFO] COST: Predicted last sample of window: Actual=379.96, Pred=380.47, MAPE=0.14%
#
# [INFO] Iteration 179: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.32%
# [INFO] COST: Predicted last sample of window: Actual=381.83, Pred=380.60, MAPE=0.32%
#
# [INFO] Iteration 180: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.08%
# [INFO] COST: Predicted last sample of window: Actual=383.91, Pred=383.60, MAPE=0.08%
#
# [INFO] Iteration 181: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.16%
# [INFO] COST: Predicted last sample of window: Actual=384.75, Pred=384.13, MAPE=0.16%
#
# [INFO] Iteration 182: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.63%
# [INFO] COST: Predicted last sample of window: Actual=386.80, Pred=384.37, MAPE=0.63%
#
# [INFO] Iteration 183: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.00%
# [INFO] COST: Predicted last sample of window: Actual=391.97, Pred=391.97, MAPE=0.00%
#
# [INFO] Iteration 184: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.61%
# [INFO] COST: Predicted last sample of window: Actual=394.51, Pred=392.11, MAPE=0.61%
#
# [INFO] Iteration 185: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.66%
# [INFO] COST: Predicted last sample of window: Actual=398.79, Pred=396.15, MAPE=0.66%
#
# [INFO] Iteration 186: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.40%
# [INFO] COST: Predicted last sample of window: Actual=394.53, Pred=396.09, MAPE=0.40%
#
# [INFO] Iteration 187: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.05%
# [INFO] COST: Predicted last sample of window: Actual=398.86, Pred=399.06, MAPE=0.05%
#
# [INFO] Iteration 188: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.51%
# [INFO] COST: Predicted last sample of window: Actual=407.15, Pred=400.98, MAPE=1.51%
#
# [INFO] Iteration 189: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.09%
# [INFO] COST: Predicted last sample of window: Actual=407.88, Pred=408.23, MAPE=0.09%
#
# [INFO] Iteration 190: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.41%
# [INFO] COST: Predicted last sample of window: Actual=409.95, Pred=408.26, MAPE=0.41%
#
# [INFO] Iteration 191: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.01%
# [INFO] COST: Predicted last sample of window: Actual=410.37, Pred=410.42, MAPE=0.01%
#
# [INFO] Iteration 192: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.85%
# [INFO] COST: Predicted last sample of window: Actual=416.24, Pred=412.69, MAPE=0.85%
#
# [INFO] Iteration 193: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.45%
# [INFO] COST: Predicted last sample of window: Actual=417.54, Pred=415.64, MAPE=0.45%
#
# [INFO] Iteration 194: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.31%
# [INFO] COST: Predicted last sample of window: Actual=423.23, Pred=421.90, MAPE=0.31%
#
# [INFO] Iteration 195: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.33%
# [INFO] COST: Predicted last sample of window: Actual=422.22, Pred=423.60, MAPE=0.33%
#
# [INFO] Iteration 196: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.15%
# [INFO] COST: Predicted last sample of window: Actual=429.72, Pred=424.77, MAPE=1.15%
#
# [INFO] Iteration 197: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.07%
# [INFO] COST: Predicted last sample of window: Actual=435.07, Pred=430.42, MAPE=1.07%
#
# [INFO] Iteration 198: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.32%
# [INFO] COST: Predicted last sample of window: Actual=443.19, Pred=437.33, MAPE=1.32%
#
# [INFO] Iteration 199: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.08%
# [INFO] COST: Predicted last sample of window: Actual=440.47, Pred=440.84, MAPE=0.08%
#
# [INFO] Iteration 200: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.14%
# [INFO] COST: Predicted last sample of window: Actual=444.30, Pred=443.66, MAPE=0.14%
#
# [INFO] Iteration 201: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.68%
# [INFO] COST: Predicted last sample of window: Actual=447.82, Pred=444.76, MAPE=0.68%
#
# [INFO] Iteration 202: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.24%
# [INFO] COST: Predicted last sample of window: Actual=452.34, Pred=451.27, MAPE=0.24%
#
# [INFO] Iteration 203: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.07%
# [INFO] COST: Predicted last sample of window: Actual=454.26, Pred=453.93, MAPE=0.07%
#
# [INFO] Iteration 204: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.03%
# [INFO] COST: Predicted last sample of window: Actual=454.93, Pred=455.05, MAPE=0.03%
#
# [INFO] Iteration 205: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.76%
# [INFO] COST: Predicted last sample of window: Actual=451.23, Pred=454.64, MAPE=0.76%
#
# [INFO] Iteration 206: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.13%
# [INFO] COST: Predicted last sample of window: Actual=450.34, Pred=450.93, MAPE=0.13%
#
# [INFO] Iteration 207: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.88%
# [INFO] COST: Predicted last sample of window: Actual=455.49, Pred=451.48, MAPE=0.88%
#
# [INFO] Iteration 208: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.03%
# [INFO] COST: Predicted last sample of window: Actual=460.97, Pred=456.20, MAPE=1.03%
#
# [INFO] Iteration 209: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.30%
# [INFO] COST: Predicted last sample of window: Actual=459.60, Pred=460.96, MAPE=0.30%
#
# [INFO] Iteration 210: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.43%
# [INFO] COST: Predicted last sample of window: Actual=465.94, Pred=463.93, MAPE=0.43%
#
# [INFO] Iteration 211: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.52%
# [INFO] COST: Predicted last sample of window: Actual=459.66, Pred=466.64, MAPE=1.52%
#
# [INFO] Iteration 212: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.01%
# [INFO] COST: Predicted last sample of window: Actual=460.73, Pred=460.70, MAPE=0.01%
#
# [INFO] Iteration 213: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.03%
# [INFO] COST: Predicted last sample of window: Actual=459.51, Pred=459.64, MAPE=0.03%
#
# [INFO] Iteration 214: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.00%
# [INFO] COST: Predicted last sample of window: Actual=452.11, Pred=452.11, MAPE=0.00%
#
# [INFO] Iteration 215: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.10%
# [INFO] COST: Predicted last sample of window: Actual=452.78, Pred=452.33, MAPE=0.10%
#
# [INFO] Iteration 216: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.34%
# [INFO] COST: Predicted last sample of window: Actual=460.56, Pred=459.00, MAPE=0.34%
#
# [INFO] Iteration 217: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.42%
# [INFO] COST: Predicted last sample of window: Actual=451.79, Pred=453.69, MAPE=0.42%
#
# [INFO] Iteration 218: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.21%
# [INFO] COST: Predicted last sample of window: Actual=448.33, Pred=449.25, MAPE=0.21%
#
# [INFO] Iteration 219: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.44%
# [INFO] COST: Predicted last sample of window: Actual=446.24, Pred=448.22, MAPE=0.44%
#
# [INFO] Iteration 220: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.99%
# [INFO] COST: Predicted last sample of window: Actual=452.87, Pred=448.39, MAPE=0.99%
#
# [INFO] Iteration 221: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.03%
# [INFO] COST: Predicted last sample of window: Actual=449.70, Pred=449.83, MAPE=0.03%
#
# [INFO] Iteration 222: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.02%
# [INFO] COST: Predicted last sample of window: Actual=445.30, Pred=449.85, MAPE=1.02%
#
# [INFO] Iteration 223: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.68%
# [INFO] COST: Predicted last sample of window: Actual=452.39, Pred=449.33, MAPE=0.68%
#
# [INFO] Iteration 224: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.77%
# [INFO] COST: Predicted last sample of window: Actual=467.08, Pred=454.12, MAPE=2.77%
#
# [INFO] Iteration 225: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.81%
# [INFO] COST: Predicted last sample of window: Actual=477.23, Pred=468.59, MAPE=1.81%
#
# [INFO] Iteration 226: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 2.20%
# [INFO] COST: Predicted last sample of window: Actual=490.10, Pred=479.30, MAPE=2.20%
#
# [INFO] Iteration 227: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.59%
# [INFO] COST: Predicted last sample of window: Actual=489.11, Pred=486.22, MAPE=0.59%
#
# [INFO] Iteration 228: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.21%
# [INFO] COST: Predicted last sample of window: Actual=491.54, Pred=490.53, MAPE=0.21%
#
# [INFO] Iteration 229: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.07%
# [INFO] COST: Predicted last sample of window: Actual=496.99, Pred=491.68, MAPE=1.07%
#
# [INFO] Iteration 230: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 3.04%
# [INFO] COST: Predicted last sample of window: Actual=515.62, Pred=499.95, MAPE=3.04%
#
# [INFO] Iteration 231: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.47%
# [INFO] COST: Predicted last sample of window: Actual=503.81, Pred=506.17, MAPE=0.47%
#
# [INFO] Iteration 232: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 0.73%
# [INFO] COST: Predicted last sample of window: Actual=505.51, Pred=509.19, MAPE=0.73%
#
# [INFO] Iteration 233: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.61%
# [INFO] COST: Predicted last sample of window: Actual=517.17, Pred=508.82, MAPE=1.61%
#
# [INFO] Iteration 234: COST, training on new window with Early Stopping...
# [RESULT] COST: Window validation MAPE: 1.30%
# ...
#
# [INFO] Iteration 20: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 6.14%
# [INFO] UL: Predicted last sample of window: Actual=53.95, Pred=57.26, MAPE=6.14%
#
# [INFO] Iteration 21: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 4.50%
# [INFO] UL: Predicted last sample of window: Actual=52.47, Pred=54.83, MAPE=4.50%
#
# [INFO] Iteration 22: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 2.70%
# [INFO] UL: Predicted last sample of window: Actual=49.97, Pred=51.32, MAPE=2.70%
#
# [INFO] Iteration 23: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.90%
# [INFO] UL: Predicted last sample of window: Actual=50.38, Pred=49.93, MAPE=0.90%
#
# [INFO] Iteration 24: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.26%
# [INFO] UL: Predicted last sample of window: Actual=50.66, Pred=50.02, MAPE=1.26%
#
# [INFO] Iteration 25: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 10.04%
# [INFO] UL: Predicted last sample of window: Actual=44.62, Pred=49.10, MAPE=10.04%
#
# [INFO] Iteration 26: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.27%
# [INFO] UL: Predicted last sample of window: Actual=47.61, Pred=47.48, MAPE=0.27%
#
# [INFO] Iteration 27: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 3.17%
# [INFO] UL: Predicted last sample of window: Actual=49.25, Pred=47.69, MAPE=3.17%
#
# [INFO] Iteration 28: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.35%
# [INFO] UL: Predicted last sample of window: Actual=50.57, Pred=49.89, MAPE=1.35%
#
# [INFO] Iteration 29: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.35%
# [INFO] UL: Predicted last sample of window: Actual=50.77, Pred=50.59, MAPE=0.35%
#
# [INFO] Iteration 30: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.26%
# [INFO] UL: Predicted last sample of window: Actual=51.26, Pred=50.61, MAPE=1.26%
#
# [INFO] Iteration 31: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.87%
# [INFO] UL: Predicted last sample of window: Actual=51.26, Pred=50.82, MAPE=0.87%
#
# [INFO] Iteration 32: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.70%
# [INFO] UL: Predicted last sample of window: Actual=51.65, Pred=51.29, MAPE=0.70%
#
# [INFO] Iteration 33: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.41%
# [INFO] UL: Predicted last sample of window: Actual=52.01, Pred=51.79, MAPE=0.41%
#
# [INFO] Iteration 34: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.10%
# [INFO] UL: Predicted last sample of window: Actual=52.89, Pred=52.31, MAPE=1.10%
#
# [INFO] Iteration 35: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.07%
# [INFO] UL: Predicted last sample of window: Actual=52.76, Pred=52.80, MAPE=0.07%
#
# [INFO] Iteration 36: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 2.65%
# [INFO] UL: Predicted last sample of window: Actual=51.53, Pred=52.89, MAPE=2.65%
#
# [INFO] Iteration 37: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.37%
# [INFO] UL: Predicted last sample of window: Actual=51.51, Pred=51.70, MAPE=0.37%
#
# [INFO] Iteration 38: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.19%
# [INFO] UL: Predicted last sample of window: Actual=51.63, Pred=51.53, MAPE=0.19%
#
# [INFO] Iteration 39: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.04%
# [INFO] UL: Predicted last sample of window: Actual=51.50, Pred=51.52, MAPE=0.04%
#
# [INFO] Iteration 40: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.76%
# [INFO] UL: Predicted last sample of window: Actual=50.61, Pred=51.50, MAPE=1.76%
#
# [INFO] Iteration 41: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.14%
# [INFO] UL: Predicted last sample of window: Actual=50.55, Pred=50.62, MAPE=0.14%
#
# [INFO] Iteration 42: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.87%
# [INFO] UL: Predicted last sample of window: Actual=52.20, Pred=51.22, MAPE=1.87%
#
# [INFO] Iteration 43: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.20%
# [INFO] UL: Predicted last sample of window: Actual=51.78, Pred=51.88, MAPE=0.20%
#
# [INFO] Iteration 44: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.24%
# [INFO] UL: Predicted last sample of window: Actual=51.21, Pred=51.85, MAPE=1.24%
#
# [INFO] Iteration 45: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.15%
# [INFO] UL: Predicted last sample of window: Actual=50.67, Pred=51.25, MAPE=1.15%
#
# [INFO] Iteration 46: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.80%
# [INFO] UL: Predicted last sample of window: Actual=50.84, Pred=51.25, MAPE=0.80%
#
# [INFO] Iteration 47: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.37%
# [INFO] UL: Predicted last sample of window: Actual=51.08, Pred=50.89, MAPE=0.37%
#
# [INFO] Iteration 48: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 4.75%
# [INFO] UL: Predicted last sample of window: Actual=53.61, Pred=51.07, MAPE=4.75%
#
# [INFO] Iteration 49: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.19%
# [INFO] UL: Predicted last sample of window: Actual=54.39, Pred=53.75, MAPE=1.19%
#
# [INFO] Iteration 50: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 2.24%
# [INFO] UL: Predicted last sample of window: Actual=55.69, Pred=54.44, MAPE=2.24%
#
# [INFO] Iteration 51: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.84%
# [INFO] UL: Predicted last sample of window: Actual=56.25, Pred=55.78, MAPE=0.84%
#
# [INFO] Iteration 52: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.30%
# [INFO] UL: Predicted last sample of window: Actual=55.60, Pred=55.77, MAPE=0.30%
#
# [INFO] Iteration 53: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 2.84%
# [INFO] UL: Predicted last sample of window: Actual=54.71, Pred=56.27, MAPE=2.84%
#
# [INFO] Iteration 54: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.06%
# [INFO] UL: Predicted last sample of window: Actual=55.02, Pred=55.05, MAPE=0.06%
#
# [INFO] Iteration 55: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 3.39%
# [INFO] UL: Predicted last sample of window: Actual=57.03, Pred=55.09, MAPE=3.39%
#
# [INFO] Iteration 56: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.83%
# [INFO] UL: Predicted last sample of window: Actual=57.37, Pred=56.89, MAPE=0.83%
#
# [INFO] Iteration 57: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.00%
# [INFO] UL: Predicted last sample of window: Actual=57.21, Pred=57.21, MAPE=0.00%
#
# [INFO] Iteration 58: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.26%
# [INFO] UL: Predicted last sample of window: Actual=56.52, Pred=57.23, MAPE=1.26%
#
# [INFO] Iteration 59: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.80%
# [INFO] UL: Predicted last sample of window: Actual=55.27, Pred=56.27, MAPE=1.80%
#
# [INFO] Iteration 60: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.41%
# [INFO] UL: Predicted last sample of window: Actual=55.07, Pred=55.29, MAPE=0.41%
#
# [INFO] Iteration 61: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.08%
# [INFO] UL: Predicted last sample of window: Actual=55.04, Pred=55.08, MAPE=0.08%
#
# [INFO] Iteration 62: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.87%
# [INFO] UL: Predicted last sample of window: Actual=54.59, Pred=55.06, MAPE=0.87%
#
# [INFO] Iteration 63: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.70%
# [INFO] UL: Predicted last sample of window: Actual=54.21, Pred=54.59, MAPE=0.70%
#
# [INFO] Iteration 64: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.68%
# [INFO] UL: Predicted last sample of window: Actual=55.00, Pred=54.63, MAPE=0.68%
#
# [INFO] Iteration 65: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.16%
# [INFO] UL: Predicted last sample of window: Actual=55.16, Pred=55.07, MAPE=0.16%
#
# [INFO] Iteration 66: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.07%
# [INFO] UL: Predicted last sample of window: Actual=55.27, Pred=55.23, MAPE=0.07%
#
# [INFO] Iteration 67: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.39%
# [INFO] UL: Predicted last sample of window: Actual=55.85, Pred=55.63, MAPE=0.39%
#
# [INFO] Iteration 68: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.00%
# [INFO] UL: Predicted last sample of window: Actual=60.15, Pred=60.15, MAPE=0.00%
#
# [INFO] Iteration 69: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.55%
# [INFO] UL: Predicted last sample of window: Actual=61.23, Pred=60.28, MAPE=1.55%
#
# [INFO] Iteration 70: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.18%
# [INFO] UL: Predicted last sample of window: Actual=61.44, Pred=61.33, MAPE=0.18%
#
# [INFO] Iteration 71: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.02%
# [INFO] UL: Predicted last sample of window: Actual=61.25, Pred=61.26, MAPE=0.02%
#
# [INFO] Iteration 72: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.14%
# [INFO] UL: Predicted last sample of window: Actual=61.18, Pred=61.27, MAPE=0.14%
#
# [INFO] Iteration 73: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 2.54%
# [INFO] UL: Predicted last sample of window: Actual=59.69, Pred=61.20, MAPE=2.54%
#
# [INFO] Iteration 74: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.55%
# [INFO] UL: Predicted last sample of window: Actual=58.78, Pred=59.69, MAPE=1.55%
#
# [INFO] Iteration 75: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.33%
# [INFO] UL: Predicted last sample of window: Actual=59.91, Pred=59.71, MAPE=0.33%
#
# [INFO] Iteration 76: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.02%
# [INFO] UL: Predicted last sample of window: Actual=59.75, Pred=59.76, MAPE=0.02%
#
# [INFO] Iteration 77: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.21%
# [INFO] UL: Predicted last sample of window: Actual=60.05, Pred=59.92, MAPE=0.21%
#
# [INFO] Iteration 78: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.87%
# [INFO] UL: Predicted last sample of window: Actual=59.56, Pred=60.08, MAPE=0.87%
#
# [INFO] Iteration 79: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.18%
# [INFO] UL: Predicted last sample of window: Actual=60.18, Pred=60.07, MAPE=0.18%
#
# [INFO] Iteration 80: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.19%
# [INFO] UL: Predicted last sample of window: Actual=60.40, Pred=60.29, MAPE=0.19%
#
# [INFO] Iteration 81: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.02%
# [INFO] UL: Predicted last sample of window: Actual=59.58, Pred=60.19, MAPE=1.02%
#
# [INFO] Iteration 82: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.36%
# [INFO] UL: Predicted last sample of window: Actual=60.92, Pred=60.09, MAPE=1.36%
#
# [INFO] Iteration 83: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.92%
# [INFO] UL: Predicted last sample of window: Actual=59.16, Pred=59.71, MAPE=0.92%
#
# [INFO] Iteration 84: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 3.68%
# [INFO] UL: Predicted last sample of window: Actual=62.11, Pred=59.82, MAPE=3.68%
#
# [INFO] Iteration 85: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.02%
# [INFO] UL: Predicted last sample of window: Actual=61.98, Pred=61.35, MAPE=1.02%
#
# [INFO] Iteration 86: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.74%
# [INFO] UL: Predicted last sample of window: Actual=62.47, Pred=62.01, MAPE=0.74%
#
# [INFO] Iteration 87: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.30%
# [INFO] UL: Predicted last sample of window: Actual=62.47, Pred=62.28, MAPE=0.30%
#
# [INFO] Iteration 88: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 3.53%
# [INFO] UL: Predicted last sample of window: Actual=59.90, Pred=62.01, MAPE=3.53%
#
# [INFO] Iteration 89: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.08%
# [INFO] UL: Predicted last sample of window: Actual=60.45, Pred=60.50, MAPE=0.08%
#
# [INFO] Iteration 90: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.50%
# [INFO] UL: Predicted last sample of window: Actual=60.82, Pred=60.52, MAPE=0.50%
#
# [INFO] Iteration 91: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.41%
# [INFO] UL: Predicted last sample of window: Actual=61.91, Pred=61.04, MAPE=1.41%
#
# [INFO] Iteration 92: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.28%
# [INFO] UL: Predicted last sample of window: Actual=61.92, Pred=61.75, MAPE=0.28%
#
# [INFO] Iteration 93: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.26%
# [INFO] UL: Predicted last sample of window: Actual=62.94, Pred=62.15, MAPE=1.26%
#
# [INFO] Iteration 94: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.14%
# [INFO] UL: Predicted last sample of window: Actual=62.04, Pred=62.12, MAPE=0.14%
#
# [INFO] Iteration 95: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.39%
# [INFO] UL: Predicted last sample of window: Actual=63.12, Pred=62.25, MAPE=1.39%
#
# [INFO] Iteration 96: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.06%
# [INFO] UL: Predicted last sample of window: Actual=63.19, Pred=63.23, MAPE=0.06%
#
# [INFO] Iteration 97: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.34%
# [INFO] UL: Predicted last sample of window: Actual=62.30, Pred=63.13, MAPE=1.34%
#
# [INFO] Iteration 98: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.34%
# [INFO] UL: Predicted last sample of window: Actual=61.80, Pred=62.63, MAPE=1.34%
#
# [INFO] Iteration 99: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 1.21%
# [INFO] UL: Predicted last sample of window: Actual=61.58, Pred=62.33, MAPE=1.21%
#
# [INFO] Iteration 100: UL, training on new window with Early Stopping...
# [RESULT] UL: Window validation MAPE: 0.41%
# [INFO] UL: Predicted last sample of window: Actual=61.32, Pred=61.57, MAPE=0.41%
#
# [INFO] Iteration 101: UL, training on new window with Early Stopping...

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error
import os
import time

stocks = [
    'COST', 'UL', 'AMGN', 'UNH', 'WAT', 'UPS', 'LPX', 'WM', 'NVDA',
    'GOOGL', 'MSFT', 'AXP', 'BLK', 'BRK-B', 'NEE', 'XOM', 'CNI'
]

start_date = '2020-01-01'
end_date = '2024-01-01'

window_size = 5
step_size = 2

if not os.path.exists("baseline_results"):
    os.makedirs("baseline_results")

def load_data(ticker, start_date, end_date):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)
    X = stock_data['Close'].values
    y = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values
    return X, y, dates

def extract_window(X_full, y_full, dates_full, start_idx, window_size):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None
    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]
    return X_window, y_window, dates_window

def sma_prediction(X_window):
    return np.mean(X_window[-2:])

def ema_prediction(X_window):
    ema = 0
    alpha = 2 / (len(X_window[-2:]) + 1)
    for i, price in enumerate(X_window[-2:]):
        ema += price * (alpha * (1 - alpha) ** (len(X_window[-2:]) - i - 1))
    return ema

def linear_regression_prediction(X_window):
    if len(X_window) < 2:
        return np.nan
    X = np.array([-2, -1]).reshape(-1, 1)  # Days n-2 and n-1
    y = X_window[-2:]  # Prices for days n-2 and n-1
    model = LinearRegression()
    model.fit(X, y)
    return model.predict([[0]])[0]  # Predict day n

def rolling_predictions(ticker, window_size, step_size):
    X_full, y_full, dates_full = load_data(ticker, start_date, end_date)
    if X_full is None:
        print(f"[WARN] Not enough data for {ticker}.")
        return None

    start_time = time.time()
    start_idx = 0

    results = []
    while True:
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size)
        if window_data[0] is None:
            print(f"[INFO] No more windows for {ticker}.")
            break
        X_window, y_window, dates_window = window_data

        for i in range(2, len(X_window)):
            sma_pred = sma_prediction(X_window[:i])
            ema_pred = ema_prediction(X_window[:i])
            lr_pred = linear_regression_prediction(X_window[:i])
            actual = y_window[i]
            date = dates_window[i]

            results.append({
                'Date': date,
                'Actual': actual,
                'SMA_Predicted': sma_pred,
                'EMA_Predicted': ema_pred,
                'LR_Predicted': lr_pred,
            })

        start_idx += step_size

    df_results = pd.DataFrame(results)
    df_results['SMA_Absolute_Error'] = np.abs(df_results['Actual'] - df_results['SMA_Predicted'])
    df_results['EMA_Absolute_Error'] = np.abs(df_results['Actual'] - df_results['EMA_Predicted'])
    df_results['LR_Absolute_Error'] = np.abs(df_results['Actual'] - df_results['LR_Predicted'])
    df_results.to_csv(f"baseline_results/{ticker}_results.csv", index=False)

    sma_mape = mean_absolute_percentage_error(df_results['Actual'], df_results['SMA_Predicted']) * 100.0
    ema_mape = mean_absolute_percentage_error(df_results['Actual'], df_results['EMA_Predicted']) * 100.0
    lr_mape = mean_absolute_percentage_error(df_results['Actual'], df_results['LR_Predicted']) * 100.0

    print(f"[INFO] {ticker}: SMA MAPE: {sma_mape:.2f}%, EMA MAPE: {ema_mape:.2f}%, LR MAPE: {lr_mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] {ticker}: Elapsed time: {elapsed:.2f}s")

    return {
        'Stock': ticker,
        'SMA_MAPE': sma_mape,
        'EMA_MAPE': ema_mape,
        'LR_MAPE': lr_mape
    }

if __name__ == "__main__":
    all_results = []
    for stock in stocks:
        result = rolling_predictions(stock, window_size, step_size)
        if result:
            all_results.append(result)

    results_df = pd.DataFrame(all_results)
    results_df.to_csv('stock_mapes_combined_results.csv', index=False)
    print("[INFO] All results saved to stock_mapes_combined_results.csv")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for COST.
# [INFO] COST: SMA MAPE: 1.68%, EMA MAPE: 11.26%, LR MAPE: 1.93%
# [INFO] COST: Elapsed time: 0.27s
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for UL.
# [INFO] UL: SMA MAPE: 1.39%, EMA MAPE: 11.07%, LR MAPE: 1.73%
# [INFO] UL: Elapsed time: 0.25s
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for AMGN.
# [INFO] AMGN: SMA MAPE: 1.67%, EMA MAPE: 11.13%, LR MAPE: 1.99%
# [INFO] AMGN: Elapsed time: 0.25s
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for UNH.
# [INFO] UNH: SMA MAPE: 1.83%, EMA MAPE: 11.21%, LR MAPE: 2.18%
# [INFO] UNH: Elapsed time: 0.26s
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for WAT.
# [INFO] WAT: SMA MAPE: 2.18%, EMA MAPE: 11.15%, LR MAPE: 2.64%
# [INFO] WAT: Elapsed time: 0.26s
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for UPS.
# [INFO] UPS: SMA MAPE: 2.02%, EMA MAPE: 11.14%, LR MAPE: 2.33%
# [INFO] UPS: Elapsed time: 0.25s
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for LPX.
# [INFO] LPX: SMA MAPE: 3.46%, EMA MAPE: 11.32%, LR MAPE: 3.95%
# [INFO] LPX: Elapsed time: 0.25s
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for WM.
# [INFO] WM: SMA MAPE: 1.43%, EMA MAPE: 11.18%, LR MAPE: 1.71%
# [INFO] WM: Elapsed time: 0.25s
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for NVDA.
# [INFO] NVDA: SMA MAPE: 3.74%, EMA MAPE: 11.46%, LR MAPE: 4.35%
# [INFO] NVDA: Elapsed time: 0.25s
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for GOOGL.
# [INFO] GOOGL: SMA MAPE: 2.24%, EMA MAPE: 11.22%, LR MAPE: 2.66%
# [INFO] GOOGL: Elapsed time: 0.26s
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for MSFT.
# [INFO] MSFT: SMA MAPE: 2.04%, EMA MAPE: 11.25%, LR MAPE: 2.56%
# [INFO] MSFT: Elapsed time: 0.25s
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for AXP.
# [INFO] AXP: SMA MAPE: 2.59%, EMA MAPE: 11.16%, LR MAPE: 2.82%
# [INFO] AXP: Elapsed time: 0.24s
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for BLK.
# [INFO] BLK: SMA MAPE: 2.17%, EMA MAPE: 11.20%, LR MAPE: 2.44%
# [INFO] BLK: Elapsed time: 0.25s
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for BRK-B.
# [INFO] BRK-B: SMA MAPE: 1.42%, EMA MAPE: 11.18%, LR MAPE: 1.65%
# [INFO] BRK-B: Elapsed time: 0.25s
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for NEE.
# [INFO] NEE: SMA MAPE: 2.02%, EMA MAPE: 11.10%, LR MAPE: 2.30%
# [INFO] NEE: Elapsed time: 0.26s
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for XOM.
# [INFO] XOM: SMA MAPE: 2.56%, EMA MAPE: 11.17%, LR MAPE: 3.04%
# [INFO] XOM: Elapsed time: 0.25s
# [*********************100%%**********************]  1 of 1 completed
# [INFO] No more windows for CNI.
# [INFO] CNI: SMA MAPE: 1.72%, EMA MAPE: 11.16%, LR MAPE: 2.05%
# [INFO] CNI: Elapsed time: 0.25s
# [INFO] All results saved to stock_mapes_combined_results.csv
