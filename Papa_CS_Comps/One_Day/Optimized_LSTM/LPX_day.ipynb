# %%
import pandas as pd
import numpy as np
import yfinance as yf
import talib
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os
import math
import time

########################
# Configuration
########################
ticker = 'LPX'
start_date = '2020-01-01'
end_date = '2024-01-01'
1
# Hyperparameters
n_steps = 2
window_size = 5
step_size = 2
initial_epochs = 100
update_epochs = 100
initial_lr = 0.0005
update_lr = 0.00005
train_ratio = 0.9
n_units = 16
batch_size = 4

# If you change features or other logic, do so below
if not os.path.exists("rolling_error_analysis_results"):
    os.makedirs("rolling_error_analysis_results")


def load_full_data_helper(ticker, start_date, end_date, window_size):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None

    # Next day prediction setup
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    # Simple features
    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values

    if len(dates) < window_size:
        return None, None, None
    return X_feat.values, y_raw, dates


def load_full_data(ticker, start_date, end_date, window_size):
    X_feat, y_raw, dates = load_full_data_helper(ticker, start_date, end_date, window_size)
    if X_feat is None:
        return None, None, None
    return X_feat, y_raw, dates


def extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None, None, None, None

    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]

    def lstm_split(dataX, dataY, n_steps):
        X, y = [], []
        for i in range(len(dataX)-n_steps+1):
            X.append(dataX[i:i+n_steps])
            y.append(dataY[i+n_steps-1])
        return np.array(X), np.array(y)

    X_samples, y_samples = lstm_split(X_window, y_window, n_steps)
    sample_dates = dates_window[n_steps-1:]

    feat_scaler = RobustScaler()
    target_scaler = RobustScaler()
    X_flat = X_window.reshape(len(X_window), -1)
    feat_scaler.fit(X_flat)
    y_window_reshaped = y_window.reshape(-1,1)
    target_scaler.fit(y_window_reshaped)

    X_scaled = feat_scaler.transform(X_flat).reshape(X_window.shape)
    y_scaled = target_scaler.transform(y_window_reshaped).flatten()
    X_samples_scaled, y_samples_scaled = lstm_split(X_scaled, y_scaled, n_steps)

    return X_samples_scaled, y_samples_scaled, sample_dates, feat_scaler, target_scaler, (X_window, y_window, dates_window)


def create_lstm_model(n_units, learning_rate, n_steps, n_features, n_layers=1):
    inputs = Input(shape=(n_steps, n_features))
    x = LSTM(n_units, activation='relu', return_sequences=(n_layers > 1))(inputs)
    if n_layers > 1:
        x = LSTM(n_units, activation='relu')(x)
    outputs = Dense(1)(x)
    model = Model(inputs, outputs)
    # We'll compile after loading weights if needed
    return model


def train_on_window(X_samples, y_samples, feat_scaler, target_scaler,
                    initial_training=False, prev_weights=None):
    total_samples = len(X_samples)
    global train_ratio
    train_count = int(math.floor(total_samples * train_ratio))
    if train_count >= total_samples:
        train_count = total_samples - 1

    X_train, y_train = X_samples[:train_count], y_samples[:train_count]
    X_val, y_val = X_samples[train_count:], y_samples[train_count:]

    if X_train.size == 0 or X_val.size == 0:
        return None, np.nan

    n_steps_local = X_train.shape[1]
    n_features = X_train.shape[2]

    if initial_training:
        epochs = initial_epochs
        lr = initial_lr
    else:
        epochs = update_epochs
        lr = update_lr

    model = create_lstm_model(n_units, lr, n_steps_local, n_features, n_layers=1)

    if prev_weights is not None:
        model.load_weights(prev_weights)

    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=lr))

    es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0, shuffle=False,
              validation_data=(X_val, y_val), callbacks=[es])

    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_unscaled = target_scaler.inverse_transform(y_val.reshape(-1,1)).flatten()
    y_val_pred_unscaled = target_scaler.inverse_transform(y_val_pred_scaled).flatten()
    val_mape = mean_absolute_percentage_error(y_val_unscaled, y_val_pred_unscaled) * 100

    return model, val_mape


def rolling_training_early_stopping(ticker, window_size, step_size, n_steps):
    X_full, y_full, dates_full = load_full_data(ticker, start_date, end_date, window_size)
    if X_full is None:
        print("[WARN] Not enough data.")
        return

    start_time = time.time()

    start_idx = 0
    window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
    if window_data[0] is None:
        print("[WARN] Initial window not valid.")
        return
    X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

    print("[INFO] Training initial window with Early Stopping...")
    model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=True, prev_weights=None)
    print(f"[RESULT] Initial window validation MAPE: {val_mape:.2f}%")

    weights_path = "rolling_error_analysis_results/cost_initial_es.weights.h5"
    model.save_weights(weights_path)

    predictions = []
    actuals = []
    pred_dates = []

    iteration = 1
    while True:
        start_idx += step_size
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
        if window_data[0] is None:
            print("[INFO] No more windows can be extracted.")
            break
        X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

        print(f"\n[INFO] Iteration {iteration}: training on new window with Early Stopping...")
        model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=weights_path)
        print(f"[RESULT] Window validation MAPE: {val_mape:.2f}%")

        weights_path = f"rolling_error_analysis_results/cost_iteration_{iteration}_es.weights.h5"
        model.save_weights(weights_path)

        X_test_last = X_samples[-1:]
        y_test_last = y_samples[-1:]
        y_pred_scaled = model.predict(X_test_last, verbose=0)
        y_test_unscaled = target_scaler.inverse_transform(y_test_last.reshape(-1,1)).flatten()
        y_pred_unscaled = target_scaler.inverse_transform(y_pred_scaled).flatten()

        predictions.append(y_pred_unscaled[0])
        actuals.append(y_test_unscaled[0])
        pred_dates.append(sample_dates[-1])

        test_mape = mean_absolute_percentage_error(y_test_unscaled, y_pred_unscaled)*100
        print(f"[INFO] Predicted last sample of window: Actual={y_test_unscaled[0]:.2f}, Pred={y_pred_unscaled[0]:.2f}, MAPE={test_mape:.2f}%")

        iteration += 1

    df_results = pd.DataFrame({
        'Date': pred_dates,
        'Actual': actuals,
        'Predicted': predictions
    })
    df_results['Absolute_Error'] = np.abs(df_results['Actual'] - df_results['Predicted'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual'])
    df_results['MAPE'] = df_results['APE'] * 100.0

    df_results.to_csv("rolling_error_analysis_results/cost_rolling_results_es.csv", index=False)
    overall_mape = df_results['MAPE'].mean()
    print(f"\n[INFO] Rolling training with Early Stopping completed for {ticker}. Overall MAPE: {overall_mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] Total elapsed time: {elapsed:.2f}s")

    worst_10 = df_results.sort_values('MAPE', ascending=False).head(10)
    print("[INFO] Top 10 worst predictions in rolling scenario (Early Stopping):")
    print(worst_10[['Date', 'Actual', 'Predicted', 'MAPE']])

if __name__ == "__main__":
    # Just run with the current top-level defined parameters:
    rolling_training_early_stopping(ticker, window_size, step_size, n_steps)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [INFO] Training initial window with Early Stopping...
# [RESULT] Initial window validation MAPE: 1.66%
#
# [INFO] Iteration 1: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.06%
# [INFO] Predicted last sample of window: Actual=31.07, Pred=31.09, MAPE=0.06%
#
# [INFO] Iteration 2: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.32%
# [INFO] Predicted last sample of window: Actual=31.50, Pred=31.08, MAPE=1.32%
#
# [INFO] Iteration 3: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.19%
# [INFO] Predicted last sample of window: Actual=31.88, Pred=31.94, MAPE=0.19%
#
# [INFO] Iteration 4: training on new window with Early Stopping...
# WARNING:tensorflow:5 out of the last 8 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x16c48e840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [RESULT] Window validation MAPE: 1.32%
# [INFO] Predicted last sample of window: Actual=31.15, Pred=31.56, MAPE=1.32%
#
# [INFO] Iteration 5: training on new window with Early Stopping...
# WARNING:tensorflow:6 out of the last 10 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x16a8718a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [RESULT] Window validation MAPE: 0.07%
# [INFO] Predicted last sample of window: Actual=31.07, Pred=31.09, MAPE=0.07%
#
# [INFO] Iteration 6: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.76%
# [INFO] Predicted last sample of window: Actual=31.31, Pred=31.07, MAPE=0.76%
#
# [INFO] Iteration 7: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.89%
# [INFO] Predicted last sample of window: Actual=30.83, Pred=31.10, MAPE=0.89%
#
# [INFO] Iteration 8: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.32%
# [INFO] Predicted last sample of window: Actual=31.18, Pred=31.08, MAPE=0.32%
#
# [INFO] Iteration 9: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.95%
# [INFO] Predicted last sample of window: Actual=31.76, Pred=31.14, MAPE=1.95%
#
# [INFO] Iteration 10: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.01%
# [INFO] Predicted last sample of window: Actual=31.84, Pred=31.84, MAPE=0.01%
#
# [INFO] Iteration 11: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.69%
# [INFO] Predicted last sample of window: Actual=33.08, Pred=31.86, MAPE=3.69%
#
# [INFO] Iteration 12: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.53%
# [INFO] Predicted last sample of window: Actual=33.73, Pred=32.88, MAPE=2.53%
#
# [INFO] Iteration 13: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.37%
# [INFO] Predicted last sample of window: Actual=33.32, Pred=33.78, MAPE=1.37%
#
# [INFO] Iteration 14: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.82%
# [INFO] Predicted last sample of window: Actual=33.94, Pred=33.66, MAPE=0.82%
#
# [INFO] Iteration 15: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.82%
# [INFO] Predicted last sample of window: Actual=32.99, Pred=33.26, MAPE=0.82%
#
# [INFO] Iteration 16: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.79%
# [INFO] Predicted last sample of window: Actual=30.80, Pred=31.66, MAPE=2.79%
#
# [INFO] Iteration 17: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.19%
# [INFO] Predicted last sample of window: Actual=28.45, Pred=28.50, MAPE=0.19%
#
# [INFO] Iteration 18: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.59%
# [INFO] Predicted last sample of window: Actual=29.11, Pred=28.94, MAPE=0.59%
#
# [INFO] Iteration 19: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.33%
# [INFO] Predicted last sample of window: Actual=29.06, Pred=29.16, MAPE=0.33%
#
# [INFO] Iteration 20: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 13.93%
# [INFO] Predicted last sample of window: Actual=23.70, Pred=27.00, MAPE=13.93%
#
# [INFO] Iteration 21: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.96%
# [INFO] Predicted last sample of window: Actual=22.00, Pred=23.09, MAPE=4.96%
#
# [INFO] Iteration 22: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 6.50%
# [INFO] Predicted last sample of window: Actual=20.71, Pred=19.36, MAPE=6.50%
#
# [INFO] Iteration 23: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.10%
# [INFO] Predicted last sample of window: Actual=16.62, Pred=17.47, MAPE=5.10%
#
# [INFO] Iteration 24: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.48%
# [INFO] Predicted last sample of window: Actual=15.95, Pred=16.35, MAPE=2.48%
#
# [INFO] Iteration 25: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=14.00, Pred=14.00, MAPE=0.00%
#
# [INFO] Iteration 26: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 18.78%
# [INFO] Predicted last sample of window: Actual=18.64, Pred=15.14, MAPE=18.78%
#
# [INFO] Iteration 27: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.40%
# [INFO] Predicted last sample of window: Actual=17.59, Pred=17.84, MAPE=1.40%
#
# [INFO] Iteration 28: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.19%
# [INFO] Predicted last sample of window: Actual=17.18, Pred=17.73, MAPE=3.19%
#
# [INFO] Iteration 29: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 8.39%
# [INFO] Predicted last sample of window: Actual=14.61, Pred=13.38, MAPE=8.39%
#
# [INFO] Iteration 30: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 6.90%
# [INFO] Predicted last sample of window: Actual=15.88, Pred=14.79, MAPE=6.90%
#
# [INFO] Iteration 31: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 7.87%
# [INFO] Predicted last sample of window: Actual=17.56, Pred=16.18, MAPE=7.87%
#
# [INFO] Iteration 32: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.11%
# [INFO] Predicted last sample of window: Actual=17.54, Pred=17.74, MAPE=1.11%
#
# [INFO] Iteration 33: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.20%
# [INFO] Predicted last sample of window: Actual=16.70, Pred=17.57, MAPE=5.20%
#
# [INFO] Iteration 34: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.55%
# [INFO] Predicted last sample of window: Actual=17.46, Pred=17.01, MAPE=2.55%
#
# [INFO] Iteration 35: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.55%
# [INFO] Predicted last sample of window: Actual=16.13, Pred=16.70, MAPE=3.55%
#
# [INFO] Iteration 36: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.91%
# [INFO] Predicted last sample of window: Actual=16.85, Pred=16.53, MAPE=1.91%
#
# [INFO] Iteration 37: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 7.29%
# [INFO] Predicted last sample of window: Actual=18.44, Pred=17.10, MAPE=7.29%
#
# [INFO] Iteration 38: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 10.02%
# [INFO] Predicted last sample of window: Actual=21.14, Pred=19.02, MAPE=10.02%
#
# [INFO] Iteration 39: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.41%
# [INFO] Predicted last sample of window: Actual=19.51, Pred=19.59, MAPE=0.41%
#
# [INFO] Iteration 40: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.12%
# [INFO] Predicted last sample of window: Actual=19.61, Pred=19.59, MAPE=0.12%
#
# [INFO] Iteration 41: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.80%
# [INFO] Predicted last sample of window: Actual=20.01, Pred=19.65, MAPE=1.80%
#
# [INFO] Iteration 42: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.80%
# [INFO] Predicted last sample of window: Actual=21.21, Pred=20.62, MAPE=2.80%
#
# [INFO] Iteration 43: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 6.53%
# [INFO] Predicted last sample of window: Actual=19.25, Pred=20.51, MAPE=6.53%
#
# [INFO] Iteration 44: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.69%
# [INFO] Predicted last sample of window: Actual=19.81, Pred=19.28, MAPE=2.69%
#
# [INFO] Iteration 45: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 8.41%
# [INFO] Predicted last sample of window: Actual=22.02, Pred=20.17, MAPE=8.41%
#
# [INFO] Iteration 46: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.59%
# [INFO] Predicted last sample of window: Actual=22.49, Pred=22.13, MAPE=1.59%
#
# [INFO] Iteration 47: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.73%
# [INFO] Predicted last sample of window: Actual=24.08, Pred=22.94, MAPE=4.73%
#
# [INFO] Iteration 48: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.40%
# [INFO] Predicted last sample of window: Actual=23.99, Pred=24.33, MAPE=1.40%
#
# [INFO] Iteration 49: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.13%
# [INFO] Predicted last sample of window: Actual=24.11, Pred=24.08, MAPE=0.13%
#
# [INFO] Iteration 50: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 6.27%
# [INFO] Predicted last sample of window: Actual=25.77, Pred=24.15, MAPE=6.27%
#
# [INFO] Iteration 51: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.97%
# [INFO] Predicted last sample of window: Actual=27.06, Pred=25.72, MAPE=4.97%
#
# [INFO] Iteration 52: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.39%
# [INFO] Predicted last sample of window: Actual=25.89, Pred=26.25, MAPE=1.39%
#
# [INFO] Iteration 53: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 14.91%
# [INFO] Predicted last sample of window: Actual=22.55, Pred=25.91, MAPE=14.91%
#
# [INFO] Iteration 54: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.37%
# [INFO] Predicted last sample of window: Actual=24.01, Pred=23.68, MAPE=1.37%
#
# [INFO] Iteration 55: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.54%
# [INFO] Predicted last sample of window: Actual=24.20, Pred=24.07, MAPE=0.54%
#
# [INFO] Iteration 56: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.45%
# [INFO] Predicted last sample of window: Actual=24.36, Pred=24.25, MAPE=0.45%
#
# [INFO] Iteration 57: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.83%
# [INFO] Predicted last sample of window: Actual=25.05, Pred=24.34, MAPE=2.83%
#
# [INFO] Iteration 58: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.87%
# [INFO] Predicted last sample of window: Actual=23.72, Pred=24.64, MAPE=3.87%
#
# [INFO] Iteration 59: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.94%
# [INFO] Predicted last sample of window: Actual=25.10, Pred=23.86, MAPE=4.94%
#
# [INFO] Iteration 60: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.08%
# [INFO] Predicted last sample of window: Actual=24.73, Pred=25.00, MAPE=1.08%
#
# [INFO] Iteration 61: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.72%
# [INFO] Predicted last sample of window: Actual=26.29, Pred=25.57, MAPE=2.72%
#
# [INFO] Iteration 62: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.48%
# [INFO] Predicted last sample of window: Actual=26.41, Pred=26.28, MAPE=0.48%
#
# [INFO] Iteration 63: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.47%
# [INFO] Predicted last sample of window: Actual=26.99, Pred=26.32, MAPE=2.47%
#
# [INFO] Iteration 64: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.07%
# [INFO] Predicted last sample of window: Actual=27.80, Pred=26.95, MAPE=3.07%
#
# [INFO] Iteration 65: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.33%
# [INFO] Predicted last sample of window: Actual=28.98, Pred=28.30, MAPE=2.33%
#
# [INFO] Iteration 66: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.37%
# [INFO] Predicted last sample of window: Actual=29.15, Pred=29.04, MAPE=0.37%
#
# [INFO] Iteration 67: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.59%
# [INFO] Predicted last sample of window: Actual=29.73, Pred=29.26, MAPE=1.59%
#
# [INFO] Iteration 68: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.70%
# [INFO] Predicted last sample of window: Actual=30.64, Pred=29.81, MAPE=2.70%
#
# [INFO] Iteration 69: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.89%
# [INFO] Predicted last sample of window: Actual=31.34, Pred=31.06, MAPE=0.89%
#
# [INFO] Iteration 70: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.53%
# [INFO] Predicted last sample of window: Actual=31.89, Pred=32.06, MAPE=0.53%
#
# [INFO] Iteration 71: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.07%
# [INFO] Predicted last sample of window: Actual=31.40, Pred=31.74, MAPE=1.07%
#
# [INFO] Iteration 72: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.92%
# [INFO] Predicted last sample of window: Actual=30.85, Pred=31.44, MAPE=1.92%
#
# [INFO] Iteration 73: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.09%
# [INFO] Predicted last sample of window: Actual=31.39, Pred=30.73, MAPE=2.09%
#
# [INFO] Iteration 74: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.31%
# [INFO] Predicted last sample of window: Actual=31.00, Pred=30.90, MAPE=0.31%
#
# [INFO] Iteration 75: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.20%
# [INFO] Predicted last sample of window: Actual=31.89, Pred=31.51, MAPE=1.20%
#
# [INFO] Iteration 76: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.21%
# [INFO] Predicted last sample of window: Actual=32.68, Pred=31.96, MAPE=2.21%
#
# [INFO] Iteration 77: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.67%
# [INFO] Predicted last sample of window: Actual=33.33, Pred=33.11, MAPE=0.67%
#
# [INFO] Iteration 78: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.45%
# [INFO] Predicted last sample of window: Actual=33.52, Pred=33.03, MAPE=1.45%
#
# [INFO] Iteration 79: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.22%
# [INFO] Predicted last sample of window: Actual=32.66, Pred=33.38, MAPE=2.22%
#
# [INFO] Iteration 80: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.11%
# [INFO] Predicted last sample of window: Actual=32.99, Pred=33.03, MAPE=0.11%
#
# [INFO] Iteration 81: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.05%
# [INFO] Predicted last sample of window: Actual=32.94, Pred=32.96, MAPE=0.05%
#
# [INFO] Iteration 82: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.37%
# [INFO] Predicted last sample of window: Actual=33.68, Pred=33.55, MAPE=0.37%
#
# [INFO] Iteration 83: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.21%
# [INFO] Predicted last sample of window: Actual=31.64, Pred=32.97, MAPE=4.21%
#
# [INFO] Iteration 84: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.01%
# [INFO] Predicted last sample of window: Actual=32.08, Pred=31.76, MAPE=1.01%
#
# [INFO] Iteration 85: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.77%
# [INFO] Predicted last sample of window: Actual=31.40, Pred=31.64, MAPE=0.77%
#
# [INFO] Iteration 86: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.32%
# [INFO] Predicted last sample of window: Actual=32.61, Pred=32.18, MAPE=1.32%
#
# [INFO] Iteration 87: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.22%
# [INFO] Predicted last sample of window: Actual=31.84, Pred=32.23, MAPE=1.22%
#
# [INFO] Iteration 88: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 6.46%
# [INFO] Predicted last sample of window: Actual=29.80, Pred=31.72, MAPE=6.46%
#
# [INFO] Iteration 89: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.63%
# [INFO] Predicted last sample of window: Actual=29.43, Pred=30.20, MAPE=2.63%
#
# [INFO] Iteration 90: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.05%
# [INFO] Predicted last sample of window: Actual=29.78, Pred=29.76, MAPE=0.05%
#
# [INFO] Iteration 91: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.34%
# [INFO] Predicted last sample of window: Actual=30.26, Pred=29.86, MAPE=1.34%
#
# [INFO] Iteration 92: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.28%
# [INFO] Predicted last sample of window: Actual=29.83, Pred=29.91, MAPE=0.28%
#
# [INFO] Iteration 93: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.41%
# [INFO] Predicted last sample of window: Actual=30.29, Pred=29.86, MAPE=1.41%
#
# [INFO] Iteration 94: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.38%
# [INFO] Predicted last sample of window: Actual=31.64, Pred=29.94, MAPE=5.38%
#
# [INFO] Iteration 95: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.42%
# [INFO] Predicted last sample of window: Actual=31.69, Pred=32.14, MAPE=1.42%
#
# [INFO] Iteration 96: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.57%
# [INFO] Predicted last sample of window: Actual=30.92, Pred=31.71, MAPE=2.57%
#
# [INFO] Iteration 97: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.65%
# [INFO] Predicted last sample of window: Actual=30.77, Pred=30.97, MAPE=0.65%
#
# [INFO] Iteration 98: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.03%
# [INFO] Predicted last sample of window: Actual=30.74, Pred=30.75, MAPE=0.03%
#
# [INFO] Iteration 99: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.75%
# [INFO] Predicted last sample of window: Actual=31.44, Pred=30.89, MAPE=1.75%
#
# [INFO] Iteration 100: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.32%
# [INFO] Predicted last sample of window: Actual=31.17, Pred=31.27, MAPE=0.32%
#
# [INFO] Iteration 101: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 6.01%
# [INFO] Predicted last sample of window: Actual=28.64, Pred=30.36, MAPE=6.01%
#
# [INFO] Iteration 102: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.10%
# [INFO] Predicted last sample of window: Actual=28.28, Pred=28.31, MAPE=0.10%
#
# [INFO] Iteration 103: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.21%
# [INFO] Predicted last sample of window: Actual=29.87, Pred=28.61, MAPE=4.21%
#
# [INFO] Iteration 104: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.62%
# [INFO] Predicted last sample of window: Actual=31.40, Pred=30.89, MAPE=1.62%
#
# [INFO] Iteration 105: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.87%
# [INFO] Predicted last sample of window: Actual=30.09, Pred=31.55, MAPE=4.87%
#
# [INFO] Iteration 106: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.12%
# [INFO] Predicted last sample of window: Actual=30.18, Pred=29.84, MAPE=1.12%
#
# [INFO] Iteration 107: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.88%
# [INFO] Predicted last sample of window: Actual=29.77, Pred=30.03, MAPE=0.88%
#
# [INFO] Iteration 108: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.45%
# [INFO] Predicted last sample of window: Actual=32.39, Pred=30.95, MAPE=4.45%
#
# [INFO] Iteration 109: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.58%
# [INFO] Predicted last sample of window: Actual=33.31, Pred=32.45, MAPE=2.58%
#
# [INFO] Iteration 110: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.25%
# [INFO] Predicted last sample of window: Actual=33.96, Pred=33.54, MAPE=1.25%
#
# [INFO] Iteration 111: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.61%
# [INFO] Predicted last sample of window: Actual=35.00, Pred=34.79, MAPE=0.61%
#
# [INFO] Iteration 112: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.63%
# [INFO] Predicted last sample of window: Actual=33.84, Pred=35.07, MAPE=3.63%
#
# [INFO] Iteration 113: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.27%
# [INFO] Predicted last sample of window: Actual=34.36, Pred=34.27, MAPE=0.27%
#
# [INFO] Iteration 114: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.50%
# [INFO] Predicted last sample of window: Actual=36.23, Pred=34.24, MAPE=5.50%
#
# [INFO] Iteration 115: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.82%
# [INFO] Predicted last sample of window: Actual=37.07, Pred=36.40, MAPE=1.82%
#
# [INFO] Iteration 116: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.72%
# [INFO] Predicted last sample of window: Actual=38.55, Pred=37.12, MAPE=3.72%
#
# [INFO] Iteration 117: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.77%
# [INFO] Predicted last sample of window: Actual=39.76, Pred=38.66, MAPE=2.77%
#
# [INFO] Iteration 118: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.60%
# [INFO] Predicted last sample of window: Actual=38.37, Pred=38.99, MAPE=1.60%
#
# [INFO] Iteration 119: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.36%
# [INFO] Predicted last sample of window: Actual=38.83, Pred=38.69, MAPE=0.36%
#
# [INFO] Iteration 120: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.01%
# [INFO] Predicted last sample of window: Actual=38.21, Pred=38.21, MAPE=0.01%
#
# [INFO] Iteration 121: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.16%
# [INFO] Predicted last sample of window: Actual=38.27, Pred=38.21, MAPE=0.16%
#
# [INFO] Iteration 122: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.20%
# [INFO] Predicted last sample of window: Actual=37.45, Pred=38.27, MAPE=2.20%
#
# [INFO] Iteration 123: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.31%
# [INFO] Predicted last sample of window: Actual=37.54, Pred=37.42, MAPE=0.31%
#
# [INFO] Iteration 124: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.69%
# [INFO] Predicted last sample of window: Actual=36.93, Pred=37.18, MAPE=0.69%
#
# [INFO] Iteration 125: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.90%
# [INFO] Predicted last sample of window: Actual=39.91, Pred=37.55, MAPE=5.90%
#
# [INFO] Iteration 126: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=38.43, Pred=38.43, MAPE=0.00%
#
# [INFO] Iteration 127: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.39%
# [INFO] Predicted last sample of window: Actual=37.64, Pred=38.54, MAPE=2.39%
#
# [INFO] Iteration 128: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=38.41, Pred=38.41, MAPE=0.00%
#
# [INFO] Iteration 129: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.55%
# [INFO] Predicted last sample of window: Actual=38.20, Pred=37.99, MAPE=0.55%
#
# [INFO] Iteration 130: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.80%
# [INFO] Predicted last sample of window: Actual=39.52, Pred=38.02, MAPE=3.80%
#
# [INFO] Iteration 131: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.57%
# [INFO] Predicted last sample of window: Actual=40.61, Pred=39.56, MAPE=2.57%
#
# [INFO] Iteration 132: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.76%
# [INFO] Predicted last sample of window: Actual=38.25, Pred=40.07, MAPE=4.76%
#
# [INFO] Iteration 133: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.70%
# [INFO] Predicted last sample of window: Actual=38.01, Pred=39.04, MAPE=2.70%
#
# [INFO] Iteration 134: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.39%
# [INFO] Predicted last sample of window: Actual=40.11, Pred=39.15, MAPE=2.39%
#
# [INFO] Iteration 135: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.79%
# [INFO] Predicted last sample of window: Actual=41.36, Pred=40.21, MAPE=2.79%
#
# [INFO] Iteration 136: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.70%
# [INFO] Predicted last sample of window: Actual=42.15, Pred=41.43, MAPE=1.70%
#
# [INFO] Iteration 137: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.90%
# [INFO] Predicted last sample of window: Actual=42.15, Pred=41.77, MAPE=0.90%
#
# [INFO] Iteration 138: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.15%
# [INFO] Predicted last sample of window: Actual=43.52, Pred=42.15, MAPE=3.15%
#
# [INFO] Iteration 139: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.88%
# [INFO] Predicted last sample of window: Actual=45.34, Pred=43.58, MAPE=3.88%
#
# [INFO] Iteration 140: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.63%
# [INFO] Predicted last sample of window: Actual=47.29, Pred=45.10, MAPE=4.63%
#
# [INFO] Iteration 141: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.18%
# [INFO] Predicted last sample of window: Actual=45.22, Pred=45.30, MAPE=0.18%
#
# [INFO] Iteration 142: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.21%
# [INFO] Predicted last sample of window: Actual=47.19, Pred=47.29, MAPE=0.21%
#
# [INFO] Iteration 143: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.82%
# [INFO] Predicted last sample of window: Actual=49.02, Pred=47.64, MAPE=2.82%
#
# [INFO] Iteration 144: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.81%
# [INFO] Predicted last sample of window: Actual=47.21, Pred=47.59, MAPE=0.81%
#
# [INFO] Iteration 145: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.03%
# [INFO] Predicted last sample of window: Actual=48.43, Pred=47.45, MAPE=2.03%
#
# [INFO] Iteration 146: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.71%
# [INFO] Predicted last sample of window: Actual=49.94, Pred=48.59, MAPE=2.71%
#
# [INFO] Iteration 147: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.53%
# [INFO] Predicted last sample of window: Actual=51.84, Pred=50.01, MAPE=3.53%
#
# [INFO] Iteration 148: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.44%
# [INFO] Predicted last sample of window: Actual=54.49, Pred=52.07, MAPE=4.44%
#
# [INFO] Iteration 149: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.44%
# [INFO] Predicted last sample of window: Actual=55.01, Pred=54.22, MAPE=1.44%
#
# [INFO] Iteration 150: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.29%
# [INFO] Predicted last sample of window: Actual=53.89, Pred=54.05, MAPE=0.29%
#
# [INFO] Iteration 151: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.34%
# [INFO] Predicted last sample of window: Actual=51.60, Pred=53.84, MAPE=4.34%
#
# [INFO] Iteration 152: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.51%
# [INFO] Predicted last sample of window: Actual=53.71, Pred=52.90, MAPE=1.51%
#
# [INFO] Iteration 153: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.01%
# [INFO] Predicted last sample of window: Actual=53.88, Pred=53.87, MAPE=0.01%
#
# [INFO] Iteration 154: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.54%
# [INFO] Predicted last sample of window: Actual=55.46, Pred=54.61, MAPE=1.54%
#
# [INFO] Iteration 155: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 6.23%
# [INFO] Predicted last sample of window: Actual=59.63, Pred=55.91, MAPE=6.23%
#
# [INFO] Iteration 156: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=60.07, Pred=60.07, MAPE=0.00%
#
# [INFO] Iteration 157: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.86%
# [INFO] Predicted last sample of window: Actual=61.60, Pred=60.45, MAPE=1.86%
#
# [INFO] Iteration 158: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.42%
# [INFO] Predicted last sample of window: Actual=63.39, Pred=61.85, MAPE=2.42%
#
# [INFO] Iteration 159: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.64%
# [INFO] Predicted last sample of window: Actual=65.37, Pred=63.64, MAPE=2.64%
#
# [INFO] Iteration 160: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.42%
# [INFO] Predicted last sample of window: Actual=67.49, Pred=65.86, MAPE=2.42%
#
# [INFO] Iteration 161: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.33%
# [INFO] Predicted last sample of window: Actual=63.50, Pred=65.61, MAPE=3.33%
#
# [INFO] Iteration 162: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.32%
# [INFO] Predicted last sample of window: Actual=67.60, Pred=64.68, MAPE=4.32%
#
# [INFO] Iteration 163: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.12%
# [INFO] Predicted last sample of window: Actual=70.55, Pred=69.06, MAPE=2.12%
#
# [INFO] Iteration 164: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.19%
# [INFO] Predicted last sample of window: Actual=68.26, Pred=68.39, MAPE=0.19%
#
# [INFO] Iteration 165: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.15%
# [INFO] Predicted last sample of window: Actual=67.08, Pred=66.98, MAPE=0.15%
#
# [INFO] Iteration 166: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.88%
# [INFO] Predicted last sample of window: Actual=69.76, Pred=68.45, MAPE=1.88%
#
# [INFO] Iteration 167: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.44%
# [INFO] Predicted last sample of window: Actual=72.73, Pred=70.22, MAPE=3.44%
#
# [INFO] Iteration 168: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.85%
# [INFO] Predicted last sample of window: Actual=70.19, Pred=70.79, MAPE=0.85%
#
# [INFO] Iteration 169: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.82%
# [INFO] Predicted last sample of window: Actual=65.79, Pred=69.62, MAPE=5.82%
#
# [INFO] Iteration 170: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.92%
# [INFO] Predicted last sample of window: Actual=64.61, Pred=65.85, MAPE=1.92%
#
# [INFO] Iteration 171: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.04%
# [INFO] Predicted last sample of window: Actual=65.33, Pred=65.30, MAPE=0.04%
#
# [INFO] Iteration 172: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=65.15, Pred=65.15, MAPE=0.00%
#
# [INFO] Iteration 173: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.72%
# [INFO] Predicted last sample of window: Actual=64.74, Pred=65.21, MAPE=0.72%
#
# [INFO] Iteration 174: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.95%
# [INFO] Predicted last sample of window: Actual=68.05, Pred=65.36, MAPE=3.95%
#
# [INFO] Iteration 175: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.27%
# [INFO] Predicted last sample of window: Actual=68.89, Pred=67.32, MAPE=2.27%
#
# [INFO] Iteration 176: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.54%
# [INFO] Predicted last sample of window: Actual=64.94, Pred=67.24, MAPE=3.54%
#
# [INFO] Iteration 177: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.89%
# [INFO] Predicted last sample of window: Actual=62.18, Pred=65.22, MAPE=4.89%
#
# [INFO] Iteration 178: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.38%
# [INFO] Predicted last sample of window: Actual=63.51, Pred=63.27, MAPE=0.38%
#
# [INFO] Iteration 179: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.52%
# [INFO] Predicted last sample of window: Actual=58.61, Pred=61.85, MAPE=5.52%
#
# [INFO] Iteration 180: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.10%
# [INFO] Predicted last sample of window: Actual=58.77, Pred=58.71, MAPE=0.10%
#
# [INFO] Iteration 181: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.89%
# [INFO] Predicted last sample of window: Actual=56.75, Pred=58.39, MAPE=2.89%
#
# [INFO] Iteration 182: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.52%
# [INFO] Predicted last sample of window: Actual=57.54, Pred=57.24, MAPE=0.52%
#
# [INFO] Iteration 183: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.96%
# [INFO] Predicted last sample of window: Actual=58.18, Pred=57.62, MAPE=0.96%
#
# [INFO] Iteration 184: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.02%
# [INFO] Predicted last sample of window: Actual=58.07, Pred=58.08, MAPE=0.02%
#
# [INFO] Iteration 185: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.50%
# [INFO] Predicted last sample of window: Actual=57.80, Pred=58.09, MAPE=0.50%
#
# [INFO] Iteration 186: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.33%
# [INFO] Predicted last sample of window: Actual=60.50, Pred=57.88, MAPE=4.33%
#
# [INFO] Iteration 187: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 7.10%
# [INFO] Predicted last sample of window: Actual=56.41, Pred=60.41, MAPE=7.10%
#
# [INFO] Iteration 188: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.26%
# [INFO] Predicted last sample of window: Actual=58.00, Pred=58.15, MAPE=0.26%
#
# [INFO] Iteration 189: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.09%
# [INFO] Predicted last sample of window: Actual=59.67, Pred=58.42, MAPE=2.09%
#
# [INFO] Iteration 190: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.03%
# [INFO] Predicted last sample of window: Actual=56.97, Pred=58.12, MAPE=2.03%
#
# [INFO] Iteration 191: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 7.85%
# [INFO] Predicted last sample of window: Actual=52.73, Pred=56.87, MAPE=7.85%
#
# [INFO] Iteration 192: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=52.44, Pred=52.44, MAPE=0.00%
#
# [INFO] Iteration 193: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.36%
# [INFO] Predicted last sample of window: Actual=53.52, Pred=52.79, MAPE=1.36%
#
# [INFO] Iteration 194: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.53%
# [INFO] Predicted last sample of window: Actual=54.06, Pred=53.77, MAPE=0.53%
#
# [INFO] Iteration 195: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.41%
# [INFO] Predicted last sample of window: Actual=54.83, Pred=54.06, MAPE=1.41%
#
# [INFO] Iteration 196: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.18%
# [INFO] Predicted last sample of window: Actual=55.44, Pred=54.78, MAPE=1.18%
#
# [INFO] Iteration 197: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.05%
# [INFO] Predicted last sample of window: Actual=55.32, Pred=55.35, MAPE=0.05%
#
# [INFO] Iteration 198: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.10%
# [INFO] Predicted last sample of window: Actual=55.39, Pred=55.33, MAPE=0.10%
#
# [INFO] Iteration 199: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.03%
# [INFO] Predicted last sample of window: Actual=55.97, Pred=55.39, MAPE=1.03%
#
# [INFO] Iteration 200: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.45%
# [INFO] Predicted last sample of window: Actual=58.95, Pred=56.91, MAPE=3.45%
#
# [INFO] Iteration 201: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.02%
# [INFO] Predicted last sample of window: Actual=58.94, Pred=58.93, MAPE=0.02%
#
# [INFO] Iteration 202: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.29%
# [INFO] Predicted last sample of window: Actual=56.02, Pred=58.98, MAPE=5.29%
#
# [INFO] Iteration 203: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.63%
# [INFO] Predicted last sample of window: Actual=57.04, Pred=57.40, MAPE=0.63%
#
# [INFO] Iteration 204: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.01%
# [INFO] Predicted last sample of window: Actual=59.36, Pred=57.57, MAPE=3.01%
#
# [INFO] Iteration 205: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.94%
# [INFO] Predicted last sample of window: Actual=62.52, Pred=59.43, MAPE=4.94%
#
# [INFO] Iteration 206: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.37%
# [INFO] Predicted last sample of window: Actual=64.82, Pred=62.64, MAPE=3.37%
#
# [INFO] Iteration 207: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.21%
# [INFO] Predicted last sample of window: Actual=63.44, Pred=63.57, MAPE=0.21%
#
# [INFO] Iteration 208: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.02%
# [INFO] Predicted last sample of window: Actual=63.39, Pred=63.40, MAPE=0.02%
#
# [INFO] Iteration 209: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.17%
# [INFO] Predicted last sample of window: Actual=63.28, Pred=63.39, MAPE=0.17%
#
# [INFO] Iteration 210: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.37%
# [INFO] Predicted last sample of window: Actual=62.55, Pred=63.40, MAPE=1.37%
#
# [INFO] Iteration 211: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.51%
# [INFO] Predicted last sample of window: Actual=61.91, Pred=62.85, MAPE=1.51%
#
# [INFO] Iteration 212: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.14%
# [INFO] Predicted last sample of window: Actual=60.81, Pred=61.50, MAPE=1.14%
#
# [INFO] Iteration 213: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.07%
# [INFO] Predicted last sample of window: Actual=61.04, Pred=61.00, MAPE=0.07%
#
# [INFO] Iteration 214: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.97%
# [INFO] Predicted last sample of window: Actual=58.83, Pred=60.58, MAPE=2.97%
#
# [INFO] Iteration 215: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.78%
# [INFO] Predicted last sample of window: Actual=61.69, Pred=59.98, MAPE=2.78%
#
# [INFO] Iteration 216: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.37%
# [INFO] Predicted last sample of window: Actual=63.76, Pred=61.61, MAPE=3.37%
#
# [INFO] Iteration 217: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.09%
# [INFO] Predicted last sample of window: Actual=63.74, Pred=63.05, MAPE=1.09%
#
# [INFO] Iteration 218: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.78%
# [INFO] Predicted last sample of window: Actual=62.56, Pred=63.05, MAPE=0.78%
#
# [INFO] Iteration 219: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.04%
# [INFO] Predicted last sample of window: Actual=61.78, Pred=61.76, MAPE=0.04%
#
# [INFO] Iteration 220: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.74%
# [INFO] Predicted last sample of window: Actual=62.08, Pred=61.62, MAPE=0.74%
#
# [INFO] Iteration 221: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.27%
# [INFO] Predicted last sample of window: Actual=63.88, Pred=61.79, MAPE=3.27%
#
# [INFO] Iteration 222: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.63%
# [INFO] Predicted last sample of window: Actual=66.73, Pred=63.64, MAPE=4.63%
#
# [INFO] Iteration 223: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.10%
# [INFO] Predicted last sample of window: Actual=66.43, Pred=66.36, MAPE=0.10%
#
# [INFO] Iteration 224: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.56%
# [INFO] Predicted last sample of window: Actual=64.11, Pred=66.39, MAPE=3.56%
#
# [INFO] Iteration 225: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.01%
# [INFO] Predicted last sample of window: Actual=64.90, Pred=64.91, MAPE=0.01%
#
# [INFO] Iteration 226: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.73%
# [INFO] Predicted last sample of window: Actual=66.06, Pred=64.92, MAPE=1.73%
#
# [INFO] Iteration 227: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.77%
# [INFO] Predicted last sample of window: Actual=60.45, Pred=63.94, MAPE=5.77%
#
# [INFO] Iteration 228: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.60%
# [INFO] Predicted last sample of window: Actual=58.93, Pred=61.05, MAPE=3.60%
#
# [INFO] Iteration 229: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 6.25%
# [INFO] Predicted last sample of window: Actual=64.23, Pred=60.22, MAPE=6.25%
#
# [INFO] Iteration 230: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.79%
# [INFO] Predicted last sample of window: Actual=66.99, Pred=63.78, MAPE=4.79%
#
# [INFO] Iteration 231: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.81%
# [INFO] Predicted last sample of window: Actual=64.64, Pred=65.81, MAPE=1.81%
#
# [INFO] Iteration 232: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.25%
# [INFO] Predicted last sample of window: Actual=64.16, Pred=64.96, MAPE=1.25%
#
# [INFO] Iteration 233: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.49%
# [INFO] Predicted last sample of window: Actual=67.44, Pred=65.09, MAPE=3.49%
#
# [INFO] Iteration 234: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.21%
# [INFO] Predicted last sample of window: Actual=66.93, Pred=66.79, MAPE=0.21%
#
# [INFO] Iteration 235: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.21%
# [INFO] Predicted last sample of window: Actual=68.47, Pred=66.95, MAPE=2.21%
#
# [INFO] Iteration 236: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.49%
# [INFO] Predicted last sample of window: Actual=72.20, Pred=68.96, MAPE=4.49%
#
# [INFO] Iteration 237: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.95%
# [INFO] Predicted last sample of window: Actual=71.44, Pred=70.76, MAPE=0.95%
#
# [INFO] Iteration 238: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.17%
# [INFO] Predicted last sample of window: Actual=67.64, Pred=70.46, MAPE=4.17%
#
# [INFO] Iteration 239: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.10%
# [INFO] Predicted last sample of window: Actual=66.67, Pred=66.61, MAPE=0.10%
#
# [INFO] Iteration 240: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.09%
# [INFO] Predicted last sample of window: Actual=70.62, Pred=67.73, MAPE=4.09%
#
# [INFO] Iteration 241: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.85%
# [INFO] Predicted last sample of window: Actual=74.27, Pred=70.67, MAPE=4.85%
#
# [INFO] Iteration 242: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.63%
# [INFO] Predicted last sample of window: Actual=74.66, Pred=74.19, MAPE=0.63%
#
# [INFO] Iteration 243: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.04%
# [INFO] Predicted last sample of window: Actual=75.44, Pred=74.66, MAPE=1.04%
#
# [INFO] Iteration 244: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.42%
# [INFO] Predicted last sample of window: Actual=75.76, Pred=75.44, MAPE=0.42%
#
# [INFO] Iteration 245: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.98%
# [INFO] Predicted last sample of window: Actual=74.72, Pred=75.45, MAPE=0.98%
#
# [INFO] Iteration 246: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.52%
# [INFO] Predicted last sample of window: Actual=73.47, Pred=73.09, MAPE=0.52%
#
# [INFO] Iteration 247: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.12%
# [INFO] Predicted last sample of window: Actual=76.39, Pred=74.77, MAPE=2.12%
#
# [INFO] Iteration 248: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.16%
# [INFO] Predicted last sample of window: Actual=78.09, Pred=76.40, MAPE=2.16%
#
# [INFO] Iteration 249: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.57%
# [INFO] Predicted last sample of window: Actual=77.64, Pred=78.08, MAPE=0.57%
#
# [INFO] Iteration 250: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.13%
# [INFO] Predicted last sample of window: Actual=77.99, Pred=78.09, MAPE=0.13%
#
# [INFO] Iteration 251: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.20%
# [INFO] Predicted last sample of window: Actual=75.03, Pred=77.43, MAPE=3.20%
#
# ...
#
# [INFO] Iteration 419: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.28%
# [INFO] Predicted last sample of window: Actual=63.72, Pred=62.27, MAPE=2.28%
#
# [INFO] Iteration 420: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.76%
# [INFO] Predicted last sample of window: Actual=62.65, Pred=63.12, MAPE=0.76%
#
# [INFO] Iteration 421: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.44%
# [INFO] Predicted last sample of window: Actual=63.74, Pred=63.46, MAPE=0.44%
#
# [INFO] Iteration 422: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.05%
# [INFO] Predicted last sample of window: Actual=62.64, Pred=62.61, MAPE=0.05%
#
# [INFO] Iteration 423: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.05%
# [INFO] Predicted last sample of window: Actual=61.66, Pred=62.92, MAPE=2.05%
#
# [INFO] Iteration 424: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.19%
# [INFO] Predicted last sample of window: Actual=59.26, Pred=61.15, MAPE=3.19%
#
# [INFO] Iteration 425: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.34%
# [INFO] Predicted last sample of window: Actual=59.49, Pred=59.29, MAPE=0.34%
#
# [INFO] Iteration 426: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.58%
# [INFO] Predicted last sample of window: Actual=59.62, Pred=59.27, MAPE=0.58%
#
# [INFO] Iteration 427: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.98%
# [INFO] Predicted last sample of window: Actual=58.61, Pred=59.18, MAPE=0.98%
#
# [INFO] Iteration 428: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 18.46%
# [INFO] Predicted last sample of window: Actual=60.81, Pred=49.58, MAPE=18.46%
#
# [INFO] Iteration 429: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.87%
# [INFO] Predicted last sample of window: Actual=64.17, Pred=61.05, MAPE=4.87%
#
# [INFO] Iteration 430: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.05%
# [INFO] Predicted last sample of window: Actual=63.65, Pred=63.62, MAPE=0.05%
#
# [INFO] Iteration 431: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.42%
# [INFO] Predicted last sample of window: Actual=64.76, Pred=63.84, MAPE=1.42%
#
# [INFO] Iteration 432: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.12%
# [INFO] Predicted last sample of window: Actual=63.55, Pred=63.62, MAPE=0.12%
#
# [INFO] Iteration 433: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.44%
# [INFO] Predicted last sample of window: Actual=65.41, Pred=63.82, MAPE=2.44%
#
# [INFO] Iteration 434: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.50%
# [INFO] Predicted last sample of window: Actual=67.65, Pred=67.31, MAPE=0.50%
#
# [INFO] Iteration 435: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.18%
# [INFO] Predicted last sample of window: Actual=68.69, Pred=67.88, MAPE=1.18%
#
# [INFO] Iteration 436: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.78%
# [INFO] Predicted last sample of window: Actual=73.87, Pred=69.60, MAPE=5.78%
#
# [INFO] Iteration 437: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.68%
# [INFO] Predicted last sample of window: Actual=74.98, Pred=74.47, MAPE=0.68%
#
# [INFO] Iteration 438: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.74%
# [INFO] Predicted last sample of window: Actual=72.75, Pred=74.74, MAPE=2.74%
#
# [INFO] Iteration 439: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.56%
# [INFO] Predicted last sample of window: Actual=72.61, Pred=72.20, MAPE=0.56%
#
# [INFO] Iteration 440: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.39%
# [INFO] Predicted last sample of window: Actual=74.74, Pred=72.96, MAPE=2.39%
#
# [INFO] Iteration 441: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.07%
# [INFO] Predicted last sample of window: Actual=78.42, Pred=75.23, MAPE=4.07%
#
# [INFO] Iteration 442: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.08%
# [INFO] Predicted last sample of window: Actual=78.60, Pred=78.54, MAPE=0.08%
#
# [INFO] Iteration 443: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.50%
# [INFO] Predicted last sample of window: Actual=77.43, Pred=78.59, MAPE=1.50%
#
# [INFO] Iteration 444: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.63%
# [INFO] Predicted last sample of window: Actual=76.02, Pred=76.50, MAPE=0.63%
#
# [INFO] Iteration 445: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.37%
# [INFO] Predicted last sample of window: Actual=76.37, Pred=76.09, MAPE=0.37%
#
# [INFO] Iteration 446: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.23%
# [INFO] Predicted last sample of window: Actual=75.93, Pred=76.11, MAPE=0.23%
#
# [INFO] Iteration 447: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.03%
# [INFO] Predicted last sample of window: Actual=76.13, Pred=76.15, MAPE=0.03%
#
# [INFO] Iteration 448: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 12.43%
# [INFO] Predicted last sample of window: Actual=67.45, Pred=75.83, MAPE=12.43%
#
# [INFO] Iteration 449: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.97%
# [INFO] Predicted last sample of window: Actual=65.05, Pred=65.68, MAPE=0.97%
#
# [INFO] Iteration 450: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.92%
# [INFO] Predicted last sample of window: Actual=63.85, Pred=64.43, MAPE=0.92%
#
# [INFO] Iteration 451: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.03%
# [INFO] Predicted last sample of window: Actual=63.72, Pred=63.74, MAPE=0.03%
#
# [INFO] Iteration 452: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.04%
# [INFO] Predicted last sample of window: Actual=63.87, Pred=63.84, MAPE=0.04%
#
# [INFO] Iteration 453: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.61%
# [INFO] Predicted last sample of window: Actual=61.35, Pred=62.34, MAPE=1.61%
#
# [INFO] Iteration 454: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.15%
# [INFO] Predicted last sample of window: Actual=59.32, Pred=60.00, MAPE=1.15%
#
# [INFO] Iteration 455: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.08%
# [INFO] Predicted last sample of window: Actual=59.55, Pred=59.50, MAPE=0.08%
#
# [INFO] Iteration 456: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.23%
# [INFO] Predicted last sample of window: Actual=60.55, Pred=59.81, MAPE=1.23%
#
# [INFO] Iteration 457: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.32%
# [INFO] Predicted last sample of window: Actual=61.62, Pred=60.80, MAPE=1.32%
#
# [INFO] Iteration 458: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.05%
# [INFO] Predicted last sample of window: Actual=62.62, Pred=61.96, MAPE=1.05%
#
# [INFO] Iteration 459: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.46%
# [INFO] Predicted last sample of window: Actual=64.28, Pred=62.70, MAPE=2.46%
#
# [INFO] Iteration 460: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.68%
# [INFO] Predicted last sample of window: Actual=61.59, Pred=62.62, MAPE=1.68%
#
# [INFO] Iteration 461: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.86%
# [INFO] Predicted last sample of window: Actual=59.95, Pred=59.44, MAPE=0.86%
#
# [INFO] Iteration 462: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.58%
# [INFO] Predicted last sample of window: Actual=59.63, Pred=59.98, MAPE=0.58%
#
# [INFO] Iteration 463: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.28%
# [INFO] Predicted last sample of window: Actual=59.25, Pred=58.49, MAPE=1.28%
#
# [INFO] Iteration 464: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.99%
# [INFO] Predicted last sample of window: Actual=58.04, Pred=58.61, MAPE=0.99%
#
# [INFO] Iteration 465: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.33%
# [INFO] Predicted last sample of window: Actual=57.62, Pred=57.81, MAPE=0.33%
#
# [INFO] Iteration 466: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.04%
# [INFO] Predicted last sample of window: Actual=55.65, Pred=56.79, MAPE=2.04%
#
# [INFO] Iteration 467: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.56%
# [INFO] Predicted last sample of window: Actual=55.08, Pred=55.39, MAPE=0.56%
#
# [INFO] Iteration 468: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.11%
# [INFO] Predicted last sample of window: Actual=56.09, Pred=55.47, MAPE=1.11%
#
# [INFO] Iteration 469: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.24%
# [INFO] Predicted last sample of window: Actual=55.45, Pred=55.32, MAPE=0.24%
#
# [INFO] Iteration 470: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=53.96, Pred=53.96, MAPE=0.00%
#
# [INFO] Iteration 471: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.68%
# [INFO] Predicted last sample of window: Actual=52.00, Pred=53.91, MAPE=3.68%
#
# [INFO] Iteration 472: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.25%
# [INFO] Predicted last sample of window: Actual=53.95, Pred=52.73, MAPE=2.25%
#
# [INFO] Iteration 473: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.36%
# [INFO] Predicted last sample of window: Actual=51.36, Pred=52.57, MAPE=2.36%
#
# [INFO] Iteration 474: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.50%
# [INFO] Predicted last sample of window: Actual=54.57, Pred=53.75, MAPE=1.50%
#
# [INFO] Iteration 475: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.14%
# [INFO] Predicted last sample of window: Actual=54.93, Pred=55.00, MAPE=0.14%
#
# [INFO] Iteration 476: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.20%
# [INFO] Predicted last sample of window: Actual=53.45, Pred=54.63, MAPE=2.20%
#
# [INFO] Iteration 477: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.54%
# [INFO] Predicted last sample of window: Actual=52.52, Pred=52.80, MAPE=0.54%
#
# [INFO] Iteration 478: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.48%
# [INFO] Predicted last sample of window: Actual=50.87, Pred=51.62, MAPE=1.48%
#
# [INFO] Iteration 479: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.16%
# [INFO] Predicted last sample of window: Actual=51.23, Pred=51.15, MAPE=0.16%
#
# [INFO] Iteration 480: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.43%
# [INFO] Predicted last sample of window: Actual=54.13, Pred=51.19, MAPE=5.43%
#
# [INFO] Iteration 481: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.63%
# [INFO] Predicted last sample of window: Actual=59.18, Pred=60.73, MAPE=2.63%
#
# [INFO] Iteration 482: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.28%
# [INFO] Predicted last sample of window: Actual=58.70, Pred=58.87, MAPE=0.28%
#
# [INFO] Iteration 483: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.84%
# [INFO] Predicted last sample of window: Actual=57.40, Pred=59.03, MAPE=2.84%
#
# [INFO] Iteration 484: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.05%
# [INFO] Predicted last sample of window: Actual=57.95, Pred=57.92, MAPE=0.05%
#
# [INFO] Iteration 485: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.43%
# [INFO] Predicted last sample of window: Actual=61.06, Pred=58.96, MAPE=3.43%
#
# [INFO] Iteration 486: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.15%
# [INFO] Predicted last sample of window: Actual=60.98, Pred=61.07, MAPE=0.15%
#
# [INFO] Iteration 487: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.32%
# [INFO] Predicted last sample of window: Actual=60.21, Pred=61.00, MAPE=1.32%
#
# [INFO] Iteration 488: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.50%
# [INFO] Predicted last sample of window: Actual=61.46, Pred=61.15, MAPE=0.50%
#
# [INFO] Iteration 489: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.02%
# [INFO] Predicted last sample of window: Actual=61.44, Pred=61.45, MAPE=0.02%
#
# [INFO] Iteration 490: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.74%
# [INFO] Predicted last sample of window: Actual=60.99, Pred=61.44, MAPE=0.74%
#
# [INFO] Iteration 491: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.99%
# [INFO] Predicted last sample of window: Actual=63.60, Pred=61.70, MAPE=2.99%
#
# [INFO] Iteration 492: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.54%
# [INFO] Predicted last sample of window: Actual=62.85, Pred=63.19, MAPE=0.54%
#
# [INFO] Iteration 493: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.29%
# [INFO] Predicted last sample of window: Actual=63.80, Pred=63.61, MAPE=0.29%
#
# [INFO] Iteration 494: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.34%
# [INFO] Predicted last sample of window: Actual=61.81, Pred=60.98, MAPE=1.34%
#
# [INFO] Iteration 495: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 8.87%
# [INFO] Predicted last sample of window: Actual=69.41, Pred=63.26, MAPE=8.87%
#
# [INFO] Iteration 496: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.11%
# [INFO] Predicted last sample of window: Actual=67.17, Pred=67.25, MAPE=0.11%
#
# [INFO] Iteration 497: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.35%
# [INFO] Predicted last sample of window: Actual=69.58, Pred=69.82, MAPE=0.35%
#
# [INFO] Iteration 498: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.17%
# [INFO] Predicted last sample of window: Actual=70.82, Pred=70.70, MAPE=0.17%
#
# [INFO] Iteration 499: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.34%
# [INFO] Predicted last sample of window: Actual=71.84, Pred=70.88, MAPE=1.34%
#
# [INFO] Iteration 500: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.52%
# [INFO] Predicted last sample of window: Actual=70.83, Pred=71.20, MAPE=0.52%
# [INFO] No more windows can be extracted.
#
# [INFO] Rolling training with Early Stopping completed for LPX. Overall MAPE: 2.25%
# [INFO] Total elapsed time: 861.35s
# [INFO] Top 10 worst predictions in rolling scenario (Early Stopping):
#           Date     Actual  Predicted       MAPE
# 25  2020-03-24  18.639999  15.138652  18.784054
# 427 2023-06-02  60.810001  49.583931  18.460895
# 391 2023-02-17  56.730000  65.261269  15.038373
# 52  2020-06-10  22.549999  25.912554  14.911551
# 19  2020-03-06  23.700001  27.002007  13.932513
# 291 2022-05-03  77.900002  67.498528  13.352341
# 447 2023-08-01  67.449997  75.832962  12.428414
# 306 2022-06-15  54.040001  60.486881  11.929830
# 37  2020-04-28  21.139999  19.022526  10.016432
# 494 2023-12-13  69.410004  63.256153   8.865942
