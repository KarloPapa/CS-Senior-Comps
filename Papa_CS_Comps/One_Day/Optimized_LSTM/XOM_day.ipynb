# %%
import pandas as pd
import numpy as np
import yfinance as yf
import talib
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os
import math
import time

########################
# Configuration
########################
ticker = 'XOM'
start_date = '2020-01-01'
end_date = '2024-01-01'
1
# Hyperparameters
n_steps = 2
window_size = 5
step_size = 2
initial_epochs = 100
update_epochs = 100
initial_lr = 0.0005
update_lr = 0.00005
train_ratio = 0.9
n_units = 16
batch_size = 4

# If you change features or other logic, do so below
if not os.path.exists("rolling_error_analysis_results"):
    os.makedirs("rolling_error_analysis_results")


def load_full_data_helper(ticker, start_date, end_date, window_size):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data.reset_index(inplace=True)
    if stock_data.empty:
        return None, None, None

    # Next day prediction setup
    stock_data['Close_next_day'] = stock_data['Close'].shift(-1)
    stock_data.dropna(subset=['Close_next_day'], inplace=True)

    # Simple features
    X_feat = stock_data[['Open', 'High', 'Low']]
    y_raw = stock_data['Close_next_day'].values
    dates = stock_data['Date'].values

    if len(dates) < window_size:
        return None, None, None
    return X_feat.values, y_raw, dates


def load_full_data(ticker, start_date, end_date, window_size):
    X_feat, y_raw, dates = load_full_data_helper(ticker, start_date, end_date, window_size)
    if X_feat is None:
        return None, None, None
    return X_feat, y_raw, dates


def extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps):
    end_idx = start_idx + window_size
    if end_idx > len(X_full):
        return None, None, None, None, None, None

    X_window = X_full[start_idx:end_idx]
    y_window = y_full[start_idx:end_idx]
    dates_window = dates_full[start_idx:end_idx]

    def lstm_split(dataX, dataY, n_steps):
        X, y = [], []
        for i in range(len(dataX)-n_steps+1):
            X.append(dataX[i:i+n_steps])
            y.append(dataY[i+n_steps-1])
        return np.array(X), np.array(y)

    X_samples, y_samples = lstm_split(X_window, y_window, n_steps)
    sample_dates = dates_window[n_steps-1:]

    feat_scaler = RobustScaler()
    target_scaler = RobustScaler()
    X_flat = X_window.reshape(len(X_window), -1)
    feat_scaler.fit(X_flat)
    y_window_reshaped = y_window.reshape(-1,1)
    target_scaler.fit(y_window_reshaped)

    X_scaled = feat_scaler.transform(X_flat).reshape(X_window.shape)
    y_scaled = target_scaler.transform(y_window_reshaped).flatten()
    X_samples_scaled, y_samples_scaled = lstm_split(X_scaled, y_scaled, n_steps)

    return X_samples_scaled, y_samples_scaled, sample_dates, feat_scaler, target_scaler, (X_window, y_window, dates_window)


def create_lstm_model(n_units, learning_rate, n_steps, n_features, n_layers=1):
    inputs = Input(shape=(n_steps, n_features))
    x = LSTM(n_units, activation='relu', return_sequences=(n_layers > 1))(inputs)
    if n_layers > 1:
        x = LSTM(n_units, activation='relu')(x)
    outputs = Dense(1)(x)
    model = Model(inputs, outputs)
    # We'll compile after loading weights if needed
    return model


def train_on_window(X_samples, y_samples, feat_scaler, target_scaler,
                    initial_training=False, prev_weights=None):
    total_samples = len(X_samples)
    global train_ratio
    train_count = int(math.floor(total_samples * train_ratio))
    if train_count >= total_samples:
        train_count = total_samples - 1

    X_train, y_train = X_samples[:train_count], y_samples[:train_count]
    X_val, y_val = X_samples[train_count:], y_samples[train_count:]

    if X_train.size == 0 or X_val.size == 0:
        return None, np.nan

    n_steps_local = X_train.shape[1]
    n_features = X_train.shape[2]

    if initial_training:
        epochs = initial_epochs
        lr = initial_lr
    else:
        epochs = update_epochs
        lr = update_lr

    model = create_lstm_model(n_units, lr, n_steps_local, n_features, n_layers=1)

    if prev_weights is not None:
        model.load_weights(prev_weights)

    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=lr))

    es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0, shuffle=False,
              validation_data=(X_val, y_val), callbacks=[es])

    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_unscaled = target_scaler.inverse_transform(y_val.reshape(-1,1)).flatten()
    y_val_pred_unscaled = target_scaler.inverse_transform(y_val_pred_scaled).flatten()
    val_mape = mean_absolute_percentage_error(y_val_unscaled, y_val_pred_unscaled) * 100

    return model, val_mape


def rolling_training_early_stopping(ticker, window_size, step_size, n_steps):
    X_full, y_full, dates_full = load_full_data(ticker, start_date, end_date, window_size)
    if X_full is None:
        print("[WARN] Not enough data.")
        return

    start_time = time.time()

    start_idx = 0
    window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
    if window_data[0] is None:
        print("[WARN] Initial window not valid.")
        return
    X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

    print("[INFO] Training initial window with Early Stopping...")
    model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=True, prev_weights=None)
    print(f"[RESULT] Initial window validation MAPE: {val_mape:.2f}%")

    weights_path = "rolling_error_analysis_results/cost_initial_es.weights.h5"
    model.save_weights(weights_path)

    predictions = []
    actuals = []
    pred_dates = []

    iteration = 1
    while True:
        start_idx += step_size
        window_data = extract_window(X_full, y_full, dates_full, start_idx, window_size, n_steps)
        if window_data[0] is None:
            print("[INFO] No more windows can be extracted.")
            break
        X_samples, y_samples, sample_dates, feat_scaler, target_scaler, (Xw, yw, dw) = window_data

        print(f"\n[INFO] Iteration {iteration}: training on new window with Early Stopping...")
        model, val_mape = train_on_window(X_samples, y_samples, feat_scaler, target_scaler, initial_training=False, prev_weights=weights_path)
        print(f"[RESULT] Window validation MAPE: {val_mape:.2f}%")

        weights_path = f"rolling_error_analysis_results/cost_iteration_{iteration}_es.weights.h5"
        model.save_weights(weights_path)

        X_test_last = X_samples[-1:]
        y_test_last = y_samples[-1:]
        y_pred_scaled = model.predict(X_test_last, verbose=0)
        y_test_unscaled = target_scaler.inverse_transform(y_test_last.reshape(-1,1)).flatten()
        y_pred_unscaled = target_scaler.inverse_transform(y_pred_scaled).flatten()

        predictions.append(y_pred_unscaled[0])
        actuals.append(y_test_unscaled[0])
        pred_dates.append(sample_dates[-1])

        test_mape = mean_absolute_percentage_error(y_test_unscaled, y_pred_unscaled)*100
        print(f"[INFO] Predicted last sample of window: Actual={y_test_unscaled[0]:.2f}, Pred={y_pred_unscaled[0]:.2f}, MAPE={test_mape:.2f}%")

        iteration += 1

    df_results = pd.DataFrame({
        'Date': pred_dates,
        'Actual': actuals,
        'Predicted': predictions
    })
    df_results['Absolute_Error'] = np.abs(df_results['Actual'] - df_results['Predicted'])
    df_results['APE'] = df_results['Absolute_Error'] / np.abs(df_results['Actual'])
    df_results['MAPE'] = df_results['APE'] * 100.0

    df_results.to_csv("rolling_error_analysis_results/cost_rolling_results_es.csv", index=False)
    overall_mape = df_results['MAPE'].mean()
    print(f"\n[INFO] Rolling training with Early Stopping completed for {ticker}. Overall MAPE: {overall_mape:.2f}%")
    elapsed = time.time() - start_time
    print(f"[INFO] Total elapsed time: {elapsed:.2f}s")

    worst_10 = df_results.sort_values('MAPE', ascending=False).head(10)
    print("[INFO] Top 10 worst predictions in rolling scenario (Early Stopping):")
    print(worst_10[['Date', 'Actual', 'Predicted', 'MAPE']])

if __name__ == "__main__":
    # Just run with the current top-level defined parameters:
    rolling_training_early_stopping(ticker, window_size, step_size, n_steps)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [INFO] Training initial window with Early Stopping...
# [RESULT] Initial window validation MAPE: 0.51%
#
# [INFO] Iteration 1: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.19%
# [INFO] Predicted last sample of window: Actual=69.80, Pred=69.67, MAPE=0.19%
#
# [INFO] Iteration 2: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.10%
# [INFO] Predicted last sample of window: Actual=69.09, Pred=69.02, MAPE=0.10%
#
# [INFO] Iteration 3: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.71%
# [INFO] Predicted last sample of window: Actual=68.56, Pred=69.04, MAPE=0.71%
#
# [INFO] Iteration 4: training on new window with Early Stopping...
# WARNING:tensorflow:5 out of the last 8 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x15d6cdb20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [RESULT] Window validation MAPE: 1.07%
# [INFO] Predicted last sample of window: Actual=67.19, Pred=67.91, MAPE=1.07%
#
# [INFO] Iteration 5: training on new window with Early Stopping...
# WARNING:tensorflow:6 out of the last 10 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x15e875bc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [RESULT] Window validation MAPE: 0.94%
# [INFO] Predicted last sample of window: Actual=66.32, Pred=66.94, MAPE=0.94%
#
# [INFO] Iteration 6: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.46%
# [INFO] Predicted last sample of window: Actual=64.65, Pred=65.60, MAPE=1.46%
#
# [INFO] Iteration 7: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.12%
# [INFO] Predicted last sample of window: Actual=64.79, Pred=64.71, MAPE=0.12%
#
# [INFO] Iteration 8: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.26%
# [INFO] Predicted last sample of window: Actual=60.73, Pred=61.49, MAPE=1.26%
#
# [INFO] Iteration 9: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.89%
# [INFO] Predicted last sample of window: Actual=62.73, Pred=61.55, MAPE=1.89%
#
# [INFO] Iteration 10: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.10%
# [INFO] Predicted last sample of window: Actual=61.47, Pred=61.41, MAPE=0.10%
#
# [INFO] Iteration 11: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.98%
# [INFO] Predicted last sample of window: Actual=60.53, Pred=61.12, MAPE=0.98%
#
# [INFO] Iteration 12: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.20%
# [INFO] Predicted last sample of window: Actual=60.93, Pred=60.81, MAPE=0.20%
#
# [INFO] Iteration 13: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.22%
# [INFO] Predicted last sample of window: Actual=59.88, Pred=60.61, MAPE=1.22%
#
# [INFO] Iteration 14: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.40%
# [INFO] Predicted last sample of window: Actual=59.86, Pred=60.10, MAPE=0.40%
#
# [INFO] Iteration 15: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.22%
# [INFO] Predicted last sample of window: Actual=56.36, Pred=59.30, MAPE=5.22%
#
# [INFO] Iteration 16: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.49%
# [INFO] Predicted last sample of window: Actual=53.01, Pred=54.33, MAPE=2.49%
#
# [INFO] Iteration 17: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.69%
# [INFO] Predicted last sample of window: Actual=51.44, Pred=51.79, MAPE=0.69%
#
# [INFO] Iteration 18: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.46%
# [INFO] Predicted last sample of window: Actual=51.30, Pred=51.06, MAPE=0.46%
#
# [INFO] Iteration 19: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.58%
# [INFO] Predicted last sample of window: Actual=50.11, Pred=51.40, MAPE=2.58%
#
# [INFO] Iteration 20: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 14.96%
# [INFO] Predicted last sample of window: Actual=41.86, Pred=48.12, MAPE=14.96%
#
# [INFO] Iteration 21: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.66%
# [INFO] Predicted last sample of window: Actual=41.98, Pred=41.70, MAPE=0.66%
#
# [INFO] Iteration 22: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=38.12, Pred=38.12, MAPE=0.00%
#
# [INFO] Iteration 23: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.07%
# [INFO] Predicted last sample of window: Actual=36.81, Pred=36.84, MAPE=0.07%
#
# [INFO] Iteration 24: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.96%
# [INFO] Predicted last sample of window: Actual=34.43, Pred=33.75, MAPE=1.96%
#
# [INFO] Iteration 25: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.36%
# [INFO] Predicted last sample of window: Actual=31.45, Pred=32.82, MAPE=4.36%
#
# [INFO] Iteration 26: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 9.18%
# [INFO] Predicted last sample of window: Actual=37.29, Pred=33.87, MAPE=9.18%
#
# [INFO] Iteration 27: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.34%
# [INFO] Predicted last sample of window: Actual=36.95, Pred=37.08, MAPE=0.34%
#
# [INFO] Iteration 28: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.39%
# [INFO] Predicted last sample of window: Actual=37.97, Pred=37.44, MAPE=1.39%
#
# [INFO] Iteration 29: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 7.12%
# [INFO] Predicted last sample of window: Actual=40.40, Pred=37.52, MAPE=7.12%
#
# [INFO] Iteration 30: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.46%
# [INFO] Predicted last sample of window: Actual=40.47, Pred=39.47, MAPE=2.46%
#
# [INFO] Iteration 31: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 7.72%
# [INFO] Predicted last sample of window: Actual=43.85, Pred=40.46, MAPE=7.72%
#
# [INFO] Iteration 32: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.19%
# [INFO] Predicted last sample of window: Actual=42.76, Pred=43.27, MAPE=1.19%
#
# [INFO] Iteration 33: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.57%
# [INFO] Predicted last sample of window: Actual=40.48, Pred=42.74, MAPE=5.57%
#
# [INFO] Iteration 34: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.33%
# [INFO] Predicted last sample of window: Actual=43.22, Pred=41.78, MAPE=3.33%
#
# [INFO] Iteration 35: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.07%
# [INFO] Predicted last sample of window: Actual=40.96, Pred=40.93, MAPE=0.07%
#
# [INFO] Iteration 36: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.69%
# [INFO] Predicted last sample of window: Actual=43.45, Pred=43.15, MAPE=0.69%
#
# [INFO] Iteration 37: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.90%
# [INFO] Predicted last sample of window: Actual=43.94, Pred=43.55, MAPE=0.90%
#
# [INFO] Iteration 38: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 7.40%
# [INFO] Predicted last sample of window: Actual=47.46, Pred=43.95, MAPE=7.40%
#
# [INFO] Iteration 39: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.09%
# [INFO] Predicted last sample of window: Actual=43.14, Pred=45.34, MAPE=5.09%
#
# [INFO] Iteration 40: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.39%
# [INFO] Predicted last sample of window: Actual=44.83, Pred=44.66, MAPE=0.39%
#
# [INFO] Iteration 41: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.12%
# [INFO] Predicted last sample of window: Actual=44.24, Pred=44.19, MAPE=0.12%
#
# [INFO] Iteration 42: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.93%
# [INFO] Predicted last sample of window: Actual=45.74, Pred=44.86, MAPE=1.93%
#
# [INFO] Iteration 43: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.50%
# [INFO] Predicted last sample of window: Actual=41.93, Pred=44.24, MAPE=5.50%
#
# [INFO] Iteration 44: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.01%
# [INFO] Predicted last sample of window: Actual=42.00, Pred=42.00, MAPE=0.01%
#
# [INFO] Iteration 45: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.73%
# [INFO] Predicted last sample of window: Actual=43.94, Pred=42.30, MAPE=3.73%
#
# [INFO] Iteration 46: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.02%
# [INFO] Predicted last sample of window: Actual=44.56, Pred=44.55, MAPE=0.02%
#
# [INFO] Iteration 47: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.17%
# [INFO] Predicted last sample of window: Actual=45.91, Pred=44.45, MAPE=3.17%
#
# [INFO] Iteration 48: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.62%
# [INFO] Predicted last sample of window: Actual=45.04, Pred=45.32, MAPE=0.62%
#
# [INFO] Iteration 49: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.87%
# [INFO] Predicted last sample of window: Actual=46.28, Pred=45.88, MAPE=0.87%
#
# [INFO] Iteration 50: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.83%
# [INFO] Predicted last sample of window: Actual=49.24, Pred=46.37, MAPE=5.83%
#
# [INFO] Iteration 51: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 7.18%
# [INFO] Predicted last sample of window: Actual=53.08, Pred=49.27, MAPE=7.18%
#
# [INFO] Iteration 52: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.92%
# [INFO] Predicted last sample of window: Actual=53.52, Pred=54.01, MAPE=0.92%
#
# [INFO] Iteration 53: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 14.97%
# [INFO] Predicted last sample of window: Actual=46.18, Pred=53.09, MAPE=14.97%
#
# [INFO] Iteration 54: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.08%
# [INFO] Predicted last sample of window: Actual=47.14, Pred=47.10, MAPE=0.08%
#
# [INFO] Iteration 55: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.18%
# [INFO] Predicted last sample of window: Actual=46.63, Pred=47.18, MAPE=1.18%
#
# [INFO] Iteration 56: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.99%
# [INFO] Predicted last sample of window: Actual=45.98, Pred=46.89, MAPE=1.99%
#
# [INFO] Iteration 57: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.18%
# [INFO] Predicted last sample of window: Actual=46.70, Pred=46.61, MAPE=0.18%
#
# [INFO] Iteration 58: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.28%
# [INFO] Predicted last sample of window: Actual=45.17, Pred=45.75, MAPE=1.28%
#
# [INFO] Iteration 59: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.33%
# [INFO] Predicted last sample of window: Actual=44.32, Pred=44.46, MAPE=0.33%
#
# [INFO] Iteration 60: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.11%
# [INFO] Predicted last sample of window: Actual=43.71, Pred=44.19, MAPE=1.11%
#
# [INFO] Iteration 61: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.10%
# [INFO] Predicted last sample of window: Actual=44.39, Pred=44.35, MAPE=0.10%
#
# [INFO] Iteration 62: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.81%
# [INFO] Predicted last sample of window: Actual=43.14, Pred=43.49, MAPE=0.81%
#
# [INFO] Iteration 63: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.94%
# [INFO] Predicted last sample of window: Actual=42.65, Pred=43.05, MAPE=0.94%
#
# [INFO] Iteration 64: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.08%
# [INFO] Predicted last sample of window: Actual=44.07, Pred=42.71, MAPE=3.08%
#
# [INFO] Iteration 65: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.91%
# [INFO] Predicted last sample of window: Actual=44.28, Pred=45.13, MAPE=1.91%
#
# [INFO] Iteration 66: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.60%
# [INFO] Predicted last sample of window: Actual=42.50, Pred=44.03, MAPE=3.60%
#
# [INFO] Iteration 67: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.05%
# [INFO] Predicted last sample of window: Actual=43.61, Pred=43.59, MAPE=0.05%
#
# [INFO] Iteration 68: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.38%
# [INFO] Predicted last sample of window: Actual=43.43, Pred=43.60, MAPE=0.38%
#
# [INFO] Iteration 69: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.13%
# [INFO] Predicted last sample of window: Actual=43.55, Pred=43.61, MAPE=0.13%
#
# [INFO] Iteration 70: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.02%
# [INFO] Predicted last sample of window: Actual=41.87, Pred=43.55, MAPE=4.02%
#
# [INFO] Iteration 71: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.28%
# [INFO] Predicted last sample of window: Actual=42.25, Pred=42.13, MAPE=0.28%
#
# [INFO] Iteration 72: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.74%
# [INFO] Predicted last sample of window: Actual=43.85, Pred=42.21, MAPE=3.74%
#
# [INFO] Iteration 73: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.08%
# [INFO] Predicted last sample of window: Actual=43.44, Pred=43.48, MAPE=0.08%
#
# [INFO] Iteration 74: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.42%
# [INFO] Predicted last sample of window: Actual=44.97, Pred=43.88, MAPE=2.42%
#
# [INFO] Iteration 75: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.65%
# [INFO] Predicted last sample of window: Actual=43.01, Pred=44.15, MAPE=2.65%
#
# [INFO] Iteration 76: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.33%
# [INFO] Predicted last sample of window: Actual=42.64, Pred=43.21, MAPE=1.33%
#
# [INFO] Iteration 77: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.60%
# [INFO] Predicted last sample of window: Actual=41.96, Pred=42.63, MAPE=1.60%
#
# [INFO] Iteration 78: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.29%
# [INFO] Predicted last sample of window: Actual=41.01, Pred=41.95, MAPE=2.29%
#
# [INFO] Iteration 79: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.01%
# [INFO] Predicted last sample of window: Actual=40.88, Pred=41.29, MAPE=1.01%
#
# [INFO] Iteration 80: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.83%
# [INFO] Predicted last sample of window: Actual=39.74, Pred=40.86, MAPE=2.83%
#
# [INFO] Iteration 81: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.13%
# [INFO] Predicted last sample of window: Actual=39.94, Pred=39.99, MAPE=0.13%
#
# [INFO] Iteration 82: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.35%
# [INFO] Predicted last sample of window: Actual=39.19, Pred=39.72, MAPE=1.35%
#
# [INFO] Iteration 83: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.27%
# [INFO] Predicted last sample of window: Actual=39.08, Pred=39.19, MAPE=0.27%
#
# [INFO] Iteration 84: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.92%
# [INFO] Predicted last sample of window: Actual=37.95, Pred=38.30, MAPE=0.92%
#
# [INFO] Iteration 85: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.57%
# [INFO] Predicted last sample of window: Actual=36.90, Pred=37.85, MAPE=2.57%
#
# [INFO] Iteration 86: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.66%
# [INFO] Predicted last sample of window: Actual=36.27, Pred=36.87, MAPE=1.66%
#
# [INFO] Iteration 87: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.63%
# [INFO] Predicted last sample of window: Actual=37.80, Pred=36.80, MAPE=2.63%
#
# [INFO] Iteration 88: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.10%
# [INFO] Predicted last sample of window: Actual=36.43, Pred=37.20, MAPE=2.10%
#
# [INFO] Iteration 89: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.46%
# [INFO] Predicted last sample of window: Actual=34.39, Pred=36.27, MAPE=5.46%
#
# [INFO] Iteration 90: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.30%
# [INFO] Predicted last sample of window: Actual=34.64, Pred=34.54, MAPE=0.30%
#
# [INFO] Iteration 91: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.26%
# [INFO] Predicted last sample of window: Actual=34.28, Pred=34.37, MAPE=0.26%
#
# [INFO] Iteration 92: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.59%
# [INFO] Predicted last sample of window: Actual=33.13, Pred=34.32, MAPE=3.59%
#
# [INFO] Iteration 93: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.30%
# [INFO] Predicted last sample of window: Actual=33.74, Pred=33.64, MAPE=0.30%
#
# [INFO] Iteration 94: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.36%
# [INFO] Predicted last sample of window: Actual=33.50, Pred=33.38, MAPE=0.36%
#
# [INFO] Iteration 95: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.66%
# [INFO] Predicted last sample of window: Actual=34.74, Pred=33.82, MAPE=2.66%
#
# [INFO] Iteration 96: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.31%
# [INFO] Predicted last sample of window: Actual=34.22, Pred=34.67, MAPE=1.31%
#
# [INFO] Iteration 97: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.03%
# [INFO] Predicted last sample of window: Actual=34.45, Pred=34.44, MAPE=0.03%
#
# [INFO] Iteration 98: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.15%
# [INFO] Predicted last sample of window: Actual=33.42, Pred=34.14, MAPE=2.15%
#
# [INFO] Iteration 99: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.43%
# [INFO] Predicted last sample of window: Actual=33.16, Pred=33.64, MAPE=1.43%
#
# [INFO] Iteration 100: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.33%
# [INFO] Predicted last sample of window: Actual=34.16, Pred=33.71, MAPE=1.33%
#
# [INFO] Iteration 101: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.51%
# [INFO] Predicted last sample of window: Actual=32.82, Pred=33.64, MAPE=2.51%
#
# [INFO] Iteration 102: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.29%
# [INFO] Predicted last sample of window: Actual=32.97, Pred=32.87, MAPE=0.29%
#
# [INFO] Iteration 103: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.44%
# [INFO] Predicted last sample of window: Actual=33.99, Pred=32.82, MAPE=3.44%
#
# [INFO] Iteration 104: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.21%
# [INFO] Predicted last sample of window: Actual=33.23, Pred=33.30, MAPE=0.21%
#
# [INFO] Iteration 105: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.33%
# [INFO] Predicted last sample of window: Actual=32.78, Pred=33.22, MAPE=1.33%
#
# [INFO] Iteration 106: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.39%
# [INFO] Predicted last sample of window: Actual=36.86, Pred=35.24, MAPE=4.39%
#
# [INFO] Iteration 107: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.38%
# [INFO] Predicted last sample of window: Actual=35.23, Pred=36.42, MAPE=3.38%
#
# [INFO] Iteration 108: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.32%
# [INFO] Predicted last sample of window: Actual=38.16, Pred=36.51, MAPE=4.32%
#
# [INFO] Iteration 109: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.28%
# [INFO] Predicted last sample of window: Actual=37.21, Pred=37.31, MAPE=0.28%
#
# [INFO] Iteration 110: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.32%
# [INFO] Predicted last sample of window: Actual=36.94, Pred=37.43, MAPE=1.32%
#
# [INFO] Iteration 111: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 10.73%
# [INFO] Predicted last sample of window: Actual=41.98, Pred=37.47, MAPE=10.73%
#
# [INFO] Iteration 112: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.15%
# [INFO] Predicted last sample of window: Actual=40.19, Pred=40.25, MAPE=0.15%
#
# [INFO] Iteration 113: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.52%
# [INFO] Predicted last sample of window: Actual=38.50, Pred=40.24, MAPE=4.52%
#
# [INFO] Iteration 114: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.63%
# [INFO] Predicted last sample of window: Actual=40.21, Pred=39.96, MAPE=0.63%
#
# [INFO] Iteration 115: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.49%
# [INFO] Predicted last sample of window: Actual=40.90, Pred=40.29, MAPE=1.49%
#
# [INFO] Iteration 116: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.57%
# [INFO] Predicted last sample of window: Actual=42.80, Pred=41.70, MAPE=2.57%
#
# [INFO] Iteration 117: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.02%
# [INFO] Predicted last sample of window: Actual=43.80, Pred=42.92, MAPE=2.02%
#
# [INFO] Iteration 118: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.05%
# [INFO] Predicted last sample of window: Actual=43.04, Pred=43.06, MAPE=0.05%
#
# [INFO] Iteration 119: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.06%
# [INFO] Predicted last sample of window: Actual=43.48, Pred=43.50, MAPE=0.06%
#
# [INFO] Iteration 120: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.51%
# [INFO] Predicted last sample of window: Actual=41.95, Pred=43.00, MAPE=2.51%
#
# [INFO] Iteration 121: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.54%
# [INFO] Predicted last sample of window: Actual=41.77, Pred=42.00, MAPE=0.54%
#
# [INFO] Iteration 122: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=41.74, Pred=41.74, MAPE=0.00%
#
# [INFO] Iteration 123: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.04%
# [INFO] Predicted last sample of window: Actual=41.60, Pred=41.62, MAPE=0.04%
#
# [INFO] Iteration 124: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=41.50, Pred=41.50, MAPE=0.00%
#
# [INFO] Iteration 125: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.65%
# [INFO] Predicted last sample of window: Actual=44.61, Pred=42.53, MAPE=4.65%
#
# [INFO] Iteration 126: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.92%
# [INFO] Predicted last sample of window: Actual=45.46, Pred=44.59, MAPE=1.92%
#
# [INFO] Iteration 127: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.62%
# [INFO] Predicted last sample of window: Actual=47.88, Pred=45.67, MAPE=4.62%
#
# [INFO] Iteration 128: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.53%
# [INFO] Predicted last sample of window: Actual=50.31, Pred=48.03, MAPE=4.53%
#
# [INFO] Iteration 129: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.63%
# [INFO] Predicted last sample of window: Actual=48.84, Pred=48.53, MAPE=0.63%
#
# [INFO] Iteration 130: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.62%
# [INFO] Predicted last sample of window: Actual=48.11, Pred=48.89, MAPE=1.62%
#
# [INFO] Iteration 131: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.77%
# [INFO] Predicted last sample of window: Actual=46.90, Pred=47.73, MAPE=1.77%
#
# [INFO] Iteration 132: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.11%
# [INFO] Predicted last sample of window: Actual=45.35, Pred=46.76, MAPE=3.11%
#
# [INFO] Iteration 133: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.15%
# [INFO] Predicted last sample of window: Actual=44.84, Pred=45.81, MAPE=2.15%
#
# [INFO] Iteration 134: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.82%
# [INFO] Predicted last sample of window: Actual=45.63, Pred=45.25, MAPE=0.82%
#
# [INFO] Iteration 135: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.35%
# [INFO] Predicted last sample of window: Actual=48.33, Pred=45.74, MAPE=5.35%
#
# [INFO] Iteration 136: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.95%
# [INFO] Predicted last sample of window: Actual=52.10, Pred=49.00, MAPE=5.95%
#
# [INFO] Iteration 137: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.79%
# [INFO] Predicted last sample of window: Actual=51.12, Pred=50.71, MAPE=0.79%
#
# [INFO] Iteration 138: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.23%
# [INFO] Predicted last sample of window: Actual=50.52, Pred=50.63, MAPE=0.23%
#
# [INFO] Iteration 139: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.22%
# [INFO] Predicted last sample of window: Actual=52.85, Pred=52.73, MAPE=0.22%
#
# [INFO] Iteration 140: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.62%
# [INFO] Predicted last sample of window: Actual=52.37, Pred=52.04, MAPE=0.62%
#
# [INFO] Iteration 141: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.75%
# [INFO] Predicted last sample of window: Actual=55.05, Pred=52.98, MAPE=3.75%
#
# [INFO] Iteration 142: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.91%
# [INFO] Predicted last sample of window: Actual=55.76, Pred=55.25, MAPE=0.91%
#
# [INFO] Iteration 143: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.82%
# [INFO] Predicted last sample of window: Actual=56.40, Pred=55.94, MAPE=0.82%
#
# [INFO] Iteration 144: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.68%
# [INFO] Predicted last sample of window: Actual=56.52, Pred=56.13, MAPE=0.68%
#
# [INFO] Iteration 145: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 5.98%
# [INFO] Predicted last sample of window: Actual=60.93, Pred=57.29, MAPE=5.98%
#
# [INFO] Iteration 146: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.65%
# [INFO] Predicted last sample of window: Actual=59.93, Pred=60.32, MAPE=0.65%
#
# [INFO] Iteration 147: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.58%
# [INFO] Predicted last sample of window: Actual=61.31, Pred=60.96, MAPE=0.58%
#
# [INFO] Iteration 148: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.69%
# [INFO] Predicted last sample of window: Actual=60.39, Pred=61.41, MAPE=1.69%
#
# [INFO] Iteration 149: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.93%
# [INFO] Predicted last sample of window: Actual=59.37, Pred=59.92, MAPE=0.93%
#
# [INFO] Iteration 150: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.16%
# [INFO] Predicted last sample of window: Actual=56.49, Pred=58.84, MAPE=4.16%
#
# [INFO] Iteration 151: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.18%
# [INFO] Predicted last sample of window: Actual=55.22, Pred=56.42, MAPE=2.18%
#
# [INFO] Iteration 152: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.18%
# [INFO] Predicted last sample of window: Actual=56.18, Pred=56.08, MAPE=0.18%
#
# [INFO] Iteration 153: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.64%
# [INFO] Predicted last sample of window: Actual=57.40, Pred=56.46, MAPE=1.64%
#
# [INFO] Iteration 154: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.59%
# [INFO] Predicted last sample of window: Actual=55.83, Pred=56.72, MAPE=1.59%
#
# [INFO] Iteration 155: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.14%
# [INFO] Predicted last sample of window: Actual=56.50, Pred=56.58, MAPE=0.14%
#
# [INFO] Iteration 156: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.13%
# [INFO] Predicted last sample of window: Actual=56.59, Pred=56.52, MAPE=0.13%
#
# [INFO] Iteration 157: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.21%
# [INFO] Predicted last sample of window: Actual=55.87, Pred=55.75, MAPE=0.21%
#
# [INFO] Iteration 158: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.26%
# [INFO] Predicted last sample of window: Actual=55.71, Pred=55.86, MAPE=0.26%
#
# [INFO] Iteration 159: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.56%
# [INFO] Predicted last sample of window: Actual=56.98, Pred=56.09, MAPE=1.56%
#
# [INFO] Iteration 160: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.36%
# [INFO] Predicted last sample of window: Actual=56.48, Pred=56.68, MAPE=0.36%
#
# [INFO] Iteration 161: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.51%
# [INFO] Predicted last sample of window: Actual=56.00, Pred=56.29, MAPE=0.51%
#
# [INFO] Iteration 162: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=55.57, Pred=55.57, MAPE=0.00%
#
# [INFO] Iteration 163: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.33%
# [INFO] Predicted last sample of window: Actual=56.41, Pred=55.66, MAPE=1.33%
#
# [INFO] Iteration 164: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.36%
# [INFO] Predicted last sample of window: Actual=58.94, Pred=57.55, MAPE=2.36%
#
# [INFO] Iteration 165: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.03%
# [INFO] Predicted last sample of window: Actual=58.82, Pred=58.22, MAPE=1.03%
#
# [INFO] Iteration 166: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.28%
# [INFO] Predicted last sample of window: Actual=60.97, Pred=58.97, MAPE=3.28%
#
# [INFO] Iteration 167: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.50%
# [INFO] Predicted last sample of window: Actual=62.43, Pred=61.49, MAPE=1.50%
#
# [INFO] Iteration 168: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.38%
# [INFO] Predicted last sample of window: Actual=60.59, Pred=62.03, MAPE=2.38%
#
# [INFO] Iteration 169: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.90%
# [INFO] Predicted last sample of window: Actual=59.30, Pred=60.43, MAPE=1.90%
#
# [INFO] Iteration 170: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.75%
# [INFO] Predicted last sample of window: Actual=62.19, Pred=60.48, MAPE=2.75%
#
# [INFO] Iteration 171: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.43%
# [INFO] Predicted last sample of window: Actual=58.98, Pred=61.00, MAPE=3.43%
#
# [INFO] Iteration 172: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.08%
# [INFO] Predicted last sample of window: Actual=58.92, Pred=58.87, MAPE=0.08%
#
# [INFO] Iteration 173: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.12%
# [INFO] Predicted last sample of window: Actual=58.26, Pred=58.91, MAPE=1.12%
#
# [INFO] Iteration 174: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.60%
# [INFO] Predicted last sample of window: Actual=58.56, Pred=58.91, MAPE=0.60%
#
# [INFO] Iteration 175: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.27%
# [INFO] Predicted last sample of window: Actual=60.46, Pred=58.48, MAPE=3.27%
#
# [INFO] Iteration 176: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.01%
# [INFO] Predicted last sample of window: Actual=61.18, Pred=61.17, MAPE=0.01%
#
# [INFO] Iteration 177: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.02%
# [INFO] Predicted last sample of window: Actual=61.05, Pred=61.07, MAPE=0.02%
#
# [INFO] Iteration 178: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.63%
# [INFO] Predicted last sample of window: Actual=62.65, Pred=61.63, MAPE=1.63%
#
# [INFO] Iteration 179: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.24%
# [INFO] Predicted last sample of window: Actual=62.17, Pred=62.32, MAPE=0.24%
#
# [INFO] Iteration 180: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.68%
# [INFO] Predicted last sample of window: Actual=64.33, Pred=62.61, MAPE=2.68%
#
# [INFO] Iteration 181: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.77%
# [INFO] Predicted last sample of window: Actual=61.99, Pred=62.47, MAPE=0.77%
#
# [INFO] Iteration 182: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.46%
# [INFO] Predicted last sample of window: Actual=62.59, Pred=62.30, MAPE=0.46%
#
# [INFO] Iteration 183: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.77%
# [INFO] Predicted last sample of window: Actual=64.26, Pred=62.48, MAPE=2.77%
#
# [INFO] Iteration 184: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.56%
# [INFO] Predicted last sample of window: Actual=64.66, Pred=64.30, MAPE=0.56%
#
# [INFO] Iteration 185: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.94%
# [INFO] Predicted last sample of window: Actual=62.62, Pred=64.46, MAPE=2.94%
#
# [INFO] Iteration 186: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.36%
# [INFO] Predicted last sample of window: Actual=63.26, Pred=63.03, MAPE=0.36%
#
# [INFO] Iteration 187: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.75%
# [INFO] Predicted last sample of window: Actual=61.37, Pred=63.06, MAPE=2.75%
#
# [INFO] Iteration 188: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.12%
# [INFO] Predicted last sample of window: Actual=60.14, Pred=60.81, MAPE=1.12%
#
# [INFO] Iteration 189: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.14%
# [INFO] Predicted last sample of window: Actual=61.17, Pred=61.08, MAPE=0.14%
#
# [INFO] Iteration 190: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.21%
# [INFO] Predicted last sample of window: Actual=59.53, Pred=60.84, MAPE=2.21%
#
# [INFO] Iteration 191: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 7.50%
# [INFO] Predicted last sample of window: Actual=57.32, Pred=53.02, MAPE=7.50%
#
# [INFO] Iteration 192: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.48%
# [INFO] Predicted last sample of window: Actual=55.96, Pred=56.79, MAPE=1.48%
#
# [INFO] Iteration 193: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.29%
# [INFO] Predicted last sample of window: Actual=57.11, Pred=56.95, MAPE=0.29%
#
# [INFO] Iteration 194: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.44%
# [INFO] Predicted last sample of window: Actual=58.48, Pred=57.06, MAPE=2.44%
#
# [INFO] Iteration 195: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.60%
# [INFO] Predicted last sample of window: Actual=58.22, Pred=57.87, MAPE=0.60%
#
# [INFO] Iteration 196: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.22%
# [INFO] Predicted last sample of window: Actual=57.57, Pred=58.27, MAPE=1.22%
#
# [INFO] Iteration 197: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.06%
# [INFO] Predicted last sample of window: Actual=58.20, Pred=58.17, MAPE=0.06%
#
# [INFO] Iteration 198: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.50%
# [INFO] Predicted last sample of window: Actual=57.20, Pred=57.49, MAPE=0.50%
#
# [INFO] Iteration 199: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.06%
# [INFO] Predicted last sample of window: Actual=57.20, Pred=57.17, MAPE=0.06%
#
# [INFO] Iteration 200: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.79%
# [INFO] Predicted last sample of window: Actual=58.35, Pred=57.89, MAPE=0.79%
#
# [INFO] Iteration 201: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.96%
# [INFO] Predicted last sample of window: Actual=56.77, Pred=57.32, MAPE=0.96%
#
# [INFO] Iteration 202: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.06%
# [INFO] Predicted last sample of window: Actual=55.56, Pred=56.71, MAPE=2.06%
#
# [INFO] Iteration 203: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 4.90%
# [INFO] Predicted last sample of window: Actual=52.73, Pred=55.31, MAPE=4.90%
#
# [INFO] Iteration 204: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.49%
# [INFO] Predicted last sample of window: Actual=54.91, Pred=54.09, MAPE=1.49%
#
# [INFO] Iteration 205: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.18%
# [INFO] Predicted last sample of window: Actual=55.46, Pred=54.81, MAPE=1.18%
#
# [INFO] Iteration 206: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.82%
# [INFO] Predicted last sample of window: Actual=55.77, Pred=55.31, MAPE=0.82%
#
# [INFO] Iteration 207: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.44%
# [INFO] Predicted last sample of window: Actual=54.52, Pred=55.85, MAPE=2.44%
#
# [INFO] Iteration 208: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.18%
# [INFO] Predicted last sample of window: Actual=55.08, Pred=54.98, MAPE=0.18%
#
# [INFO] Iteration 209: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.03%
# [INFO] Predicted last sample of window: Actual=54.55, Pred=54.53, MAPE=0.03%
#
# [INFO] Iteration 210: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.64%
# [INFO] Predicted last sample of window: Actual=54.09, Pred=54.44, MAPE=0.64%
#
# [INFO] Iteration 211: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.35%
# [INFO] Predicted last sample of window: Actual=55.37, Pred=54.07, MAPE=2.35%
#
# [INFO] Iteration 212: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.96%
# [INFO] Predicted last sample of window: Actual=56.42, Pred=54.75, MAPE=2.96%
#
# [INFO] Iteration 213: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.57%
# [INFO] Predicted last sample of window: Actual=55.16, Pred=55.47, MAPE=0.57%
#
# [INFO] Iteration 214: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.47%
# [INFO] Predicted last sample of window: Actual=53.64, Pred=54.97, MAPE=2.47%
#
# [INFO] Iteration 215: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.67%
# [INFO] Predicted last sample of window: Actual=57.08, Pred=54.99, MAPE=3.67%
#
# [INFO] Iteration 216: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.07%
# [INFO] Predicted last sample of window: Actual=59.30, Pred=57.48, MAPE=3.07%
#
# [INFO] Iteration 217: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.51%
# [INFO] Predicted last sample of window: Actual=59.88, Pred=59.57, MAPE=0.51%
#
# [INFO] Iteration 218: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.82%
# [INFO] Predicted last sample of window: Actual=60.93, Pred=59.82, MAPE=1.82%
#
# [INFO] Iteration 219: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.40%
# [INFO] Predicted last sample of window: Actual=61.62, Pred=62.48, MAPE=1.40%
#
# [INFO] Iteration 220: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.47%
# [INFO] Predicted last sample of window: Actual=60.66, Pred=60.95, MAPE=0.47%
#
# [INFO] Iteration 221: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.11%
# [INFO] Predicted last sample of window: Actual=61.56, Pred=61.49, MAPE=0.11%
#
# [INFO] Iteration 222: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.27%
# [INFO] Predicted last sample of window: Actual=61.07, Pred=61.23, MAPE=0.27%
#
# [INFO] Iteration 223: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.76%
# [INFO] Predicted last sample of window: Actual=62.59, Pred=61.49, MAPE=1.76%
#
# [INFO] Iteration 224: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.39%
# [INFO] Predicted last sample of window: Actual=63.50, Pred=62.62, MAPE=1.39%
#
# [INFO] Iteration 225: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.07%
# [INFO] Predicted last sample of window: Actual=62.69, Pred=62.73, MAPE=0.07%
#
# [INFO] Iteration 226: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.41%
# [INFO] Predicted last sample of window: Actual=64.35, Pred=63.45, MAPE=1.41%
#
# [INFO] Iteration 227: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.48%
# [INFO] Predicted last sample of window: Actual=64.13, Pred=64.44, MAPE=0.48%
#
# [INFO] Iteration 228: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.19%
# [INFO] Predicted last sample of window: Actual=64.47, Pred=64.35, MAPE=0.19%
#
# [INFO] Iteration 229: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.57%
# [INFO] Predicted last sample of window: Actual=64.82, Pred=64.45, MAPE=0.57%
#
# [INFO] Iteration 230: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.02%
# [INFO] Predicted last sample of window: Actual=64.41, Pred=64.42, MAPE=0.02%
#
# [INFO] Iteration 231: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.46%
# [INFO] Predicted last sample of window: Actual=65.72, Pred=64.76, MAPE=1.46%
#
# [INFO] Iteration 232: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.36%
# [INFO] Predicted last sample of window: Actual=64.19, Pred=65.06, MAPE=1.36%
#
# [INFO] Iteration 233: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.55%
# [INFO] Predicted last sample of window: Actual=63.82, Pred=64.17, MAPE=0.55%
#
# [INFO] Iteration 234: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.15%
# [INFO] Predicted last sample of window: Actual=65.02, Pred=64.27, MAPE=1.15%
#
# [INFO] Iteration 235: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.11%
# [INFO] Predicted last sample of window: Actual=63.61, Pred=64.32, MAPE=1.11%
#
# [INFO] Iteration 236: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.16%
# [INFO] Predicted last sample of window: Actual=61.51, Pred=62.84, MAPE=2.16%
#
# [INFO] Iteration 237: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.88%
# [INFO] Predicted last sample of window: Actual=63.48, Pred=62.92, MAPE=0.88%
#
# [INFO] Iteration 238: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.15%
# [INFO] Predicted last sample of window: Actual=61.59, Pred=61.50, MAPE=0.15%
#
# [INFO] Iteration 239: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.96%
# [INFO] Predicted last sample of window: Actual=59.79, Pred=60.96, MAPE=1.96%
#
# [INFO] Iteration 240: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.64%
# [INFO] Predicted last sample of window: Actual=60.89, Pred=60.50, MAPE=0.64%
#
# [INFO] Iteration 241: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.59%
# [INFO] Predicted last sample of window: Actual=62.27, Pred=61.28, MAPE=1.59%
#
# [INFO] Iteration 242: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.41%
# [INFO] Predicted last sample of window: Actual=62.61, Pred=62.35, MAPE=0.41%
#
# [INFO] Iteration 243: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.35%
# [INFO] Predicted last sample of window: Actual=61.63, Pred=62.46, MAPE=1.35%
#
# [INFO] Iteration 244: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.38%
# [INFO] Predicted last sample of window: Actual=61.27, Pred=61.51, MAPE=0.38%
#
# [INFO] Iteration 245: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.57%
# [INFO] Predicted last sample of window: Actual=60.03, Pred=60.97, MAPE=1.57%
#
# [INFO] Iteration 246: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.03%
# [INFO] Predicted last sample of window: Actual=60.50, Pred=60.48, MAPE=0.03%
#
# [INFO] Iteration 247: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.01%
# [INFO] Predicted last sample of window: Actual=61.02, Pred=60.41, MAPE=1.01%
#
# [INFO] Iteration 248: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.05%
# [INFO] Predicted last sample of window: Actual=61.69, Pred=61.04, MAPE=1.05%
#
# [INFO] Iteration 249: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.57%
# [INFO] Predicted last sample of window: Actual=60.79, Pred=61.14, MAPE=0.57%
#
# [INFO] Iteration 250: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.77%
# [INFO] Predicted last sample of window: Actual=63.54, Pred=61.14, MAPE=3.77%
#
# [INFO] Iteration 251: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 11.16%
# [INFO] Predicted last sample of window: Actual=66.75, Pred=74.20, MAPE=11.16%
#
# ...
# [INFO] Predicted last sample of window: Actual=109.14, Pred=108.76, MAPE=0.35%
#
# [INFO] Iteration 420: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.69%
# [INFO] Predicted last sample of window: Actual=105.79, Pred=108.63, MAPE=2.69%
#
# [INFO] Iteration 421: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.77%
# [INFO] Predicted last sample of window: Actual=105.07, Pred=105.88, MAPE=0.77%
#
# [INFO] Iteration 422: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.56%
# [INFO] Predicted last sample of window: Actual=104.82, Pred=104.23, MAPE=0.56%
#
# [INFO] Iteration 423: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.07%
# [INFO] Predicted last sample of window: Actual=106.26, Pred=105.12, MAPE=1.07%
#
# [INFO] Iteration 424: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.46%
# [INFO] Predicted last sample of window: Actual=106.40, Pred=105.91, MAPE=0.46%
#
# [INFO] Iteration 425: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.72%
# [INFO] Predicted last sample of window: Actual=105.66, Pred=106.42, MAPE=0.72%
#
# [INFO] Iteration 426: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.54%
# [INFO] Predicted last sample of window: Actual=104.04, Pred=105.64, MAPE=1.54%
#
# [INFO] Iteration 427: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.78%
# [INFO] Predicted last sample of window: Actual=103.36, Pred=104.17, MAPE=0.78%
#
# [INFO] Iteration 428: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.21%
# [INFO] Predicted last sample of window: Actual=105.29, Pred=104.01, MAPE=1.21%
#
# [INFO] Iteration 429: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.54%
# [INFO] Predicted last sample of window: Actual=108.53, Pred=105.78, MAPE=2.54%
#
# [INFO] Iteration 430: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.19%
# [INFO] Predicted last sample of window: Actual=107.39, Pred=107.59, MAPE=0.19%
#
# [INFO] Iteration 431: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.78%
# [INFO] Predicted last sample of window: Actual=106.44, Pred=107.27, MAPE=0.78%
#
# [INFO] Iteration 432: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.38%
# [INFO] Predicted last sample of window: Actual=105.89, Pred=106.29, MAPE=0.38%
#
# [INFO] Iteration 433: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.27%
# [INFO] Predicted last sample of window: Actual=102.72, Pred=105.05, MAPE=2.27%
#
# [INFO] Iteration 434: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.57%
# [INFO] Predicted last sample of window: Actual=103.30, Pred=103.89, MAPE=0.57%
#
# [INFO] Iteration 435: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.06%
# [INFO] Predicted last sample of window: Actual=104.29, Pred=103.18, MAPE=1.06%
#
# [INFO] Iteration 436: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.55%
# [INFO] Predicted last sample of window: Actual=105.40, Pred=104.82, MAPE=0.55%
#
# [INFO] Iteration 437: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.46%
# [INFO] Predicted last sample of window: Actual=107.25, Pred=105.68, MAPE=1.46%
#
# [INFO] Iteration 438: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.02%
# [INFO] Predicted last sample of window: Actual=106.91, Pred=106.94, MAPE=0.02%
#
# [INFO] Iteration 439: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.06%
# [INFO] Predicted last sample of window: Actual=103.16, Pred=106.31, MAPE=3.06%
#
# [INFO] Iteration 440: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.39%
# [INFO] Predicted last sample of window: Actual=105.97, Pred=104.49, MAPE=1.39%
#
# [INFO] Iteration 441: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.27%
# [INFO] Predicted last sample of window: Actual=104.54, Pred=104.82, MAPE=0.27%
#
# [INFO] Iteration 442: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.58%
# [INFO] Predicted last sample of window: Actual=101.38, Pred=104.00, MAPE=2.58%
#
# [INFO] Iteration 443: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.29%
# [INFO] Predicted last sample of window: Actual=101.62, Pred=101.33, MAPE=0.29%
#
# [INFO] Iteration 444: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.05%
# [INFO] Predicted last sample of window: Actual=103.89, Pred=101.76, MAPE=2.05%
#
# [INFO] Iteration 445: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.56%
# [INFO] Predicted last sample of window: Actual=105.68, Pred=104.03, MAPE=1.56%
#
# [INFO] Iteration 446: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.00%
# [INFO] Predicted last sample of window: Actual=105.42, Pred=105.42, MAPE=0.00%
#
# [INFO] Iteration 447: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.60%
# [INFO] Predicted last sample of window: Actual=107.24, Pred=106.59, MAPE=0.60%
#
# [INFO] Iteration 448: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.29%
# [INFO] Predicted last sample of window: Actual=105.29, Pred=105.59, MAPE=0.29%
#
# [INFO] Iteration 449: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.33%
# [INFO] Predicted last sample of window: Actual=107.42, Pred=107.07, MAPE=0.33%
#
# [INFO] Iteration 450: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.47%
# [INFO] Predicted last sample of window: Actual=107.73, Pred=107.23, MAPE=0.47%
#
# [INFO] Iteration 451: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.94%
# [INFO] Predicted last sample of window: Actual=110.12, Pred=107.99, MAPE=1.94%
#
# [INFO] Iteration 452: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.50%
# [INFO] Predicted last sample of window: Actual=111.92, Pred=110.24, MAPE=1.50%
#
# [INFO] Iteration 453: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.60%
# [INFO] Predicted last sample of window: Actual=106.34, Pred=110.17, MAPE=3.60%
#
# [INFO] Iteration 454: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.42%
# [INFO] Predicted last sample of window: Actual=110.04, Pred=108.47, MAPE=1.42%
#
# [INFO] Iteration 455: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.30%
# [INFO] Predicted last sample of window: Actual=108.10, Pred=108.42, MAPE=0.30%
#
# [INFO] Iteration 456: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.67%
# [INFO] Predicted last sample of window: Actual=106.35, Pred=108.13, MAPE=1.67%
#
# [INFO] Iteration 457: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.01%
# [INFO] Predicted last sample of window: Actual=109.16, Pred=108.05, MAPE=1.01%
#
# [INFO] Iteration 458: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.43%
# [INFO] Predicted last sample of window: Actual=110.88, Pred=109.30, MAPE=1.43%
#
# [INFO] Iteration 459: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.18%
# [INFO] Predicted last sample of window: Actual=113.52, Pred=111.04, MAPE=2.18%
#
# [INFO] Iteration 460: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.28%
# [INFO] Predicted last sample of window: Actual=114.51, Pred=114.19, MAPE=0.28%
#
# [INFO] Iteration 461: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.46%
# [INFO] Predicted last sample of window: Actual=115.61, Pred=113.93, MAPE=1.46%
#
# [INFO] Iteration 462: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.39%
# [INFO] Predicted last sample of window: Actual=117.49, Pred=115.86, MAPE=1.39%
#
# [INFO] Iteration 463: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.50%
# [INFO] Predicted last sample of window: Actual=118.52, Pred=116.74, MAPE=1.50%
#
# [INFO] Iteration 464: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.09%
# [INFO] Predicted last sample of window: Actual=117.64, Pred=117.54, MAPE=0.09%
#
# [INFO] Iteration 465: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.12%
# [INFO] Predicted last sample of window: Actual=116.40, Pred=117.70, MAPE=1.12%
#
# [INFO] Iteration 466: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.88%
# [INFO] Predicted last sample of window: Actual=114.94, Pred=113.93, MAPE=0.88%
#
# [INFO] Iteration 467: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.31%
# [INFO] Predicted last sample of window: Actual=116.41, Pred=116.05, MAPE=0.31%
#
# [INFO] Iteration 468: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.59%
# [INFO] Predicted last sample of window: Actual=119.47, Pred=118.76, MAPE=0.59%
#
# [INFO] Iteration 469: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.53%
# [INFO] Predicted last sample of window: Actual=115.63, Pred=117.40, MAPE=1.53%
#
# [INFO] Iteration 470: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.68%
# [INFO] Predicted last sample of window: Actual=111.50, Pred=115.61, MAPE=3.68%
#
# [INFO] Iteration 471: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 3.15%
# [INFO] Predicted last sample of window: Actual=107.17, Pred=110.55, MAPE=3.15%
#
# [INFO] Iteration 472: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.06%
# [INFO] Predicted last sample of window: Actual=110.45, Pred=110.38, MAPE=0.06%
#
# [INFO] Iteration 473: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.17%
# [INFO] Predicted last sample of window: Actual=106.47, Pred=106.66, MAPE=0.17%
#
# [INFO] Iteration 474: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.42%
# [INFO] Predicted last sample of window: Actual=109.95, Pred=109.48, MAPE=0.42%
#
# [INFO] Iteration 475: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.52%
# [INFO] Predicted last sample of window: Actual=112.95, Pred=110.11, MAPE=2.52%
#
# [INFO] Iteration 476: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.57%
# [INFO] Predicted last sample of window: Actual=111.08, Pred=111.71, MAPE=0.57%
#
# [INFO] Iteration 477: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.98%
# [INFO] Predicted last sample of window: Actual=108.39, Pred=110.53, MAPE=1.98%
#
# [INFO] Iteration 478: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.81%
# [INFO] Predicted last sample of window: Actual=107.60, Pred=108.47, MAPE=0.81%
#
# [INFO] Iteration 479: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.26%
# [INFO] Predicted last sample of window: Actual=105.88, Pred=108.27, MAPE=2.26%
#
# [INFO] Iteration 480: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.17%
# [INFO] Predicted last sample of window: Actual=105.64, Pred=105.82, MAPE=0.17%
#
# [INFO] Iteration 481: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.70%
# [INFO] Predicted last sample of window: Actual=107.78, Pred=105.95, MAPE=1.70%
#
# [INFO] Iteration 482: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.80%
# [INFO] Predicted last sample of window: Actual=104.21, Pred=106.09, MAPE=1.80%
#
# [INFO] Iteration 483: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.88%
# [INFO] Predicted last sample of window: Actual=102.96, Pred=103.87, MAPE=0.88%
#
# [INFO] Iteration 484: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.18%
# [INFO] Predicted last sample of window: Actual=104.84, Pred=103.60, MAPE=1.18%
#
# [INFO] Iteration 485: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.15%
# [INFO] Predicted last sample of window: Actual=103.66, Pred=103.82, MAPE=0.15%
#
# [INFO] Iteration 486: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.65%
# [INFO] Predicted last sample of window: Actual=104.96, Pred=104.27, MAPE=0.65%
#
# [INFO] Iteration 487: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.15%
# [INFO] Predicted last sample of window: Actual=104.46, Pred=104.62, MAPE=0.15%
#
# [INFO] Iteration 488: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.08%
# [INFO] Predicted last sample of window: Actual=104.57, Pred=104.49, MAPE=0.08%
#
# [INFO] Iteration 489: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.06%
# [INFO] Predicted last sample of window: Actual=103.90, Pred=103.96, MAPE=0.06%
#
# [INFO] Iteration 490: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.03%
# [INFO] Predicted last sample of window: Actual=102.74, Pred=103.79, MAPE=1.03%
#
# [INFO] Iteration 491: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.24%
# [INFO] Predicted last sample of window: Actual=102.43, Pred=102.67, MAPE=0.24%
#
# [INFO] Iteration 492: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.59%
# [INFO] Predicted last sample of window: Actual=99.11, Pred=100.69, MAPE=1.59%
#
# [INFO] Iteration 493: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.12%
# [INFO] Predicted last sample of window: Actual=99.55, Pred=99.43, MAPE=0.12%
#
# [INFO] Iteration 494: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.11%
# [INFO] Predicted last sample of window: Actual=98.05, Pred=99.14, MAPE=1.11%
#
# [INFO] Iteration 495: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 2.08%
# [INFO] Predicted last sample of window: Actual=101.58, Pred=99.46, MAPE=2.08%
#
# [INFO] Iteration 496: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.57%
# [INFO] Predicted last sample of window: Actual=101.65, Pred=101.07, MAPE=0.57%
#
# [INFO] Iteration 497: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.33%
# [INFO] Predicted last sample of window: Actual=101.27, Pred=101.60, MAPE=0.33%
#
# [INFO] Iteration 498: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.18%
# [INFO] Predicted last sample of window: Actual=101.91, Pred=101.73, MAPE=0.18%
#
# [INFO] Iteration 499: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 0.05%
# [INFO] Predicted last sample of window: Actual=101.66, Pred=101.71, MAPE=0.05%
#
# [INFO] Iteration 500: training on new window with Early Stopping...
# [RESULT] Window validation MAPE: 1.43%
# [INFO] Predicted last sample of window: Actual=99.98, Pred=101.40, MAPE=1.43%
# [INFO] No more windows can be extracted.
#
# [INFO] Rolling training with Early Stopping completed for XOM. Overall MAPE: 1.63%
# [INFO] Total elapsed time: 786.25s
# [INFO] Top 10 worst predictions in rolling scenario (Early Stopping):
#           Date     Actual  Predicted       MAPE
# 52  2020-06-10  46.180000  53.094856  14.973703
# 19  2020-03-06  41.860001  48.121807  14.958926
# 250 2022-01-04  66.750000  74.196892  11.156392
# 110 2020-11-23  41.980000  37.473969  10.733757
# 25  2020-03-24  37.290001  33.868168   9.176275
# 30  2020-04-07  43.849998  40.464996   7.719503
# 190 2021-07-15  57.320000  53.023495   7.495647
# 37  2020-04-28  47.459999  43.946514   7.403045
# 50  2020-06-04  53.080002  49.269924   7.177991
# 28  2020-04-01  40.400002  37.523495   7.120066
